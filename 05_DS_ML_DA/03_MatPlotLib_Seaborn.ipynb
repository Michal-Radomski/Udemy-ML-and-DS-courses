# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Generate sample data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create the plot
plt.figure(figsize=(8, 5))
plt.plot(x, y, label='sin(x)', color='blue', linewidth=2)
plt.title('Simple Sine Wave Plot')
plt.xlabel('X values')
plt.ylabel('sin(X)')
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %%
# Sample data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.exp(-x/5) * np.cos(x)

# Set global style
plt.style.use('seaborn-v0_8-darkgrid')  # Modern dark theme

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Left plot: Styled line with fill
ax1.plot(x, y1, '-.', color='#FF6B6B', linewidth=2.5, label='sin(x)', alpha=0.8)
ax1.fill_between(x, y1, alpha=0.3, color='#FF6B6B')
ax1.set_title('Styled Sine Wave', fontsize=14, fontweight='bold')
ax1.set_xlabel('X Axis', fontsize=12)
ax1.set_ylabel('Value', fontsize=12)
ax1.legend(loc='upper right')
ax1.grid(True, linestyle='--', alpha=0.5)

# Annotate a point
ax1.annotate('Peak', xy=(np.pi/2, 1), xytext=(4, 0.8),
             arrowprops=dict(arrowstyle='->', color='white', lw=1.5),
             fontsize=10, color='white', fontweight='bold')

# Right plot: Multiple lines with markers
colors = ['#4ECDC4', '#45B7D1', '#F18F01']
for i, y in enumerate([y2, y3, y1*0.5]):
    ax2.plot(x, y, '-', color=colors[i], linewidth=2, 
             marker='o', markersize=4, markevery=10, label=f'Curve {i+1}')
ax2.set_title('Multi-Line Plot with Markers', fontsize=14, fontweight='bold')
ax2.legend(frameon=True, fancybox=True, shadow=True)
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Sample data - sales by product
categories = ['Laptops', 'Phones', 'Tablets', 'Headphones', 'Monitors']
sales = [450, 320, 180, 250, 380]

# Create the bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(categories, sales, 
               color=['#FF6B6B', '#4ECDC4', '#45B7D1', '#F18F01', '#96CEB4'],
               edgecolor='black', linewidth=1.2, alpha=0.8)

# Customize appearance
plt.title('Product Sales by Category (2026)', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Product Categories', fontsize=12)
plt.ylabel('Sales ($K)', fontsize=12)

# Add value labels on top of bars
for bar, value in zip(bars, sales):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 5,
             f'${value}K', ha='center', va='bottom', fontweight='bold')

# Rotate x-axis labels for better readability
plt.xticks(rotation=15, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.3)

# Improve layout
plt.tight_layout()
plt.show()

# %%
# Load built-in dataset
tips = sns.load_dataset("tips")

# Create grouped bar plot by day and smoker status
plt.figure(figsize=(10, 6))
sns.catplot(data=tips, kind="bar", x="day", y="total_bill", hue="smoker", 
            height=6, aspect=1.5, palette="Set2")

plt.title("Average Total Bill by Day and Smoker Status", fontsize=16, fontweight='bold', pad=20)
plt.xlabel("Day of Week", fontsize=12)
plt.ylabel("Average Total Bill ($)", fontsize=12)
plt.xticks(rotation=0)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
# Load dataset
tips = sns.load_dataset("tips")

# Create 2x2 subplot grid
fig, axes = plt.subplots(2, 2, figsize=(15, 12))
fig.suptitle('Matplotlib vs Seaborn: Tips Dataset Comparison', fontsize=18, fontweight='bold')

# 1. Matplotlib scatter plot (manual styling)
x_mat = tips['total_bill']
y_mat = tips['tip']
axes[0,0].scatter(x_mat, y_mat, c=tips['size'], cmap='viridis', alpha=0.6, s=60)
axes[0,0].set_title('Matplotlib: Scatter (Manual)', fontsize=14)
axes[0,0].set_xlabel('Total Bill ($)')
axes[0,0].set_ylabel('Tip ($)')
axes[0,0].grid(True, alpha=0.3)

# 2. Seaborn scatter plot (automatic styling)
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='size', size='size', 
                sizes=(20, 200), alpha=0.7, ax=axes[0,1])
axes[0,1].set_title('Seaborn: Scatter (Automatic)', fontsize=14)

# 3. Matplotlib histogram (grouped manually)
axes[1,0].hist([tips[tips['sex']=='Male']['tip'], tips[tips['sex']=='Female']['tip']], 
               bins=15, alpha=0.7, label=['Male', 'Female'], color=['skyblue', 'coral'])
axes[1,0].set_title('Matplotlib: Grouped Histogram', fontsize=14)
axes[1,0].set_xlabel('Tip Amount ($)')
axes[1,0].legend()

# 4. Seaborn violin plot (statistical)
sns.violinplot(data=tips, x='day', y='total_bill', hue='time', split=True, ax=axes[1,1])
axes[1,1].set_title('Seaborn: Violin Plot (Statistical)', fontsize=14)

plt.tight_layout()
plt.show()
