# %%
import numpy as np
print(np.__version__)
# Out:
# 2.1.3

# %%
a = [10,20,30.1]
print(a)
type(a)

b=np.array(a)
print(b)
# Out:
# [10, 20, 30.1]
# [10.  20.  30.1]

# %%
b+100
# Out:
# array([110. , 120. , 130.1])

# %%
np.shape(b)
# Out:
# (3,)

# %%
b.dtype
# Out:
# dtype('float64')

# %%
c=np.array([1,2,3], dtype=complex)
print(c)
print(c.dtype)
# Out:
# [1.+0.j 2.+0.j 3.+0.j]
# complex128

# %%
d=np.array([[1,2,3],[4,5,6]])
print(d)
print(d.shape)
# Out:
# [[1 2 3]
#  [4 5 6]]
# (2, 3)
