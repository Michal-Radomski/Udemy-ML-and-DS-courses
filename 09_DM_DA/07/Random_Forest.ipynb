# %%
# Import libraries
import pandas as pd

# %%
# Import the data
data = pd.read_csv("data/bank-full.csv", sep = ";")
data.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
# Transform the string variables
dataset = pd.get_dummies(data = data,
                         drop_first = True)
dataset.head()
# Out:
#    age  balance  day  duration  campaign  pdays  previous  job_blue-collar  \
# 0   58     2143    5       261         1     -1         0            False
# 1   44       29    5       151         1     -1         0            False
# 2   33        2    5        76         1     -1         0            False
# 3   47     1506    5        92         1     -1         0             True
# 4   33        1    5       198         1     -1         0            False
#
#    job_entrepreneur  job_housemaid  ...  month_jun  month_mar  month_may  \
# 0             False          False  ...      False      False       True
# 1             False          False  ...      False      False       True
# 2              True          False  ...      False      False       True
# 3             False          False  ...      False      False       True
# 4             False          False  ...      False      False       True
#
#    month_nov  month_oct  month_sep  poutcome_other  poutcome_success  \
# 0      False      False      False           False             False
# 1      False      False      False           False             False
# 2      False      False      False           False             False
# 3      False      False      False           False             False
# 4      False      False      False           False             False
#
#    poutcome_unknown  y_yes
# 0              True  False
# 1              True  False
# 2              True  False
# 3              True  False
# 4              True  False
#
# [5 rows x 43 columns]

# %%
# Isolate X and Y
y = dataset.iloc[:,-1]
X = dataset.iloc[:, :-1]
X.head(1)
# Out:
#    age  balance  day  duration  campaign  pdays  previous  job_blue-collar  \
# 0   58     2143    5       261         1     -1         0            False
#
#    job_entrepreneur  job_housemaid  ...  month_jul  month_jun  month_mar  \
# 0             False          False  ...      False      False      False
#
#    month_may  month_nov  month_oct  month_sep  poutcome_other  \
# 0       True      False      False      False           False
#
#    poutcome_success  poutcome_unknown
# 0             False              True
#
# [1 rows x 42 columns]

# %%
# Split into training and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size = 0.2,
                                                    random_state = 1502,
                                                    stratify = y)
X_train.head()
# Out:
#        age  balance  day  duration  campaign  pdays  previous  \
# 6276    31       66   27       121         1     -1         0
# 2876    48      427   14       201         1     -1         0
# 39212   33      139   18       732         2    291         5
# 40781   23        0   10       213         1     -1         0
# 7551    37     1255   30       224         2     -1         0
#
#        job_blue-collar  job_entrepreneur  job_housemaid  ...  month_jul  \
# 6276              True             False          False  ...      False
# 2876             False             False          False  ...      False
# 39212             True             False          False  ...      False
# 40781            False             False          False  ...      False
# 7551             False             False          False  ...      False
#
#        month_jun  month_mar  month_may  month_nov  month_oct  month_sep  \
# 6276       False      False       True      False      False      False
# 2876       False      False       True      False      False      False
# 39212      False      False       True      False      False      False
# 40781      False      False      False      False      False      False
# 7551       False      False       True      False      False      False
#
#        poutcome_other  poutcome_success  poutcome_unknown
# 6276            False             False              True
# 2876            False             False              True
# 39212           False             False             False
# 40781           False             False              True
# 7551            False             False              True
#
# [5 rows x 42 columns]

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators = 300,
                               random_state = 1502)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=300, random_state=1502)

# %%
# Predictions
predictions = model.predict(X_test)
predictions[:20]
# Out:
# array([False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False])

# %%
# Checkin dataset balance
y_test.mean()
# Out:
# np.float64(0.11699657193409267)

# %%
# Confusion Matrix
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.92      0.97      0.95      7985
#         True       0.67      0.40      0.50      1058
#
#     accuracy                           0.91      9043
#    macro avg       0.80      0.68      0.72      9043
# weighted avg       0.89      0.91      0.90      9043

# %%
# Feature Importance
importance = pd.Series(model.feature_importances_,
                       index = X_train.columns.values)
importance.nlargest(5).plot(kind = 'barh',
                            figsize = (12, 8))
# Out:
# <Axes: >

# %%
# Libraries
import numpy as np
import pandas as p

# %%
# Data
data = pd.read_csv("data/Affairs dataset.csv")
data.head()
# Out:
#    Unnamed: 0  affairs  gender   age  yearsmarried children  religiousness  \
# 0           4        0    male  37.0         10.00       no              3
# 1           5        0  female  27.0          4.00       no              4
# 2          11        0  female  32.0         15.00      yes              1
# 3          16        0    male  57.0         15.00      yes              5
# 4          23        0    male  22.0          0.75       no              2
#
#    education  occupation  rating
# 0         18           7       4
# 1         14           6       4
# 2         12           1       4
# 3         18           6       5
# 4         17           6       3

# %%
data.affairs.unique()
# Out:
# array([ 0,  3,  7, 12,  1,  2])

# %%
# Isolate X and Y
y = data.iloc[:,1]
X = data.iloc[:,2:]
X.head(1)
# Out:
#   gender   age  yearsmarried children  religiousness  education  occupation  \
# 0   male  37.0          10.0       no              3         18           7
#
#    rating
# 0       4

# %%
# Transform y variable into binary
y = np.where(y > 0,1,0)

# %%
# Transform numerical variable into dummy
X = pd.get_dummies(X, drop_first=True, columns = ['occupation'])
X.head()
# Out:
#    gender   age  yearsmarried children  religiousness  education  rating  \
# 0    male  37.0         10.00       no              3         18       4
# 1  female  27.0          4.00       no              4         14       4
# 2  female  32.0         15.00      yes              1         12       4
# 3    male  57.0         15.00      yes              5         18       5
# 4    male  22.0          0.75       no              2         17       3
#
#    occupation_2  occupation_3  occupation_4  occupation_5  occupation_6  \
# 0         False         False         False         False         False
# 1         False         False         False         False          True
# 2         False         False         False         False         False
# 3         False         False         False         False          True
# 4         False         False         False         False          True
#
#    occupation_7
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False

# %%
# Transform categorical variables into dummy
X = pd.get_dummies(X, drop_first=True)
X.head()
# Out:
#     age  yearsmarried  religiousness  education  rating  occupation_2  \
# 0  37.0         10.00              3         18       4         False
# 1  27.0          4.00              4         14       4         False
# 2  32.0         15.00              1         12       4         False
# 3  57.0         15.00              5         18       5         False
# 4  22.0          0.75              2         17       3         False
#
#    occupation_3  occupation_4  occupation_5  occupation_6  occupation_7  \
# 0         False         False         False         False          True
# 1         False         False         False          True         False
# 2         False         False         False         False         False
# 3         False         False         False          True         False
# 4         False         False         False          True         False
#
#    gender_male  children_yes
# 0         True         False
# 1        False         False
# 2        False          True
# 3         True          True
# 4         True         False

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators = 10,
                               random_state = 1502)
model.fit(X, y)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=1502)

# %%
X.shape
# Out:
# (601, 13)

# %%
# Driver Importance 
importance = pd.Series(model.feature_importances_,
                       index = X.columns.values)
importance.nlargest(5).plot(kind = 'barh',
                            figsize = (12, 8))
# Out:
# <Axes: >
