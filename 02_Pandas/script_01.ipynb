# %%
import pandas as pd
import numpy as np

# %%
pd.Series([300,400,500], index=["jan", "feb", "march"])
# Out:
# jan      300
# feb      400
# march    500
# dtype: int64

# %%
dict1={"jan": 300, "feb": 400, "march":500}

# %%
var_series=pd.Series(dic1)
