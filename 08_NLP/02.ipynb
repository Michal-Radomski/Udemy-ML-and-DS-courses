# %%
import spacy
spacy.__version__
# Out:
# '3.8.11'

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 9.0 MB/s  0:00:01ta 0:00:010:00:01:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import en_core_web_sm

# %%
# !pip install goose3
# Out:
# Requirement already satisfied: goose3 in /home/michalek/miniconda3/lib/python3.13/site-packages (3.1.21)
# Requirement already satisfied: requests in /home/michalek/miniconda3/lib/python3.13/site-packages (from goose3) (2.32.5)
# Requirement already satisfied: Pillow in /home/michalek/miniconda3/lib/python3.13/site-packages (from goose3) (12.1.0)
# Requirement already satisfied: lxml in /home/michalek/miniconda3/lib/python3.13/site-packages (from goose3) (6.0.2)
# Requirement already satisfied: cssselect in /home/michalek/miniconda3/lib/python3.13/site-packages (from goose3) (1.4.0)
# Requirement already satisfied: beautifulsoup4 in /home/michalek/miniconda3/lib/python3.13/site-packages (from goose3) (4.14.2)
# Requirement already satisfied: python-dateutil in /home/michalek/miniconda3/lib/python3.13/site-packages (from goose3) (2.9.0.post0)
# Requirement already satisfied: langdetect in /home/michalek/miniconda3/lib/python3.13/site-packages (from goose3) (1.0.9)
# Requirement already satisfied: pyahocorasick in /home/michalek/miniconda3/lib/python3.13/site-packages (from goose3) (2.3.0)
# Requirement already satisfied: soupsieve>1.2 in /home/michalek/miniconda3/lib/python3.13/site-packages (from beautifulsoup4->goose3) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/michalek/miniconda3/lib/python3.13/site-packages (from beautifulsoup4->goose3) (4.15.0)
# Requirement already satisfied: six in /home/michalek/miniconda3/lib/python3.13/site-packages (from langdetect->goose3) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/michalek/miniconda3/lib/python3.13/site-packages (from requests->goose3) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/michalek/miniconda3/lib/python3.13/site-packages (from requests->goose3) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/michalek/miniconda3/lib/python3.13/site-packages (from requests->goose3) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/michalek/miniconda3/lib/python3.13/site-packages (from requests->goose3) (2026.2.25)

# %%
# import goose3, os
# print(os.path.dirname(goose3.__file__))

# %% [markdown]
# # Loading texts from the Internet

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
print(nlp.path)
# Out:
# /home/michalek/miniconda3/lib/python3.13/site-packages/en_core_web_sm/en_core_web_sm-3.8.0

# %%
from goose3 import Goose
g = Goose()
url = 'https://en.wikipedia.org/wiki/Natural_language_processing'
article = g.extract(url)

# %%
article.title
# Out:
# 'Natural language processing - Wikipedia'

# %%
article.authors
# Out:
# ['Contributors to Wikimedia projects']

# %%
article.links
# Out:
# ['/wiki/Special:EditPage/Natural_language_processing',
#  '/wiki/Talk:Natural_language_processing',
#  '/wiki/Help:Maintenance_template_removal',
#  '/wiki/File:Question_book-new.svg',
#  '/wiki/Wikipedia:Verifiability',
#  'https://www.google.com/search?as_eq=wikipedia&q=%22Natural+language+processing%22',
#  'https://www.google.com/search?tbm=nws&q=%22Natural+language+processing%22+-wikipedia&tbs=ar:1',
#  'https://www.google.com/search?&q=%22Natural+language+processing%22&tbs=bkt:s&tbm=bks',
#  'https://www.google.com/search?tbs=bks:1&q=%22Natural+language+processing%22+-wikipedia',
#  'https://scholar.google.com/scholar?q=%22Natural+language+processing%22',
#  'https://www.jstor.org/action/doBasicSearch?Query=%22Natural+language+processing%22&acc=on&wc=on',
#  '/wiki/Special:EditPage/Natural_language_processing',
#  '/wiki/Help:Referencing_for_beginners',
#  '/wiki/Help:Maintenance_template_removal',
#  '/wiki/File:Crystal_Clear_app_kedit.svg',
#  '/wiki/Talk:Natural_language_processing',
#  'https://en.wikipedia.org/w/index.php?title=Natural_language_processing&action=edit',
#  '/wiki/Wikipedia:Manual_of_Style',
#  '/wiki/Wikipedia:Manual_of_Style/Layout',
#  'https://en.wikipedia.org/w/index.php?title=Natural_language_processing&action=edit',
#  '/wiki/Help:Maintenance_template_removal',
#  '/wiki/Help:Maintenance_template_removal',
#  '/wiki/Category:Artificial_intelligence',
#  '/wiki/Artificial_intelligence',
#  '/wiki/File:Dall-e_3_(jan_%2724)_artificial_intelligence_icon.png',
#  '/wiki/Artificial_intelligence#Goals',
#  '/wiki/Artificial_general_intelligence',
#  '/wiki/Intelligent_agent',
#  '/wiki/Recursive_self-improvement',
#  '/wiki/Automated_planning_and_scheduling',
#  '/wiki/Computer_vision',
#  '/wiki/General_game_playing',
#  '/wiki/Knowledge_representation_and_reasoning',
#  '/wiki/Robotics',
#  '/wiki/AI_safety',
#  '/wiki/Machine_learning',
#  '/wiki/Symbolic_artificial_intelligence',
#  '/wiki/Deep_learning',
#  '/wiki/Bayesian_network',
#  '/wiki/Evolutionary_algorithm',
#  '/wiki/Hybrid_intelligent_system',
#  '/wiki/Artificial_intelligence_systems_integration',
#  '/wiki/Open-source_artificial_intelligence',
#  '/wiki/AI_data_center',
#  '/wiki/Applications_of_artificial_intelligence',
#  '/wiki/Machine_learning_in_bioinformatics',
#  '/wiki/Deepfake',
#  '/wiki/Machine_learning_in_earth_sciences',
#  '/wiki/Applications_of_artificial_intelligence#Finance',
#  '/wiki/Generative_artificial_intelligence',
#  '/wiki/Artificial_intelligence_art',
#  '/wiki/Generative_audio',
#  '/wiki/Music_and_artificial_intelligence',
#  '/wiki/Artificial_intelligence_in_government',
#  '/wiki/Artificial_intelligence_in_healthcare',
#  '/wiki/Artificial_intelligence_in_mental_health',
#  '/wiki/Artificial_intelligence_in_industry',
#  '/wiki/AI-assisted_software_development',
#  '/wiki/Machine_translation',
#  '/wiki/Artificial_intelligence_arms_race',
#  '/wiki/Machine_learning_in_physics',
#  '/wiki/List_of_artificial_intelligence_projects',
#  '/wiki/Philosophy_of_artificial_intelligence',
#  '/wiki/AI_alignment',
#  '/wiki/Artificial_consciousness',
#  '/wiki/Bitter_lesson',
#  '/wiki/Chinese_room',
#  '/wiki/Friendly_artificial_intelligence',
#  '/wiki/Ethics_of_artificial_intelligence',
#  '/wiki/Existential_risk_from_artificial_general_intelligence',
#  '/wiki/Turing_test',
#  '/wiki/Uncanny_valley',
#  '/wiki/Human%E2%80%93AI_interaction',
#  '/wiki/History_of_artificial_intelligence',
#  '/wiki/Timeline_of_artificial_intelligence',
#  '/wiki/Progress_in_artificial_intelligence',
#  '/wiki/AI_winter',
#  '/wiki/AI_boom',
#  '/wiki/AI_bubble',
#  '/wiki/Artificial_intelligence_controversies',
#  '/wiki/Deepfake_pornography',
#  '/wiki/Taylor_Swift_deepfake_pornography_controversy',
#  '/wiki/Grok_sexual_deepfake_scandal',
#  '/wiki/Google_Gemini_image_generation_controversy',
#  '/wiki/Pause_Giant_AI_Experiments:_An_Open_Letter',
#  '/wiki/Removal_of_Sam_Altman_from_OpenAI',
#  '/wiki/Statement_on_AI_Risk',
#  '/wiki/Tay_(chatbot)',
#  '/wiki/Th%C3%A9%C3%A2tre_D%27op%C3%A9ra_Spatial',
#  '/wiki/Voiceverse_NFT_plagiarism_scandal',
#  '/wiki/Glossary_of_artificial_intelligence',
#  '/wiki/Natural_language',
#  '/wiki/Computer',
#  '/wiki/Computer_science',
#  '/wiki/Artificial_intelligence',
#  '/wiki/Information_retrieval',
#  '/wiki/Knowledge_representation_and_reasoning',
#  '/wiki/Computational_linguistics',
#  '/wiki/Linguistics',
#  '#cite_note-nlpintro-1',
#  '/wiki/Speech_recognition',
#  '/wiki/Text_classification',
#  '/wiki/Natural_language_understanding',
#  '/wiki/Natural_language_generation',
#  '/w/index.php?title=Natural_language_processing&action=edit&section=1',
#  '/wiki/History_of_natural_language_processing',
#  '#cite_note-2',
#  '/wiki/Alan_Turing',
#  '/wiki/Computing_Machinery_and_Intelligence',
#  '/wiki/Turing_test',
#  '/w/index.php?title=Natural_language_processing&action=edit&section=2',
#  '/wiki/File:AST_Document.svg',
#  '/wiki/John_Searle_(American_philosopher)',
#  '/wiki/Georgetown-IBM_experiment',
#  '/wiki/Automatic_translation',
#  '#cite_note-3',
#  '/wiki/ALPAC',
#  '#cite_note-4',
#  '/wiki/Statistical_machine_translation',
#  '/wiki/SHRDLU',
#  '/wiki/Blocks_world',
#  '/wiki/ELIZA',
#  '/wiki/Rogerian_psychotherapy',
#  '/wiki/Joseph_Weizenbaum',
#  '#cite_note-5',
#  '/wiki/Ontology_(information_science)',
#  '/wiki/Chatterbots',
#  '/wiki/PARRY',
#  '/wiki/Head-driven_phrase_structure_grammar',
#  '/wiki/Generative_grammar',
#  '#cite_note-6',
#  '/wiki/Lesk_algorithm',
#  '#cite_note-7',
#  '/wiki/Rhetorical_structure_theory',
#  '/wiki/Racter',
#  '/wiki/Jabberwacky',
#  '#cite_note-8',
#  '/w/index.php?title=Natural_language_processing&action=edit&section=3',
#  '/wiki/Machine_learning',
#  '/wiki/Moore%27s_law',
#  '/wiki/Chomskyan',
#  '/wiki/Transformational_grammar',
#  '/wiki/Corpus_linguistics',
#  '#cite_note-9',
#  '/wiki/Machine_translation',
#  '/wiki/IBM_alignment_models',
#  '/wiki/Text_corpus',
#  '/wiki/Parliament_of_Canada',
#  '/wiki/European_Union',
#  '/wiki/Unsupervised_learning',
#  '/wiki/Semi-supervised_learning',
#  '/wiki/Supervised_learning',
#  '/wiki/World_Wide_Web',
#  '/wiki/Time_complexity',
#  '/wiki/Word_n-gram_language_model',
#  '/wiki/Multi-layer_perceptron',
#  '/wiki/Yoshua_Bengio',
#  '#cite_note-10',
#  '/wiki/Tom%C3%A1%C5%A1_Mikolov',
#  '/wiki/Brno_University_of_Technology',
#  '/wiki/Recurrent_neural_network',
#  '#cite_note-11',
#  '/wiki/Word2vec',
#  '/wiki/Representation_learning',
#  '/wiki/Deep_learning',
#  '#cite_note-goldberg:nnlp17-12',
#  '#cite_note-goodfellow:book16-13',
#  '/wiki/Language_modeling',
#  '#cite_note-jozefowicz:lm16-14',
#  '#cite_note-choe:emnlp16-15',
#  '#cite_note-vinyals:nips15-16',
#  '/wiki/Artificial_intelligence_in_healthcare',
#  '/wiki/Electronic_health_record',
#  '#cite_note-17',
#  '#cite_note-18',
#  '/w/index.php?title=Natural_language_processing&action=edit&section=4',
#  '#cite_note-winograd:shrdlu71-19',
#  '#cite_note-schank77-20',
#  '/wiki/Stemming',
#  '/wiki/Machine_learning',
#  '/wiki/Language_model',
#  '/wiki/Intractable_problem',
#  '/wiki/Apertium',
#  '/wiki/Tokenization_(lexical_analysis)',
#  '/wiki/Knowledge_extraction',
#  '/w/index.php?title=Natural_language_processing&action=edit&section=5',
#  '/wiki/AI_winter',
#  '#cite_note-johnson:eacl:ilcl09-21',
#  '#cite_note-resnik:langlog11-22',
#  '/wiki/Decision_tree',
#  '/wiki/Conditional_(computer_programming)#If–then(–else)',
#  '/wiki/Markov_model',
#  '/w/index.php?title=Natural_language_processing&action=edit&section=6',
#  '/wiki/Artificial_neural_network',
#  '/wiki/Feature_engineering',
#  '#cite_note-23',
#  '/wiki/Neural_network_(machine_learning)',
#  '/wiki/Semantic_networks',
#  '#cite_note-24',
#  '/wiki/Word_embedding',
#  '/wiki/Neural_machine_translation',
#  '/wiki/Seq2seq',
#  '/wiki/Statistical_machine_translation',
#  '/w/index.php?title=Natural_language_processing&action=edit&section=7',
#  '/w/index.php?title=Natural_language_processing&action=edit&section=8',
#  '/wiki/File:Hebrew_stop_words_word_cloud.png',
#  '/wiki/Optical_character_recognition',
#  '/wiki/Speech_recognition',
#  '/wiki/Text_to_speech',
#  '/wiki/AI-complete',
#  '/wiki/Natural_speech',
#  '/wiki/Speech_segmentation',
#  '/wiki/Coarticulation',
#  '/wiki/Analog_signal',
#  '/wiki/Speech_segmentation',
#  '/wiki/Speech_recognition',
#  '/wiki/Text-to-speech',
#  '#cite_note-25',
#  '/wiki/Word_segmentation',
#  '/wiki/Tokenization_(lexical_analysis)',
#  '/wiki/Tokenization_(data_security)',
#  '#cite_note-:0-26',
#  '/wiki/English_language',
#  '/wiki/Chinese_language',
#  '/wiki/Japanese_language',
#  '/wiki/Thai_language',
#  '/wiki/Vocabulary',
#  '/wiki/Morphology_(linguistics)',
#  '/wiki/Bag_of_words',
#  '#cite_note-27',
#  '#cite_note-28',
#  '/w/index.php?title=Natural_language_processing&action=edit&section=9',
#  '/wiki/File:Eustagger_euskal_lematizatzailearen_adibidea.png',
#  '/wiki/Lemmatisation',
#  '#cite_note-29',
#  '/wiki/Morphology_(linguistics)',
#  '/wiki/Morpheme',
#  '/wiki/Morphology_(linguistics)',
#  '/wiki/English_language',
#  '/wiki/Inflectional_morphology',
#  '/wiki/Turkish_language',
#  '/wiki/Meitei_language',
#  '/wiki/Agglutination',
#  '#cite_note-30',
#  '/wiki/Part-of-speech_tagging',
#  '/wiki/Part_of_speech',
#  '/wiki/Noun',
#  '/wiki/Verb',
#  '/wiki/Adjective',
#  '/wiki/Stemming',
#  '/w/index.php?title=Natural_language_processing&action=edit&section=10',
#  '/wiki/Category:Formal_languages',
#  '/wiki/Formal_languages',
#  '/wiki/Formal_system',
#  '/wiki/Alphabet_(formal_languages)',
#  '/wiki/Syntax_(logic)',
#  '/wiki/Semantics_of_logic',
#  '/wiki/Semantics_(computer_science)',
#  '/wiki/Formal_grammar',
#  '/wiki/Formation_rule',
#  '/wiki/Well-formed_formula',
#  '/wiki/Automata_theory',
#  '/wiki/Regular_expression',
#  '/wiki/Production_(computer_science)',
#  '/wiki/Ground_expression',
#  '/wiki/Atomic_formula',
#  '/wiki/Formal_methods',
#  '/wiki/Propositional_calculus',
#  '/wiki/Predicate_logic',
#  '/wiki/Mathematical_notation',
#  '/wiki/Programming_language_theory',
#  '/wiki/Mathematical_linguistics',
#  '/wiki/Computational_linguistics',
#  '/wiki/Syntax_analysis',
#  '/wiki/Formal_verification',
#  '/wiki/Automated_theorem_proving',
#  '/wiki/Grammar_induction',
#  '#cite_note-31',
#  '/wiki/Formal_grammar',
#  '/wiki/Sentence_breaking',
#  '/wiki/Sentence_boundary_disambiguation',
#  '/wiki/Full_stop',
#  '/wiki/Punctuation_mark',
#  '/wiki/Abbreviation',
#  '/wiki/Parsing',
#  '/wiki/Parse_tree',
#  '/wiki/Grammar',
#  '/wiki/Natural_language',
#  '/wiki/Ambiguous',
#  '/wiki/Probabilistic_context-free_grammar',
#  '/wiki/Stochastic_grammar',
#  '/w/index.php?title=Natural_language_processing&action=edit&section=11',
#  '/wiki/File:Entity_Linking_-_Example_of_pipeline.png',
#  '/wiki/Lexical_semantics',
#  '/wiki/Distributional_semantics',
#  '/wiki/Named_entity_recognition',
#  '/wiki/Capitalization',
#  '/wiki/Named_entity',
#  '/wiki/Chinese_language',
#  '/wiki/Arabic_language',
#  '/wiki/German_language',
#  '/wiki/Noun',
#  '/wiki/French_language',
#  '/wiki/Spanish_language',
#  '/wiki/Adjective',
#  '#cite_note-32',
#  '/wiki/Sentiment_analysis',
#  '/wiki/Multimodal_sentiment_analysis',
#  '/wiki/Word_n-gram_language_model',
#  '/wiki/Term_frequency-inverse_document_frequency',
#  '/wiki/Deep_learning',
#  '#cite_note-:0-26',
#  '/wiki/Terminology_extraction',
#  '/wiki/Word-sense_disambiguation',
#  '/wiki/Meaning_(linguistics)',
#  '/wiki/WordNet',
#  '/wiki/Entity_linking',
#  '/wiki/Named_entity',
#  '/w/index.php?title=Natural_language_processing&action=edit&section=12',
#  '/wiki/Relationship_extraction',
#  '/wiki/Semantic_parsing',
#  '/wiki/Abstract_Meaning_Representation',
#  '/wiki/Discourse_representation_theory',
#  '#Natural_language_understanding',
#  '/wiki/Semantic_role_labeling',
#  '/wiki/Frame_semantics_(linguistics)',
#  '/wiki/Semantic_roles',
#  '/w/index.php?title=Natural_language_processing&action=edit&section=13',
#  '/wiki/Coreference',
#  '/wiki/Anaphora_resolution',
#  '/wiki/Pronoun',
#  '/wiki/Referring_expression',
#  '/wiki/Discourse_analysis',
#  '/wiki/Discourse',
#  '/wiki/Speech_act',
#  '/wiki/Frame_semantics_(linguistics)',
#  '#Semantic_role_labelling',
#  '/wiki/Pro-drop_language',
#  '/wiki/Textual_entailment',
#  '#cite_note-rte:11-33',
#  '/wiki/Topic_segmentation',
#  '/wiki/Argument_mining',
#  '/wiki/Natural_language',
#  '#cite_note-34',
#  '/wiki/Argument_scheme',
#  '#cite_note-35',
#  '#cite_note-36',
#  '/w/index.php?title=Natural_language_processing&action=edit&section=14',
#  '/wiki/File:Use_of_Firefox%27_%27Translate_selection_to_English%27_machine_translation_on_Commons_talk_meta_pages_02.png',
#  '/wiki/Automatic_summarization',
#  '#cite_note-37',
#  '#cite_note-38',
#  '#cite_note-39',
#  '/wiki/GPT-2',
#  '/wiki/Logic_translation',
#  '/wiki/Machine_translation',
#  '/wiki/AI-complete',
#  '/wiki/Natural_language_understanding',
#  '/wiki/First-order_logic',
#  '/wiki/Computer',
#  '/wiki/Closed-world_assumption',
#  '/wiki/Open-world_assumption',
#  '#cite_note-40',
#  '/wiki/Natural_language_generation',
#  '#cite_note-41',
#  '/wiki/1_the_Road',
#  '/wiki/Language_model',
#  '#cite_note-42',
#  '/wiki/Document_AI',
#  '#cite_note-43',
#  '/wiki/Dialogue_system',
#  '/wiki/Question_answering',
#  '/wiki/Text-to-image_generation',
#  '#cite_note-44',
#  '/wiki/3D_model',
#  '#cite_note-45',
#  '#cite_note-46',
#  '/wiki/Text-to-video_model',
#  '#cite_note-47',
#  '#cite_note-48',
#  '/w/index.php?title=Natural_language_processing&action=edit&section=15',
#  '#cite_note-49',
#  '/w/index.php?title=Natural_language_processing&action=edit&section=16',
#  '/wiki/Cognition',
#  '#cite_note-50',
#  '/wiki/Cognitive_science',
#  '#cite_note-51',
#  '/wiki/Cognitive_linguistics',
#  '#cite_note-52',
#  '#Symbolic_NLP_(1950s_–_early_1990s)',
#  '/wiki/George_Lakoff',
#  '#cite_note-53',
#  '/wiki/Conceptual_metaphor',
#  '#cite_note-54',
#  '/wiki/Probabilistic_context-free_grammar',
#  'https://worldwide.espacenet.com/patent/search/family/055314712/publication/US9269353B1?q=pn%3DUS9269353',
#  '#cite_note-55',
#  '#cite_note-56',
#  '#cite_note-57',
#  '#cite_note-58',
#  '/wiki/ACT-R',
#  '#cite_note-59',
#  '/wiki/Association_for_Computational_Linguistics',
#  '/wiki/Explainable_artificial_intelligence',
#  '#cite_note-60',
#  '/wiki/Multimodal_interaction',
#  '#cite_note-61',
#  '/wiki/Artificial_intelligence',
#  '/wiki/Large_language_model',
#  '#cite_note-62',
#  '/wiki/Artificial_general_intelligence',
#  '/wiki/Free_energy_principle',
#  '#cite_note-63',
#  '/wiki/Karl_J._Friston',
#  '/w/index.php?title=Natural_language_processing&action=edit&section=17',
#  '/wiki/1_the_Road',
#  '/wiki/Artificial_intelligence_detection_software',
#  '/wiki/Automated_essay_scoring',
#  '/wiki/Biomedical_text_mining',
#  '/wiki/Compound_term_processing',
#  '/wiki/Computational_linguistics',
#  '/wiki/Computer-assisted_reviewing',
#  '/wiki/Controlled_natural_language',
#  '/wiki/Deep_learning',
#  '/wiki/Deep_linguistic_processing',
#  '/wiki/Distributional_semantics',
#  '/wiki/Foreign_language_reading_aid',
#  '/wiki/Foreign_language_writing_aid',
#  '/wiki/Information_extraction',
#  '/wiki/Information_retrieval',
#  '/wiki/Language_and_Communication_Technologies',
#  '/wiki/Language_model',
#  '/wiki/Language_technology',
#  '/wiki/Latent_semantic_indexing',
#  '/wiki/Multi-agent_system',
#  '/wiki/Native-language_identification',
#  '/wiki/Natural-language_programming',
#  '/wiki/Natural-language_understanding',
#  '/wiki/Natural-language_user_interface',
#  '/wiki/Outline_of_natural_language_processing',
#  '/wiki/Query_expansion',
#  '/wiki/Query_understanding',
#  '/wiki/Reification_(linguistics)',
#  '/wiki/Speech_processing',
#  '/wiki/Spoken_dialogue_systems',
#  '/wiki/Text-proofing',
#  '/wiki/Text_simplification',
#  '/wiki/Transformer_(machine_learning_model)',
#  '/wiki/Truecasing',
#  '/wiki/Question_answering',
#  '/wiki/Word2vec',
#  '/w/index.php?title=Natural_language_processing&action=edit&section=18',
#  '#cite_ref-nlpintro_1-0',
#  'https://mitpress.mit.edu/9780262042840/introduction-to-natural-language-processing/',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-0-262-04284-0',
#  '#cite_ref-2',
#  'https://cs.stanford.edu/people/eroberts/courses/soco/projects/2004-05/nlp/overview_history.html',
#  '#cite_ref-3',
#  'https://web.archive.org/web/20190713103044/http://www.hutchinsweb.me.uk/Nutshell-2005.pdf',
#  'http://www.hutchinsweb.me.uk/Nutshell-2005.pdf',
#  '/wiki/Wikipedia:Verifiability#Self-published_sources',
#  '#cite_ref-4',
#  '#cite_ref-5',
#  '/wiki/Category:Harv_and_Sfn_template_errors',
#  '/wiki/Category:Harv_and_Sfn_template_errors',
#  '#CITEREFCrevier1993',
#  '#CITEREFBuchanan2005',
#  '#cite_ref-6',
#  '/wiki/Kimmo_Koskenniemi',
#  'https://web.archive.org/web/20181221032913/http://www.ling.helsinki.fi/~koskenni/doc/Two-LevelMorphology.pdf',
#  '/wiki/University_of_Helsinki',
#  'http://www.ling.helsinki.fi/~koskenni/doc/Two-LevelMorphology.pdf',
#  '#cite_ref-7',
#  'https://www.ijcai.org/Proceedings/81-1/Papers/071.pdf',
#  '#cite_ref-8',
#  '/wiki/Bibcode_(identifier)',
#  'https://ui.adsabs.harvard.edu/abs/1986IEEEP..74.1026G',
#  '/wiki/Doi_(identifier)',
#  'https://doi.org/10.1109%2FPROC.1986.13580',
#  '/wiki/ISSN_(identifier)',
#  'https://search.worldcat.org/issn/1558-2256',
#  '/wiki/S2CID_(identifier)',
#  'https://api.semanticscholar.org/CorpusID:30688575',
#  '#cite_ref-9',
#  '/wiki/Corner_case',
#  '/wiki/Pathological_(mathematics)',
#  '/wiki/Thought_experiment',
#  '/wiki/Corpus_linguistics',
#  '/wiki/Text_corpus',
#  '/wiki/Poverty_of_the_stimulus',
#  '#cite_ref-10',
#  'https://dl.acm.org/doi/10.5555/944919.944966',
#  '#cite_ref-11',
#  'https://gwern.net/doc/ai/nn/rnn/2010-mikolov.pdf',
#  '/wiki/Doi_(identifier)',
#  'https://doi.org/10.21437%2FInterspeech.2010-343',
#  '/wiki/S2CID_(identifier)',
#  'https://api.semanticscholar.org/CorpusID:17048224',
#  '#cite_ref-goldberg:nnlp17_12-0',
#  'https://doi.org/10.1613%2Fjair.4992',
#  '/wiki/ArXiv_(identifier)',
#  'https://arxiv.org/abs/1807.10854',
#  '/wiki/Doi_(identifier)',
#  'https://doi.org/10.1613%2Fjair.4992',
#  '/wiki/S2CID_(identifier)',
#  'https://api.semanticscholar.org/CorpusID:8273530',
#  '#cite_ref-goodfellow:book16_13-0',
#  'http://www.deeplearningbook.org/',
#  '#cite_ref-jozefowicz:lm16_14-0',
#  '/wiki/ArXiv_(identifier)',
#  'https://arxiv.org/abs/1602.02410',
#  '/wiki/Bibcode_(identifier)',
#  'https://ui.adsabs.harvard.edu/abs/2016arXiv160202410J',
#  '#cite_ref-choe:emnlp16_15-0',
#  'https://web.archive.org/web/20181023034804/https://aclanthology.coli.uni-saarland.de/papers/D16-1257/d16-1257',
#  'https://aclanthology.coli.uni-saarland.de/papers/D16-1257/d16-1257',
#  '#cite_ref-vinyals:nips15_16-0',
#  'https://papers.nips.cc/paper/5635-grammar-as-a-foreign-language.pdf',
#  '/wiki/ArXiv_(identifier)',
#  'https://arxiv.org/abs/1412.7449',
#  '/wiki/Bibcode_(identifier)',
#  'https://ui.adsabs.harvard.edu/abs/2014arXiv1412.7449V',
#  '#cite_ref-17',
#  'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8120048',
#  '/wiki/Doi_(identifier)',
#  'https://doi.org/10.1177%2F19322968211000831',
#  '/wiki/ISSN_(identifier)',
#  'https://search.worldcat.org/issn/1932-2968',
#  '/wiki/PMC_(identifier)',
#  'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8120048',
#  '/wiki/PMID_(identifier)',
#  'https://pubmed.ncbi.nlm.nih.gov/33736486',
#  '#cite_ref-18',
#  'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9233261',
#  '/wiki/Doi_(identifier)',
#  'https://doi.org/10.2196%2F38482',
#  '/wiki/ISSN_(identifier)',
#  'https://search.worldcat.org/issn/2291-9694',
#  '/wiki/PMC_(identifier)',
#  'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9233261',
#  '/wiki/PMID_(identifier)',
#  'https://pubmed.ncbi.nlm.nih.gov/35687381',
#  '#cite_ref-winograd:shrdlu71_19-0',
#  'http://hci.stanford.edu/winograd/shrdlu/',
#  '#cite_ref-schank77_20-0',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/0-470-99033-3',
#  '#cite_ref-johnson:eacl:ilcl09_21-0',
#  'http://www.aclweb.org/anthology/W09-0103',
#  '#cite_ref-resnik:langlog11_22-0',
#  'http://languagelog.ldc.upenn.edu/nll/?p=2946',
#  '#cite_ref-23',
#  'https://web.archive.org/web/20210414054126/https://www.socher.org/index.php/Main/DeepLearningForNLP-ACL2012Tutorial',
#  'https://www.socher.org/index.php/Main/DeepLearningForNLP-ACL2012Tutorial',
#  'http://web.stanford.edu/class/cs224n/',
#  '#cite_ref-24',
#  'https://www.routledge.com/Semantic-Network-Analysis-in-Social-Sciences/Segev/p/book/9780367636524',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-0-367-63652-4',
#  'https://web.archive.org/web/20211205140726/https://www.routledge.com/Semantic-Network-Analysis-in-Social-Sciences/Segev/p/book/9780367636524',
#  '#cite_ref-25',
#  '/wiki/Yingli_Tian',
#  '/wiki/CiteSeerX_(identifier)',
#  'https://citeseerx.ist.psu.edu/viewdoc/summary?doi=10.1.1.668.869',
#  '/wiki/Doi_(identifier)',
#  'https://doi.org/10.1007%2F978-3-642-29364-1_2',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-3-642-29363-4',
#  '#cite_ref-:0_26-0',
#  '#cite_ref-:0_26-1',
#  'https://www.deeplearning.ai/resources/natural-language-processing/',
#  '#cite_ref-27',
#  'https://www.geeksforgeeks.org/nlp/tokenization-in-natural-language-processing-nlp/',
#  '#cite_ref-28',
#  'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC12391535',
#  '/wiki/Doi_(identifier)',
#  'https://doi.org/10.1038%2Fs41598-025-14699-1',
#  '/wiki/PMC_(identifier)',
#  'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC12391535',
#  '#cite_ref-29',
#  'https://www.gyansetu.in/what-is-natural-language-processing/',
#  '#cite_ref-30',
#  'http://aclweb.org/anthology//W/W12/W12-5008.pdf',
#  '#cite_ref-31',
#  'http://papers.nips.cc/paper/1945-natural-language-grammar-induction-using-a-constituent-context-model.pdf',
#  '#cite_ref-32',
#  'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9972634',
#  '/wiki/Doi_(identifier)',
#  'https://doi.org/10.1186%2Fs12967-023-04011-y',
#  '/wiki/PMC_(identifier)',
#  'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9972634',
#  '/wiki/PMID_(identifier)',
#  'https://pubmed.ncbi.nlm.nih.gov/36855134',
#  '#cite_ref-rte:11_33-0',
#  'https://tac.nist.gov//2011/RTE/',
#  '#cite_ref-34',
#  'https://dl.acm.org/doi/10.1145/2850417',
#  '/wiki/Doi_(identifier)',
#  'https://doi.org/10.1145%2F2850417',
#  '/wiki/Hdl_(identifier)',
#  'https://hdl.handle.net/11585%2F523460',
#  '/wiki/ISSN_(identifier)',
#  'https://search.worldcat.org/issn/1533-5399',
#  '/wiki/S2CID_(identifier)',
#  'https://api.semanticscholar.org/CorpusID:9561587',
#  '#cite_ref-35',
#  'https://web.archive.org/web/20210418083659/https://www.i3s.unice.fr/~villata/tutorialIJCAI2016.html',
#  'https://www.i3s.unice.fr/~villata/tutorialIJCAI2016.html',
#  '#cite_ref-36',
#  'http://acl2016tutorial.arg.tech/',
#  '#cite_ref-37',
#  'https://www.mq.edu.au/research/research-centres-groups-and-facilities/innovative-technologies/centres/centre-for-language-technology-clt',
#  '#cite_ref-38',
#  'https://www.comp.nus.edu.sg/~nlp/conll13st.html',
#  '#cite_ref-39',
#  'https://www.comp.nus.edu.sg/~nlp/conll14st.html',
#  '#cite_ref-40',
#  'https://web.archive.org/web/20111009135952/http://www.ijimt.org/abstract/100-E00187.htm',
#  'http://www.ijimt.org/abstract/100-E00187.htm',
#  '#cite_ref-41',
#  'http://www.ubu.com/historical/racter/index.html',
#  '#cite_ref-42',
#  '/wiki/Doi_(identifier)',
#  'https://doi.org/10.1007%2F978-3-030-16800-1',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-3-030-16799-8',
#  '/wiki/S2CID_(identifier)',
#  'https://api.semanticscholar.org/CorpusID:155818532',
#  '#cite_ref-43',
#  'https://ghostarchive.org/varchive/youtube/20211030/7dtl650D0y0',
#  'https://www.youtube.com/watch?v=7dtl650D0y0',
#  '#cite_ref-44',
#  'https://www.theverge.com/2022/4/6/23012123/openai-clip-dalle-2-ai-text-to-image-generator-testing',
#  '#cite_ref-45',
#  'https://nlp.stanford.edu/projects/text2scene.shtml',
#  '#cite_ref-46',
#  'https://doi.org/10.1145/383259.383316',
#  '/wiki/Doi_(identifier)',
#  'https://doi.org/10.1145%2F383259.383316',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-1-58113-374-5',
#  '/wiki/S2CID_(identifier)',
#  'https://api.semanticscholar.org/CorpusID:3842372',
#  '#cite_ref-47',
#  'https://venturebeat.com/ai/google-announces-ai-advances-in-text-to-video-language-translation-more/',
#  '#cite_ref-48',
#  'https://www.theverge.com/2022/9/29/23378210/meta-text-to-video-ai-generation-make-a-video-model-dall-e',
#  '#cite_ref-49',
#  'https://www.conll.org/previous-tasks',
#  '#cite_ref-50',
#  'https://web.archive.org/web/20200715113427/https://www.lexico.com/definition/cognition',
#  '/wiki/Oxford_University_Press',
#  '/wiki/Dictionary.com',
#  'https://www.lexico.com/definition/cognition',
#  '#cite_ref-51',
#  'http://www.aft.org/newspubs/periodicals/ae/summer2002/willingham.cfm',
#  '#cite_ref-52',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-0-805-85352-0',
#  '#cite_ref-53',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-0-465-05674-3',
#  '#cite_ref-54',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-0-521-59541-4',
#  '#cite_ref-55',
#  'https://worldwide.espacenet.com/textdoc?DB=EPODOC&IDX=US9269353',
#  '#cite_ref-56',
#  'https://universalconceptualcognitiveannotation.github.io/',
#  '#cite_ref-57',
#  'https://www.redalyc.org/pdf/1345/134549291020.pdf',
#  '#cite_ref-58',
#  'https://www.fcg-net.org/',
#  '#cite_ref-59',
#  'https://www.aclweb.org/portal/',
#  '#cite_ref-60',
#  'https://www.w3.org/Data/demos/chunks/chunks.html',
#  '#cite_ref-61',
#  'https://doi.org/10.1162%2Ftacl_a_00177',
#  '/wiki/Doi_(identifier)',
#  'https://doi.org/10.1162%2Ftacl_a_00177',
#  '/wiki/S2CID_(identifier)',
#  'https://api.semanticscholar.org/CorpusID:2317858',
#  '#cite_ref-62',
#  '/wiki/ArXiv_(identifier)',
#  'https://arxiv.org/abs/2207.07051',
#  'https://arxiv.org/archive/cs.CL',
#  '#cite_ref-63',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-0-262-36997-8',
#  '/w/index.php?title=Natural_language_processing&action=edit&section=19',
#  'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC40721',
#  '/wiki/Bibcode_(identifier)',
#  'https://ui.adsabs.harvard.edu/abs/1995PNAS...92.9977B',
#  '/wiki/Doi_(identifier)',
#  'https://doi.org/10.1073%2Fpnas.92.22.9977',
#  '/wiki/PMC_(identifier)',
#  'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC40721',
#  '/wiki/PMID_(identifier)',
#  'https://pubmed.ncbi.nlm.nih.gov/7479812',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-0-596-51649-9',
#  '/w/index.php?title=Kenna_Hughes-Castleberry&action=edit&redlink=1',
#  '/wiki/Cain%27s_Jawbone',
#  '/wiki/Scientific_American',
#  '/wiki/Natural-language_processing',
#  '/wiki/Context_(linguistics)',
#  '/wiki/Ancient_language',
#  '/wiki/Civilization',
#  '/wiki/Training_data',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-0-13-187321-6',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-1848218482',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-1848219212',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-0-521-86571-5',
#  'http://nlp.stanford.edu/IR-book/',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-0-262-13360-9',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-0-387-19557-5',
#  '/w/index.php?title=Natural_language_processing&action=edit&section=20',
#  '/wiki/File:Commons-logo.svg',
#  'https://commons.wikimedia.org/wiki/Category:Natural_language_processing',
#  '/wiki/AI-complete',
#  '/wiki/Bag-of-words_model',
#  '/wiki/N-gram',
#  '/wiki/Bigram',
#  '/wiki/Trigram',
#  '/wiki/Computational_linguistics',
#  '/wiki/Natural_language_understanding',
#  '/wiki/Stop_word',
#  '/wiki/Text_processing',
#  '/wiki/Text_mining',
#  '/wiki/Argument_mining',
#  '/wiki/Collocation_extraction',
#  '/wiki/Concept_mining',
#  '/wiki/Coreference#Coreference_resolution',
#  '/wiki/Deep_linguistic_processing',
#  '/wiki/Distant_reading',
#  '/wiki/Information_extraction',
#  '/wiki/Named-entity_recognition',
#  '/wiki/Ontology_learning',
#  '/wiki/Parsing',
#  '/wiki/Semantic_parsing',
#  '/wiki/Syntactic_parsing_(computational_linguistics)',
#  '/wiki/Part-of-speech_tagging',
#  '/wiki/Semantic_analysis_(machine_learning)',
#  '/wiki/Semantic_role_labeling',
#  '/wiki/Semantic_decomposition_(natural_language_processing)',
#  '/wiki/Semantic_similarity',
#  '/wiki/Sentiment_analysis',
#  '/wiki/Terminology_extraction',
#  '/wiki/Text_mining',
#  '/wiki/Textual_entailment',
#  '/wiki/Truecasing',
#  '/wiki/Word-sense_disambiguation',
#  '/wiki/Word-sense_induction',
#  '/wiki/Text_segmentation',
#  '/wiki/Compound-term_processing',
#  '/wiki/Lemmatisation',
#  '/wiki/Lexical_analysis',
#  '/wiki/Shallow_parsing',
#  '/wiki/Stemming',
#  '/wiki/Sentence_boundary_disambiguation',
#  '/wiki/Word#Word_boundaries',
#  '/wiki/Automatic_summarization',
#  '/wiki/Multi-document_summarization',
#  '/wiki/Sentence_extraction',
#  '/wiki/Text_simplification',
#  '/wiki/Machine_translation',
#  '/wiki/Computer-assisted_translation',
#  '/wiki/Example-based_machine_translation',
#  '/wiki/Rule-based_machine_translation',
#  '/wiki/Statistical_machine_translation',
#  '/wiki/Transfer-based_machine_translation',
#  '/wiki/Neural_machine_translation',
#  '/wiki/Distributional_semantics',
#  '/wiki/BERT_(language_model)',
#  '/wiki/Document-term_matrix',
#  '/wiki/Explicit_semantic_analysis',
#  '/wiki/FastText',
#  '/wiki/GloVe',
#  '/wiki/Language_model',
#  '/wiki/Large_language_model',
#  '/wiki/Small_language_model',
#  '/wiki/Latent_semantic_analysis',
#  '/wiki/Long_short-term_memory',
#  '/wiki/Seq2seq',
#  '/wiki/Transformer_(deep_learning_architecture)',
#  '/wiki/Word_embedding',
#  '/wiki/Word2vec',
#  '/wiki/Language_resource',
#  '/wiki/Corpus_linguistics',
#  '/wiki/Lexical_resource',
#  '/wiki/Linguistic_Linked_Open_Data',
#  '/wiki/Machine-readable_dictionary',
#  '/wiki/Parallel_text',
#  '/wiki/PropBank',
#  '/wiki/Semantic_network',
#  '/wiki/Simple_Knowledge_Organization_System',
#  '/wiki/Speech_corpus',
#  '/wiki/Text_corpus',
#  '/wiki/Thesaurus_(information_retrieval)',
#  '/wiki/Treebank',
#  '/wiki/Universal_Dependencies',
#  '/wiki/BabelNet',
#  '/wiki/Bank_of_English',
#  '/wiki/DBpedia',
#  '/wiki/FrameNet',
#  '/wiki/Google_Ngram_Viewer',
#  '/wiki/UBY',
#  '/wiki/WordNet',
#  '/wiki/Wikidata',
#  '/wiki/Automatic_identification_and_data_capture',
#  '/wiki/Speech_recognition',
#  '/wiki/Speech_segmentation',
#  '/wiki/Speech_synthesis',
#  '/wiki/Natural_language_generation',
#  '/wiki/Optical_character_recognition',
#  '/wiki/Topic_model',
#  '/wiki/Document_classification',
#  '/wiki/Latent_Dirichlet_allocation',
#  '/wiki/Pachinko_allocation',
#  '/wiki/Computer-assisted_reviewing',
#  '/wiki/Automated_essay_scoring',
#  '/wiki/Concordancer',
#  '/wiki/Grammar_checker',
#  '/wiki/Predictive_text',
#  '/wiki/Pronunciation_assessment',
#  '/wiki/Spell_checker',
#  '/wiki/Natural-language_user_interface',
#  '/wiki/Chatbot',
#  '/wiki/Interactive_fiction',
#  '/wiki/Question_answering',
#  '/wiki/Virtual_assistant',
#  '/wiki/Voice_user_interface',
#  '/wiki/Formal_semantics_(natural_language)',
#  '/wiki/Hallucination_(artificial_intelligence)',
#  '/wiki/Natural_Language_Toolkit',
#  '/wiki/SpaCy',
#  '/wiki/Wikipedia:Contents/Portals',
#  '/wiki/File:Globe_of_letters.svg',
#  '/wiki/Portal:Language',
#  '/wiki/Help:Authority_control',
#  'https://www.wikidata.org/wiki/Q30642#identifiers',
#  'https://id.loc.gov/authorities/sh88002425',
#  'https://id.ndl.go.jp/auth/ndlna/00562347',
#  'https://www.nli.org.il/en/authorities/987007536703305171',
#  'https://lux.collections.yale.edu/view/concept/e0fc4a1c-7602-43f9-9cea-0d8bb49039b8']

# %% [markdown]
# # Named entity recognition

# %%
nlp = spacy.load('en_core_web_sm')
nlp

# %%
document = nlp(article.cleaned_text)

# %%
# Tags: https://ashutoshtripathi.com/2020/04/13/parts-of-speech-tagging-and-dependency-parsing-using-spacy-nlp/
for token in document:
  print(token.text, ' - ', token.pos_)
# Out:
# Natural  -  ADJ
# language  -  NOUN
# processing  -  NOUN
# (  -  PUNCT
# NLP  -  PROPN
# )  -  PUNCT
# is  -  AUX
# the  -  DET
# processing  -  NOUN
# of  -  ADP
# natural  -  ADJ
# language  -  NOUN
# information  -  NOUN
# by  -  ADP
# a  -  DET
# computer  -  NOUN
# .  -  PUNCT
# NLP  -  PROPN
# is  -  AUX
# a  -  DET
# subfield  -  NOUN
# of  -  ADP
# computer  -  NOUN
# science  -  NOUN
# and  -  CCONJ
# is  -  AUX
# closely  -  ADV
# associated  -  VERB
# with  -  ADP
# artificial  -  ADJ
# intelligence  -  NOUN
# .  -  PUNCT
# NLP  -  PROPN
# is  -  AUX
# also  -  ADV
# related  -  VERB
# to  -  ADP
# information  -  NOUN
# retrieval  -  NOUN
# ,  -  PUNCT
# knowledge  -  NOUN
# representation  -  NOUN
# ,  -  PUNCT
# computational  -  ADJ
# linguistics  -  NOUN
# ,  -  PUNCT
# and  -  CCONJ
# linguistics  -  NOUN
# more  -  ADV
# broadly.[1  -  X
# ]  -  PUNCT
#
#
#   -  SPACE
# Major  -  ADJ
# processing  -  NOUN
# tasks  -  NOUN
# in  -  ADP
# an  -  DET
# NLP  -  PROPN
# system  -  NOUN
# include  -  VERB
# :  -  PUNCT
# speech  -  NOUN
# recognition  -  NOUN
# ,  -  PUNCT
# text  -  NOUN
# classification  -  NOUN
# ,  -  PUNCT
# natural  -  ADJ
# language  -  NOUN
# understanding  -  NOUN
# ,  -  PUNCT
# and  -  CCONJ
# natural  -  ADJ
# language  -  NOUN
# generation  -  NOUN
# .  -  PUNCT
#
#
#   -  SPACE
# Natural  -  ADJ
# language  -  NOUN
# processing  -  NOUN
# has  -  VERB
# its  -  PRON
# roots  -  NOUN
# in  -  ADP
# the  -  DET
# 1950s.[2  -  NUM
# ]  -  PUNCT
# Already  -  ADV
# in  -  ADP
# 1950  -  NUM
# ,  -  PUNCT
# Alan  -  PROPN
# Turing  -  PROPN
# published  -  VERB
# an  -  DET
# article  -  NOUN
# titled  -  VERB
# "  -  PUNCT
# Computing  -  PROPN
# Machinery  -  PROPN
# and  -  CCONJ
# Intelligence  -  PROPN
# "  -  PUNCT
# which  -  PRON
# proposed  -  VERB
# what  -  PRON
# is  -  AUX
# now  -  ADV
# called  -  VERB
# the  -  DET
# Turing  -  VERB
# test  -  NOUN
# as  -  ADP
# a  -  DET
# criterion  -  NOUN
# of  -  ADP
# intelligence  -  NOUN
# ,  -  PUNCT
# though  -  SCONJ
# at  -  ADP
# the  -  DET
# time  -  NOUN
# that  -  PRON
# was  -  AUX
# not  -  PART
# articulated  -  VERB
# as  -  ADP
# a  -  DET
# problem  -  NOUN
# separate  -  ADJ
# from  -  ADP
# artificial  -  ADJ
# intelligence  -  NOUN
# .  -  PUNCT
# The  -  DET
# proposed  -  VERB
# test  -  NOUN
# includes  -  VERB
# a  -  DET
# task  -  NOUN
# that  -  PRON
# involves  -  VERB
# the  -  DET
# automated  -  VERB
# interpretation  -  NOUN
# and  -  CCONJ
# generation  -  NOUN
# of  -  ADP
# natural  -  ADJ
# language  -  NOUN
# .  -  PUNCT
#
#
#   -  SPACE
# The  -  DET
# premise  -  NOUN
# of  -  ADP
# symbolic  -  ADJ
# NLP  -  PROPN
# is  -  AUX
# often  -  ADV
# illustrated  -  VERB
# using  -  VERB
# John  -  PROPN
# Searle  -  PROPN
# 's  -  PART
# Chinese  -  ADJ
# room  -  NOUN
# thought  -  VERB
# experiment  -  NOUN
# :  -  PUNCT
# Given  -  VERB
# a  -  DET
# collection  -  NOUN
# of  -  ADP
# rules  -  NOUN
# (  -  PUNCT
# e.g.  -  ADV
# ,  -  PUNCT
# a  -  DET
# Chinese  -  ADJ
# phrasebook  -  NOUN
# ,  -  PUNCT
# with  -  ADP
# questions  -  NOUN
# and  -  CCONJ
# matching  -  NOUN
# answers  -  NOUN
# )  -  PUNCT
# ,  -  PUNCT
# the  -  DET
# computer  -  NOUN
# emulates  -  VERB
# natural  -  ADJ
# language  -  NOUN
# understanding  -  NOUN
# (  -  PUNCT
# or  -  CCONJ
# other  -  ADJ
# NLP  -  PROPN
# tasks  -  NOUN
# )  -  PUNCT
# by  -  ADP
# applying  -  VERB
# those  -  DET
# rules  -  NOUN
# to  -  ADP
# the  -  DET
# data  -  NOUN
# it  -  PRON
# confronts  -  VERB
# .  -  PUNCT
#
#   -  SPACE
# •  -  NUM
# 1950s  -  NUM
# :  -  PUNCT
# The  -  DET
# Georgetown  -  PROPN
# experiment  -  NOUN
# in  -  ADP
# 1954  -  NUM
# involved  -  VERB
# fully  -  ADV
# automatic  -  ADJ
# translation  -  NOUN
# of  -  ADP
# more  -  ADJ
# than  -  ADP
# sixty  -  NUM
# Russian  -  ADJ
# sentences  -  NOUN
# into  -  ADP
# English  -  PROPN
# .  -  PUNCT
# The  -  DET
# authors  -  NOUN
# claimed  -  VERB
# that  -  SCONJ
# within  -  ADP
# three  -  NUM
# or  -  CCONJ
# five  -  NUM
# years  -  NOUN
# ,  -  PUNCT
# machine  -  NOUN
# translation  -  NOUN
# would  -  AUX
# be  -  AUX
# a  -  DET
# solved  -  ADJ
# problem  -  NOUN
# .  -  PUNCT
# 3  -  NUM
# However  -  ADV
# ,  -  PUNCT
# real  -  ADJ
# progress  -  NOUN
# was  -  AUX
# much  -  ADV
# slower  -  ADJ
# ,  -  PUNCT
# and  -  CCONJ
# after  -  ADP
# the  -  DET
# ALPAC  -  PROPN
# report  -  NOUN
# in  -  ADP
# 1966  -  NUM
# ,  -  PUNCT
# which  -  PRON
# found  -  VERB
# that  -  SCONJ
# ten  -  NUM
# years  -  NOUN
# of  -  ADP
# research  -  NOUN
# had  -  AUX
# failed  -  VERB
# to  -  PART
# fulfill  -  VERB
# the  -  DET
# expectations  -  NOUN
# ,  -  PUNCT
# funding  -  NOUN
# for  -  ADP
# machine  -  NOUN
# translation  -  NOUN
# was  -  AUX
# dramatically  -  ADV
# reduced  -  VERB
# .  -  PUNCT
# Little  -  ADJ
# further  -  ADJ
# research  -  NOUN
# in  -  ADP
# machine  -  NOUN
# translation  -  NOUN
# was  -  AUX
# conducted  -  VERB
# in  -  ADP
# America  -  PROPN
# (  -  PUNCT
# though  -  SCONJ
# some  -  DET
# research  -  NOUN
# continued  -  VERB
# elsewhere  -  ADV
# ,  -  PUNCT
# such  -  ADJ
# as  -  ADP
# Japan  -  PROPN
# and  -  CCONJ
# Europe  -  PROPN
# 4  -  NUM
# )  -  PUNCT
# until  -  ADP
# the  -  DET
# late  -  ADJ
# 1980s  -  NOUN
# when  -  SCONJ
# the  -  DET
# first  -  ADJ
# statistical  -  ADJ
# machine  -  NOUN
# translation  -  NOUN
# systems  -  NOUN
# were  -  AUX
# developed  -  VERB
# .  -  PUNCT
#
#   -  SPACE
# •  -  VERB
# 1960s  -  NOUN
# :  -  PUNCT
# Some  -  DET
# notably  -  ADV
# successful  -  ADJ
# natural  -  ADJ
# language  -  NOUN
# processing  -  NOUN
# systems  -  NOUN
# developed  -  VERB
# in  -  ADP
# the  -  DET
# 1960s  -  NOUN
# were  -  AUX
# SHRDLU  -  ADJ
# ,  -  PUNCT
# a  -  DET
# natural  -  ADJ
# language  -  NOUN
# system  -  NOUN
# working  -  VERB
# in  -  ADP
# restricted  -  VERB
# "  -  PUNCT
# blocks  -  NOUN
# worlds  -  NOUN
# "  -  PUNCT
# with  -  ADP
# restricted  -  ADJ
# vocabularies  -  NOUN
# ,  -  PUNCT
# and  -  CCONJ
# ELIZA  -  PROPN
# ,  -  PUNCT
# a  -  DET
# simulation  -  NOUN
# of  -  ADP
# a  -  DET
# Rogerian  -  ADJ
# psychotherapy  -  NOUN
# ,  -  PUNCT
# written  -  VERB
# by  -  ADP
# Joseph  -  PROPN
# Weizenbaum  -  PROPN
# between  -  ADP
# 1964  -  NUM
# and  -  CCONJ
# 1966  -  NUM
# .  -  PUNCT
# Despite  -  SCONJ
# using  -  VERB
# minimal  -  ADJ
# information  -  NOUN
# about  -  ADP
# human  -  ADJ
# thought  -  NOUN
# or  -  CCONJ
# emotion  -  NOUN
# ,  -  PUNCT
# ELIZA  -  PROPN
# was  -  AUX
# able  -  ADJ
# to  -  PART
# produce  -  VERB
# interactions  -  NOUN
# that  -  PRON
# appeared  -  VERB
# human  -  NOUN
# -  -  PUNCT
# like  -  ADJ
# .  -  PUNCT
# When  -  SCONJ
# the  -  DET
# "  -  PUNCT
# patient  -  NOUN
# "  -  PUNCT
# exceeded  -  VERB
# the  -  DET
# very  -  ADV
# small  -  ADJ
# knowledge  -  NOUN
# base  -  NOUN
# ,  -  PUNCT
# ELIZA  -  PROPN
# might  -  AUX
# provide  -  VERB
# a  -  DET
# generic  -  ADJ
# response  -  NOUN
# ,  -  PUNCT
# for  -  ADP
# example  -  NOUN
# ,  -  PUNCT
# responding  -  VERB
# to  -  ADP
# "  -  PUNCT
# My  -  PRON
# head  -  NOUN
# hurts  -  VERB
# "  -  PUNCT
# with  -  ADP
# "  -  PUNCT
# Why  -  SCONJ
# do  -  AUX
# you  -  PRON
# say  -  VERB
# your  -  PRON
# head  -  NOUN
# hurts  -  VERB
# ?  -  PUNCT
# "  -  PUNCT
# .  -  PUNCT
# Ross  -  PROPN
# Quillian  -  PROPN
# 's  -  PART
# successful  -  ADJ
# work  -  NOUN
# on  -  ADP
# natural  -  ADJ
# language  -  NOUN
# was  -  AUX
# demonstrated  -  VERB
# with  -  ADP
# a  -  DET
# vocabulary  -  NOUN
# of  -  ADP
# only  -  ADV
# twenty  -  NUM
# words  -  NOUN
# ,  -  PUNCT
# because  -  SCONJ
# that  -  PRON
# was  -  AUX
# all  -  PRON
# that  -  PRON
# would  -  AUX
# fit  -  VERB
# in  -  ADP
# a  -  DET
# computer  -  NOUN
# memory  -  NOUN
# at  -  ADP
# the  -  DET
# time  -  NOUN
# .  -  PUNCT
# 5  -  NUM
#
#   -  SPACE
# •  -  VERB
# 1970s  -  NOUN
# :  -  PUNCT
# During  -  ADP
# the  -  DET
# 1970s  -  NOUN
# ,  -  PUNCT
# many  -  ADJ
# programmers  -  NOUN
# began  -  VERB
# to  -  PART
# write  -  VERB
# "  -  PUNCT
# conceptual  -  ADJ
# ontologies  -  NOUN
# "  -  PUNCT
# ,  -  PUNCT
# which  -  PRON
# structured  -  VERB
# real  -  ADJ
# -  -  PUNCT
# world  -  NOUN
# information  -  NOUN
# into  -  ADP
# computer  -  NOUN
# -  -  PUNCT
# understandable  -  ADJ
# data  -  NOUN
# .  -  PUNCT
# Examples  -  NOUN
# are  -  AUX
# MARGIE  -  PROPN
# (  -  PUNCT
# Schank  -  PROPN
# ,  -  PUNCT
# 1975  -  NUM
# )  -  PUNCT
# ,  -  PUNCT
# SAM  -  PROPN
# (  -  PUNCT
# Cullingford  -  PROPN
# ,  -  PUNCT
# 1978  -  NUM
# )  -  PUNCT
# ,  -  PUNCT
# PAM  -  PROPN
# (  -  PUNCT
# Wilensky  -  PROPN
# ,  -  PUNCT
# 1978  -  NUM
# )  -  PUNCT
# ,  -  PUNCT
# TaleSpin  -  PROPN
# (  -  PUNCT
# Meehan  -  PROPN
# ,  -  PUNCT
# 1976  -  NUM
# )  -  PUNCT
# ,  -  PUNCT
# QUALM  -  PROPN
# (  -  PUNCT
# Lehnert  -  PROPN
# ,  -  PUNCT
# 1977  -  NUM
# )  -  PUNCT
# ,  -  PUNCT
# Politics  -  PROPN
# (  -  PUNCT
# Carbonell  -  PROPN
# ,  -  PUNCT
# 1979  -  NUM
# )  -  PUNCT
# ,  -  PUNCT
# and  -  CCONJ
# Plot  -  PROPN
# Units  -  PROPN
# (  -  PUNCT
# Lehnert  -  PROPN
# 1981  -  NUM
# )  -  PUNCT
# .  -  PUNCT
# During  -  ADP
# this  -  DET
# time  -  NOUN
# ,  -  PUNCT
# the  -  DET
# first  -  ADJ
# chatterbots  -  NOUN
# were  -  AUX
# written  -  VERB
# (  -  PUNCT
# e.g.  -  ADV
# ,  -  PUNCT
# PARRY  -  PROPN
# )  -  PUNCT
# .  -  PUNCT
#
#   -  SPACE
# •  -  VERB
# 1980s  -  NUM
# :  -  PUNCT
# The  -  DET
# 1980s  -  NOUN
# and  -  CCONJ
# early  -  ADJ
# 1990s  -  NOUN
# mark  -  VERB
# the  -  DET
# heyday  -  NOUN
# of  -  ADP
# symbolic  -  ADJ
# methods  -  NOUN
# in  -  ADP
# NLP  -  PROPN
# .  -  PUNCT
# Focus  -  NOUN
# areas  -  NOUN
# of  -  ADP
# the  -  DET
# time  -  NOUN
# included  -  VERB
# research  -  NOUN
# on  -  ADP
# rule  -  NOUN
# -  -  PUNCT
# based  -  VERB
# parsing  -  NOUN
# (  -  PUNCT
# e.g.  -  ADV
# ,  -  PUNCT
# the  -  DET
# development  -  NOUN
# of  -  ADP
# HPSG  -  NOUN
# as  -  ADP
# a  -  DET
# computational  -  ADJ
# operationalization  -  NOUN
# of  -  ADP
# generative  -  ADJ
# grammar  -  NOUN
# )  -  PUNCT
# ,  -  PUNCT
# morphology  -  NOUN
# (  -  PUNCT
# e.g.  -  ADV
# ,  -  PUNCT
# two  -  NUM
# -  -  PUNCT
# level  -  NOUN
# morphology  -  NOUN
# 6  -  NUM
# )  -  PUNCT
# ,  -  PUNCT
# semantics  -  NOUN
# (  -  PUNCT
# e.g.  -  ADV
# ,  -  PUNCT
# Lesk  -  PROPN
# algorithm  -  PROPN
# )  -  PUNCT
# ,  -  PUNCT
# reference  -  NOUN
# (  -  PUNCT
# e.g.  -  ADV
# ,  -  PUNCT
# within  -  ADP
# Centering  -  VERB
# Theory  -  PROPN
# 7  -  NUM
# )  -  PUNCT
# and  -  CCONJ
# other  -  ADJ
# areas  -  NOUN
# of  -  ADP
# natural  -  ADJ
# language  -  NOUN
# understanding  -  NOUN
# (  -  PUNCT
# e.g.  -  ADV
# ,  -  PUNCT
# in  -  ADP
# the  -  DET
# Rhetorical  -  PROPN
# Structure  -  PROPN
# Theory  -  PROPN
# )  -  PUNCT
# .  -  PUNCT
# Other  -  ADJ
# lines  -  NOUN
# of  -  ADP
# research  -  NOUN
# were  -  AUX
# continued  -  VERB
# ,  -  PUNCT
# e.g.  -  ADV
# ,  -  PUNCT
# the  -  DET
# development  -  NOUN
# of  -  ADP
# chatterbots  -  NOUN
# with  -  ADP
# Racter  -  PROPN
# and  -  CCONJ
# Jabberwacky  -  PROPN
# .  -  PUNCT
# An  -  DET
# important  -  ADJ
# development  -  NOUN
# (  -  PUNCT
# that  -  PRON
# eventually  -  ADV
# led  -  VERB
# to  -  ADP
# the  -  DET
# statistical  -  ADJ
# turn  -  NOUN
# in  -  ADP
# the  -  DET
# 1990s  -  NUM
# )  -  PUNCT
# was  -  AUX
# the  -  DET
# rising  -  VERB
# importance  -  NOUN
# of  -  ADP
# quantitative  -  ADJ
# evaluation  -  NOUN
# in  -  ADP
# this  -  DET
# period  -  NOUN
# .  -  PUNCT
# 8  -  NUM
#
#
#   -  SPACE
# Up  -  ADV
# until  -  ADP
# the  -  DET
# 1980s  -  NUM
# ,  -  PUNCT
# most  -  ADJ
# natural  -  ADJ
# language  -  NOUN
# processing  -  NOUN
# systems  -  NOUN
# were  -  AUX
# based  -  VERB
# on  -  ADP
# complex  -  ADJ
# sets  -  NOUN
# of  -  ADP
# hand  -  NOUN
# -  -  PUNCT
# written  -  VERB
# rules  -  NOUN
# .  -  PUNCT
# Starting  -  VERB
# in  -  ADP
# the  -  DET
# late  -  ADJ
# 1980s  -  NOUN
# ,  -  PUNCT
# however  -  ADV
# ,  -  PUNCT
# there  -  PRON
# was  -  VERB
# a  -  DET
# revolution  -  NOUN
# in  -  ADP
# natural  -  ADJ
# language  -  NOUN
# processing  -  NOUN
# with  -  ADP
# the  -  DET
# introduction  -  NOUN
# of  -  ADP
# machine  -  NOUN
# learning  -  VERB
# algorithms  -  NOUN
# for  -  ADP
# language  -  NOUN
# processing  -  NOUN
# .  -  PUNCT
# This  -  DET
# shift  -  NOUN
# was  -  AUX
# influenced  -  VERB
# by  -  ADP
# increasing  -  VERB
# computational  -  ADJ
# power  -  NOUN
# (  -  PUNCT
# see  -  VERB
# Moore  -  PROPN
# 's  -  PART
# law  -  NOUN
# )  -  PUNCT
# and  -  CCONJ
# a  -  DET
# decline  -  NOUN
# in  -  ADP
# the  -  DET
# dominance  -  NOUN
# of  -  ADP
# Chomskyan  -  ADJ
# linguistic  -  ADJ
# theories  -  NOUN
# ...  -  PUNCT
# (  -  PUNCT
# e.g.  -  ADV
# transformational  -  ADJ
# grammar  -  NOUN
# )  -  PUNCT
# ,  -  PUNCT
# whose  -  DET
# theoretical  -  ADJ
# underpinnings  -  NOUN
# discouraged  -  VERB
# the  -  DET
# sort  -  NOUN
# of  -  ADP
# corpus  -  NOUN
# linguistics  -  NOUN
# that  -  PRON
# underlies  -  VERB
# the  -  DET
# machine  -  NOUN
# -  -  PUNCT
# learning  -  VERB
# approach  -  NOUN
# to  -  ADP
# language  -  NOUN
# processing.[9  -  NOUN
# ]  -  PUNCT
#
#   -  SPACE
# •  -  VERB
# 1990s  -  NOUN
# :  -  PUNCT
# Many  -  ADJ
# of  -  ADP
# the  -  DET
# notable  -  ADJ
# early  -  ADJ
# successes  -  NOUN
# in  -  ADP
# statistical  -  ADJ
# methods  -  NOUN
# in  -  ADP
# NLP  -  PROPN
# occurred  -  VERB
# in  -  ADP
# the  -  DET
# field  -  NOUN
# of  -  ADP
# machine  -  NOUN
# translation  -  NOUN
# ,  -  PUNCT
# due  -  ADJ
# especially  -  ADV
# to  -  PART
# work  -  VERB
# at  -  ADP
# IBM  -  PROPN
# Research  -  PROPN
# ,  -  PUNCT
# such  -  ADJ
# as  -  ADP
# IBM  -  PROPN
# alignment  -  NOUN
# models  -  NOUN
# .  -  PUNCT
# These  -  DET
# systems  -  NOUN
# were  -  AUX
# able  -  ADJ
# to  -  PART
# take  -  VERB
# advantage  -  NOUN
# of  -  ADP
# existing  -  VERB
# multilingual  -  ADJ
# textual  -  NOUN
# corpora  -  NOUN
# that  -  PRON
# had  -  AUX
# been  -  AUX
# produced  -  VERB
# by  -  ADP
# the  -  DET
# Parliament  -  PROPN
# of  -  ADP
# Canada  -  PROPN
# and  -  CCONJ
# the  -  DET
# European  -  PROPN
# Union  -  PROPN
# as  -  ADP
# a  -  DET
# result  -  NOUN
# of  -  ADP
# laws  -  NOUN
# calling  -  VERB
# for  -  ADP
# the  -  DET
# translation  -  NOUN
# of  -  ADP
# all  -  DET
# governmental  -  ADJ
# proceedings  -  NOUN
# into  -  ADP
# all  -  DET
# official  -  ADJ
# languages  -  NOUN
# of  -  ADP
# the  -  DET
# corresponding  -  ADJ
# systems  -  NOUN
# of  -  ADP
# government  -  NOUN
# .  -  PUNCT
# However  -  ADV
# ,  -  PUNCT
# many  -  ADJ
# systems  -  NOUN
# relied  -  VERB
# on  -  ADP
# corpora  -  PROPN
# that  -  PRON
# were  -  AUX
# specifically  -  ADV
# developed  -  VERB
# for  -  ADP
# the  -  DET
# tasks  -  NOUN
# they  -  PRON
# were  -  AUX
# designed  -  VERB
# to  -  PART
# perform  -  VERB
# .  -  PUNCT
# This  -  DET
# reliance  -  NOUN
# has  -  AUX
# been  -  AUX
# a  -  DET
# major  -  ADJ
# limitation  -  NOUN
# to  -  ADP
# their  -  PRON
# broader  -  ADJ
# effectiveness  -  NOUN
# and  -  CCONJ
# continues  -  VERB
# to  -  PART
# affect  -  VERB
# similar  -  ADJ
# systems  -  NOUN
# .  -  PUNCT
# Consequently  -  ADV
# ,  -  PUNCT
# significant  -  ADJ
# research  -  NOUN
# has  -  AUX
# focused  -  VERB
# on  -  ADP
# methods  -  NOUN
# for  -  ADP
# learning  -  VERB
# effectively  -  ADV
# from  -  ADP
# limited  -  ADJ
# amounts  -  NOUN
# of  -  ADP
# data  -  NOUN
# .  -  PUNCT
#
#   -  SPACE
# •  -  NUM
# 2000s  -  NUM
# :  -  PUNCT
# With  -  ADP
# the  -  DET
# growth  -  NOUN
# of  -  ADP
# the  -  DET
# web  -  NOUN
# ,  -  PUNCT
# increasing  -  VERB
# amounts  -  NOUN
# of  -  ADP
# raw  -  ADJ
# (  -  PUNCT
# unannotated  -  ADJ
# )  -  PUNCT
# language  -  NOUN
# data  -  NOUN
# have  -  AUX
# become  -  VERB
# available  -  ADJ
# since  -  SCONJ
# the  -  DET
# mid-1990s  -  NOUN
# .  -  PUNCT
# Research  -  NOUN
# has  -  AUX
# thus  -  ADV
# increasingly  -  ADV
# focused  -  VERB
# on  -  ADP
# unsupervised  -  ADJ
# and  -  CCONJ
# semi  -  ADJ
# -  -  ADJ
# supervised  -  ADJ
# learning  -  NOUN
# algorithms  -  VERB
# .  -  PUNCT
# Such  -  ADJ
# algorithms  -  NOUN
# can  -  AUX
# learn  -  VERB
# from  -  ADP
# data  -  NOUN
# that  -  PRON
# has  -  AUX
# not  -  PART
# been  -  AUX
# hand  -  NOUN
# -  -  PUNCT
# annotated  -  VERB
# with  -  ADP
# the  -  DET
# desired  -  VERB
# answers  -  NOUN
# or  -  CCONJ
# using  -  VERB
# a  -  DET
# combination  -  NOUN
# of  -  ADP
# annotated  -  ADJ
# and  -  CCONJ
# non  -  ADJ
# -  -  ADJ
# annotated  -  ADJ
# data  -  NOUN
# .  -  PUNCT
# Generally  -  ADV
# ,  -  PUNCT
# this  -  DET
# task  -  NOUN
# is  -  AUX
# much  -  ADV
# more  -  ADV
# difficult  -  ADJ
# than  -  ADP
# supervised  -  ADJ
# learning  -  NOUN
# ,  -  PUNCT
# and  -  CCONJ
# typically  -  ADV
# produces  -  VERB
# less  -  ADV
# accurate  -  ADJ
# results  -  NOUN
# for  -  ADP
# a  -  DET
# given  -  VERB
# amount  -  NOUN
# of  -  ADP
# input  -  NOUN
# data  -  NOUN
# .  -  PUNCT
# However  -  ADV
# ,  -  PUNCT
# large  -  ADJ
# quantities  -  NOUN
# of  -  ADP
# non  -  ADJ
# -  -  ADJ
# annotated  -  ADJ
# data  -  NOUN
# are  -  AUX
# available  -  ADJ
# (  -  PUNCT
# including  -  VERB
# ,  -  PUNCT
# among  -  ADP
# other  -  ADJ
# things  -  NOUN
# ,  -  PUNCT
# the  -  DET
# entire  -  ADJ
# content  -  NOUN
# of  -  ADP
# the  -  DET
# World  -  PROPN
# Wide  -  PROPN
# Web  -  PROPN
# )  -  PUNCT
# ,  -  PUNCT
# which  -  PRON
# can  -  AUX
# often  -  ADV
# make  -  VERB
# up  -  ADP
# for  -  ADP
# the  -  DET
# worse  -  ADJ
# efficiency  -  NOUN
# if  -  SCONJ
# the  -  DET
# algorithm  -  PROPN
# used  -  VERB
# has  -  VERB
# a  -  DET
# low  -  ADJ
# enough  -  ADJ
# time  -  NOUN
# complexity  -  NOUN
# to  -  PART
# be  -  AUX
# practical  -  ADJ
# .  -  PUNCT
#
#   -  SPACE
# •  -  VERB
# 2003  -  NUM
# :  -  PUNCT
# word  -  NOUN
# n  -  CCONJ
# -  -  PUNCT
# gram  -  NOUN
# model  -  NOUN
# ,  -  PUNCT
# at  -  ADP
# the  -  DET
# time  -  NOUN
# the  -  DET
# best  -  ADJ
# statistical  -  ADJ
# algorithm  -  NOUN
# ,  -  PUNCT
# is  -  AUX
# outperformed  -  VERB
# by  -  ADP
# a  -  DET
# multi  -  ADJ
# -  -  ADJ
# layer  -  ADJ
# perceptron  -  NOUN
# (  -  PUNCT
# with  -  ADP
# a  -  DET
# single  -  ADJ
# hidden  -  VERB
# layer  -  NOUN
# and  -  CCONJ
# context  -  NOUN
# length  -  NOUN
# of  -  ADP
# several  -  ADJ
# words  -  NOUN
# ,  -  PUNCT
# trained  -  VERB
# on  -  ADP
# up  -  ADP
# to  -  PART
# 14  -  NUM
# million  -  NUM
# words  -  NOUN
# ,  -  PUNCT
# by  -  ADP
# Bengio  -  PROPN
# et  -  PROPN
# al  -  PROPN
# .  -  PROPN
# )  -  PUNCT
# 10  -  NUM
#
#   -  SPACE
# •  -  VERB
# 2010  -  NUM
# :  -  PUNCT
# Tomáš  -  PROPN
# Mikolov  -  PROPN
# (  -  PUNCT
# then  -  ADV
# a  -  DET
# PhD  -  NOUN
# student  -  NOUN
# at  -  ADP
# Brno  -  PROPN
# University  -  PROPN
# of  -  ADP
# Technology  -  PROPN
# )  -  PUNCT
# with  -  ADP
# co  -  NOUN
# -  -  NOUN
# authors  -  NOUN
# applied  -  VERB
# a  -  DET
# simple  -  ADJ
# recurrent  -  ADJ
# neural  -  ADJ
# network  -  NOUN
# with  -  ADP
# a  -  DET
# single  -  ADJ
# hidden  -  VERB
# layer  -  NOUN
# to  -  PART
# language  -  VERB
# modeling  -  NOUN
# ,  -  PUNCT
# 11  -  NUM
# and  -  CCONJ
# in  -  ADP
# the  -  DET
# following  -  VERB
# years  -  NOUN
# he  -  PRON
# went  -  VERB
# on  -  ADP
# to  -  PART
# develop  -  VERB
# Word2vec  -  PROPN
# .  -  PUNCT
# In  -  ADP
# the  -  DET
# 2010s  -  NOUN
# ,  -  PUNCT
# representation  -  NOUN
# learning  -  NOUN
# and  -  CCONJ
# deep  -  ADJ
# neural  -  ADJ
# network  -  NOUN
# -  -  PUNCT
# style  -  NOUN
# (  -  PUNCT
# featuring  -  VERB
# many  -  ADJ
# hidden  -  VERB
# layers  -  NOUN
# )  -  PUNCT
# machine  -  NOUN
# learning  -  NOUN
# methods  -  NOUN
# became  -  VERB
# widespread  -  ADJ
# in  -  ADP
# natural  -  ADJ
# language  -  NOUN
# processing  -  NOUN
# .  -  PUNCT
# This  -  DET
# shift  -  NOUN
# gained  -  VERB
# momentum  -  NOUN
# due  -  ADP
# to  -  ADP
# results  -  NOUN
# showing  -  VERB
# that  -  SCONJ
# such  -  ADJ
# techniques  -  NOUN
# 12  -  NUM
# 13  -  NUM
# can  -  AUX
# achieve  -  VERB
# state  -  NOUN
# -  -  PUNCT
# of  -  ADP
# -  -  PUNCT
# the  -  DET
# -  -  PUNCT
# art  -  NOUN
# results  -  NOUN
# in  -  ADP
# many  -  ADJ
# natural  -  ADJ
# language  -  NOUN
# tasks  -  NOUN
# ,  -  PUNCT
# e.g.  -  ADV
# ,  -  PUNCT
# in  -  ADP
# language  -  NOUN
# modeling  -  NOUN
# 14  -  NUM
# and  -  CCONJ
# parsing  -  VERB
# .  -  PUNCT
# 15  -  NUM
# 16  -  NUM
# This  -  PRON
# is  -  AUX
# increasingly  -  ADV
# important  -  ADJ
# in  -  ADP
# medicine  -  NOUN
# and  -  CCONJ
# healthcare  -  PROPN
# ,  -  PUNCT
# where  -  SCONJ
# NLP  -  PROPN
# helps  -  VERB
# analyze  -  VERB
# notes  -  NOUN
# and  -  CCONJ
# text  -  NOUN
# in  -  ADP
# electronic  -  ADJ
# health  -  NOUN
# records  -  NOUN
# that  -  PRON
# would  -  AUX
# otherwise  -  ADV
# be  -  AUX
# inaccessible  -  ADJ
# for  -  ADP
# study  -  NOUN
# when  -  SCONJ
# seeking  -  VERB
# to  -  PART
# improve  -  VERB
# care  -  NOUN
# 17  -  NUM
# or  -  CCONJ
# protect  -  VERB
# patient  -  NOUN
# privacy  -  NOUN
# .  -  PUNCT
# 18  -  NUM
#
#
#   -  SPACE
# Symbolic  -  PROPN
# approach  -  NOUN
# ,  -  PUNCT
# i.e.  -  X
# ,  -  PUNCT
# the  -  DET
# hand  -  NOUN
# -  -  PUNCT
# coding  -  NOUN
# of  -  ADP
# a  -  DET
# set  -  NOUN
# of  -  ADP
# rules  -  NOUN
# for  -  ADP
# manipulating  -  VERB
# symbols  -  NOUN
# ,  -  PUNCT
# coupled  -  VERB
# with  -  ADP
# a  -  DET
# dictionary  -  ADJ
# lookup  -  NOUN
# ,  -  PUNCT
# was  -  AUX
# historically  -  ADV
# the  -  DET
# first  -  ADJ
# approach  -  NOUN
# used  -  VERB
# both  -  PRON
# by  -  ADP
# AI  -  PROPN
# in  -  ADP
# general  -  ADJ
# and  -  CCONJ
# by  -  ADP
# NLP  -  PROPN
# in  -  ADP
# particular:[19][20  -  PROPN
# ]  -  PUNCT
# such  -  ADJ
# as  -  ADP
# by  -  ADP
# writing  -  VERB
# grammars  -  NOUN
# or  -  CCONJ
# devising  -  VERB
# heuristic  -  ADJ
# rules  -  NOUN
# for  -  ADP
# stemming  -  VERB
# .  -  PUNCT
#
#
#   -  SPACE
# Machine  -  NOUN
# learning  -  NOUN
# approaches  -  NOUN
# ,  -  PUNCT
# which  -  PRON
# include  -  VERB
# both  -  CCONJ
# statistical  -  ADJ
# and  -  CCONJ
# neural  -  ADJ
# networks  -  NOUN
# ,  -  PUNCT
# on  -  ADP
# the  -  DET
# other  -  ADJ
# hand  -  NOUN
# ,  -  PUNCT
# have  -  VERB
# many  -  ADJ
# advantages  -  NOUN
# over  -  ADP
# the  -  DET
# symbolic  -  ADJ
# approach  -  NOUN
# :  -  PUNCT
#
#   -  SPACE
# •  -  VERB
# both  -  CCONJ
# statistical  -  ADJ
# and  -  CCONJ
# neural  -  ADJ
# networks  -  NOUN
# methods  -  NOUN
# can  -  AUX
# focus  -  VERB
# more  -  ADV
# on  -  ADP
# the  -  DET
# most  -  ADV
# common  -  ADJ
# cases  -  NOUN
# extracted  -  VERB
# from  -  ADP
# a  -  DET
# corpus  -  NOUN
# of  -  ADP
# texts  -  NOUN
# ,  -  PUNCT
# whereas  -  SCONJ
# the  -  DET
# rule  -  NOUN
# -  -  PUNCT
# based  -  VERB
# approach  -  NOUN
# needs  -  VERB
# to  -  PART
# provide  -  VERB
# rules  -  NOUN
# for  -  ADP
# both  -  DET
# rare  -  ADJ
# cases  -  NOUN
# and  -  CCONJ
# common  -  ADJ
# ones  -  NOUN
# equally  -  ADV
# .  -  PUNCT
#
#   -  SPACE
# •  -  ADJ
# language  -  NOUN
# models  -  NOUN
# ,  -  PUNCT
# produced  -  VERB
# by  -  ADP
# either  -  CCONJ
# statistical  -  ADJ
# or  -  CCONJ
# neural  -  ADJ
# networks  -  NOUN
# methods  -  NOUN
# ,  -  PUNCT
# are  -  AUX
# more  -  ADV
# robust  -  ADJ
# to  -  ADP
# both  -  CCONJ
# unfamiliar  -  ADJ
# (  -  PUNCT
# e.g.  -  ADV
# containing  -  VERB
# words  -  NOUN
# or  -  CCONJ
# structures  -  NOUN
# that  -  PRON
# have  -  AUX
# not  -  PART
# been  -  AUX
# seen  -  VERB
# before  -  ADV
# )  -  PUNCT
# and  -  CCONJ
# erroneous  -  ADJ
# input  -  NOUN
# (  -  PUNCT
# e.g.  -  ADV
# with  -  ADP
# misspelled  -  ADJ
# words  -  NOUN
# or  -  CCONJ
# words  -  NOUN
# accidentally  -  ADV
# omitted  -  VERB
# )  -  PUNCT
# in  -  ADP
# comparison  -  NOUN
# to  -  ADP
# the  -  DET
# rule  -  NOUN
# -  -  PUNCT
# based  -  VERB
# systems  -  NOUN
# ,  -  PUNCT
# which  -  PRON
# are  -  AUX
# also  -  ADV
# more  -  ADV
# costly  -  ADJ
# to  -  PART
# produce  -  VERB
# .  -  PUNCT
#
#   -  SPACE
# •  -  VERB
# the  -  PRON
# larger  -  ADJ
# such  -  DET
# a  -  DET
# (  -  PUNCT
# probabilistic  -  ADJ
# )  -  PUNCT
# language  -  NOUN
# model  -  NOUN
# is  -  AUX
# ,  -  PUNCT
# the  -  PRON
# more  -  ADV
# accurate  -  ADJ
# it  -  PRON
# becomes  -  VERB
# ,  -  PUNCT
# in  -  ADP
# contrast  -  NOUN
# to  -  ADP
# rule  -  NOUN
# -  -  PUNCT
# based  -  VERB
# systems  -  NOUN
# that  -  PRON
# can  -  AUX
# gain  -  VERB
# accuracy  -  NOUN
# only  -  ADV
# by  -  ADP
# increasing  -  VERB
# the  -  DET
# amount  -  NOUN
# and  -  CCONJ
# complexity  -  NOUN
# of  -  ADP
# the  -  DET
# rules  -  NOUN
# leading  -  VERB
# to  -  ADP
# intractability  -  NOUN
# problems  -  NOUN
# .  -  PUNCT
#
#   -  SPACE
# •  -  VERB
# when  -  SCONJ
# the  -  DET
# amount  -  NOUN
# of  -  ADP
# training  -  NOUN
# data  -  NOUN
# is  -  AUX
# insufficient  -  ADJ
# to  -  PART
# successfully  -  ADV
# apply  -  VERB
# machine  -  NOUN
# learning  -  NOUN
# methods  -  NOUN
# ,  -  PUNCT
# e.g.  -  ADV
# ,  -  PUNCT
# for  -  ADP
# the  -  DET
# machine  -  NOUN
# translation  -  NOUN
# of  -  ADP
# low  -  ADJ
# -  -  PUNCT
# resource  -  NOUN
# languages  -  NOUN
# such  -  ADJ
# as  -  ADP
# provided  -  VERB
# by  -  ADP
# the  -  DET
# Apertium  -  PROPN
# system  -  NOUN
# ,  -  PUNCT
#
#   -  SPACE
# •  -  NUM
# for  -  ADP
# preprocessing  -  VERB
# in  -  ADP
# NLP  -  PROPN
# pipelines  -  NOUN
# ,  -  PUNCT
# e.g.  -  ADV
# ,  -  PUNCT
# tokenization  -  NOUN
# ,  -  PUNCT
# or  -  CCONJ
#
#   -  SPACE
# •  -  VERB
# for  -  ADP
# post  -  ADJ
# -  -  ADJ
# processing  -  ADJ
# and  -  CCONJ
# transforming  -  VERB
# the  -  DET
# output  -  NOUN
# of  -  ADP
# NLP  -  PROPN
# pipelines  -  NOUN
# ,  -  PUNCT
# e.g.  -  ADV
# ,  -  PUNCT
# for  -  ADP
# knowledge  -  NOUN
# extraction  -  NOUN
# from  -  ADP
# syntactic  -  ADJ
# parses  -  NOUN
# .  -  PUNCT
#
#
#   -  SPACE
# In  -  ADP
# the  -  DET
# late  -  ADJ
# 1980s  -  NOUN
# and  -  CCONJ
# mid-1990s  -  NOUN
# ,  -  PUNCT
# the  -  DET
# statistical  -  ADJ
# approach  -  NOUN
# ended  -  VERB
# a  -  DET
# period  -  NOUN
# of  -  ADP
# AI  -  PROPN
# winter  -  NOUN
# ,  -  PUNCT
# which  -  PRON
# was  -  AUX
# caused  -  VERB
# by  -  ADP
# the  -  DET
# inefficiencies  -  NOUN
# of  -  ADP
# the  -  DET
# rule  -  NOUN
# -  -  PUNCT
# based  -  VERB
# approaches.[21][22  -  PROPN
# ]  -  PUNCT
#
#
#   -  SPACE
# The  -  DET
# earliest  -  ADJ
# decision  -  NOUN
# trees  -  NOUN
# ,  -  PUNCT
# producing  -  VERB
# systems  -  NOUN
# of  -  ADP
# hard  -  ADJ
# if  -  SCONJ
# –  -  PUNCT
# then  -  ADV
# rules  -  NOUN
# ,  -  PUNCT
# were  -  AUX
# still  -  ADV
# very  -  ADV
# similar  -  ADJ
# to  -  ADP
# the  -  DET
# old  -  ADJ
# rule  -  NOUN
# -  -  PUNCT
# based  -  VERB
# approaches  -  NOUN
# .  -  PUNCT
# Only  -  ADV
# the  -  DET
# introduction  -  NOUN
# of  -  ADP
# hidden  -  ADJ
# Markov  -  PROPN
# models  -  NOUN
# ,  -  PUNCT
# applied  -  VERB
# to  -  ADP
# part  -  NOUN
# -  -  PUNCT
# of  -  ADP
# -  -  PUNCT
# speech  -  NOUN
# tagging  -  NOUN
# ,  -  PUNCT
# announced  -  VERB
# the  -  DET
# end  -  NOUN
# of  -  ADP
# the  -  DET
# old  -  ADJ
# rule  -  NOUN
# -  -  PUNCT
# based  -  VERB
# approach  -  NOUN
# .  -  PUNCT
#
#
#   -  SPACE
# A  -  DET
# major  -  ADJ
# drawback  -  NOUN
# of  -  ADP
# statistical  -  ADJ
# methods  -  NOUN
# is  -  AUX
# that  -  SCONJ
# they  -  PRON
# require  -  VERB
# elaborate  -  ADJ
# feature  -  NOUN
# engineering  -  NOUN
# .  -  PUNCT
# Since  -  SCONJ
# 2015,[23  -  NUM
# ]  -  PUNCT
# neural  -  ADJ
# network  -  NOUN
# –  -  PUNCT
# based  -  VERB
# methods  -  NOUN
# have  -  AUX
# increasingly  -  ADV
# replaced  -  VERB
# traditional  -  ADJ
# statistical  -  ADJ
# approaches  -  NOUN
# ,  -  PUNCT
# using  -  VERB
# semantic  -  ADJ
# networks[24  -  NOUN
# ]  -  PUNCT
# and  -  CCONJ
# word  -  NOUN
# embeddings  -  NOUN
# to  -  PART
# capture  -  VERB
# semantic  -  ADJ
# properties  -  NOUN
# of  -  ADP
# words  -  NOUN
# .  -  PUNCT
#
#
#   -  SPACE
# Intermediate  -  ADJ
# tasks  -  NOUN
# (  -  PUNCT
# e.g.  -  ADV
# ,  -  PUNCT
# part  -  NOUN
# -  -  PUNCT
# of  -  ADP
# -  -  PUNCT
# speech  -  NOUN
# tagging  -  NOUN
# and  -  CCONJ
# dependency  -  NOUN
# parsing  -  NOUN
# )  -  PUNCT
# are  -  AUX
# not  -  PART
# needed  -  VERB
# anymore  -  ADV
# .  -  PUNCT
#
#
#   -  SPACE
# Neural  -  ADJ
# machine  -  NOUN
# translation  -  NOUN
# ,  -  PUNCT
# based  -  VERB
# on  -  ADP
# then  -  ADV
# -  -  PUNCT
# newly  -  ADV
# invented  -  VERB
# sequence  -  NOUN
# -  -  PUNCT
# to  -  ADP
# -  -  PUNCT
# sequence  -  NOUN
# transformations  -  NOUN
# ,  -  PUNCT
# made  -  VERB
# obsolete  -  ADJ
# the  -  DET
# intermediate  -  ADJ
# steps  -  NOUN
# ,  -  PUNCT
# such  -  ADJ
# as  -  ADP
# word  -  NOUN
# alignment  -  NOUN
# ,  -  PUNCT
# previously  -  ADV
# necessary  -  ADJ
# for  -  ADP
# statistical  -  ADJ
# machine  -  NOUN
# translation  -  NOUN
# .  -  PUNCT
#
#
#   -  SPACE
# The  -  DET
# following  -  NOUN
# is  -  AUX
# a  -  DET
# list  -  NOUN
# of  -  ADP
# some  -  PRON
# of  -  ADP
# the  -  DET
# most  -  ADV
# commonly  -  ADV
# researched  -  VERB
# tasks  -  NOUN
# in  -  ADP
# natural  -  ADJ
# language  -  NOUN
# processing  -  NOUN
# .  -  PUNCT
# Some  -  PRON
# of  -  ADP
# these  -  DET
# tasks  -  NOUN
# have  -  VERB
# direct  -  ADJ
# real  -  ADJ
# -  -  PUNCT
# world  -  NOUN
# applications  -  NOUN
# ,  -  PUNCT
# while  -  SCONJ
# others  -  NOUN
# more  -  ADV
# commonly  -  ADV
# serve  -  VERB
# as  -  ADP
# subtasks  -  NOUN
# that  -  PRON
# are  -  AUX
# used  -  VERB
# to  -  PART
# aid  -  VERB
# in  -  ADP
# solving  -  VERB
# larger  -  ADJ
# tasks  -  NOUN
# .  -  PUNCT
#
#
#   -  SPACE
# Though  -  SCONJ
# natural  -  ADJ
# language  -  NOUN
# processing  -  NOUN
# tasks  -  NOUN
# are  -  AUX
# closely  -  ADV
# intertwined  -  VERB
# ,  -  PUNCT
# they  -  PRON
# can  -  AUX
# be  -  AUX
# subdivided  -  VERB
# into  -  ADP
# categories  -  NOUN
# for  -  ADP
# convenience  -  NOUN
# .  -  PUNCT
# A  -  DET
# coarse  -  ADJ
# division  -  NOUN
# is  -  AUX
# given  -  VERB
# below  -  ADP
# .  -  PUNCT
#
#
#   -  SPACE
# Based  -  VERB
# on  -  ADP
# long  -  ADV
# -  -  PUNCT
# standing  -  VERB
# trends  -  NOUN
# in  -  ADP
# the  -  DET
# field  -  NOUN
# ,  -  PUNCT
# it  -  PRON
# is  -  AUX
# possible  -  ADJ
# to  -  PART
# extrapolate  -  VERB
# future  -  ADJ
# directions  -  NOUN
# of  -  ADP
# NLP  -  PROPN
# .  -  PUNCT
# As  -  ADP
# of  -  ADP
# 2020  -  NUM
# ,  -  PUNCT
# three  -  NUM
# trends  -  NOUN
# among  -  ADP
# the  -  DET
# topics  -  NOUN
# of  -  ADP
# the  -  DET
# long  -  ADV
# -  -  PUNCT
# standing  -  VERB
# series  -  NOUN
# of  -  ADP
# CoNLL  -  PROPN
# Shared  -  PROPN
# Tasks  -  PROPN
# can  -  AUX
# be  -  AUX
# observed:[49  -  ADJ
# ]  -  X
#
#   -  SPACE
# •  -  ADJ
# Increasing  -  VERB
# interest  -  NOUN
# in  -  ADP
# multilinguality  -  NOUN
# ,  -  PUNCT
# and  -  CCONJ
# ,  -  PUNCT
# potentially  -  ADV
# ,  -  PUNCT
# multimodality  -  NOUN
# (  -  PUNCT
# English  -  PROPN
# since  -  SCONJ
# 1999  -  NUM
# ;  -  PUNCT
# Spanish  -  PROPN
# ,  -  PUNCT
# Dutch  -  PROPN
# since  -  SCONJ
# 2002  -  NUM
# ;  -  PUNCT
# German  -  ADJ
# since  -  SCONJ
# 2003  -  NUM
# ;  -  PUNCT
# Bulgarian  -  PROPN
# ,  -  PUNCT
# Danish  -  PROPN
# ,  -  PUNCT
# Japanese  -  ADJ
# ,  -  PUNCT
# Portuguese  -  ADJ
# ,  -  PUNCT
# Slovenian  -  PROPN
# ,  -  PUNCT
# Swedish  -  PROPN
# ,  -  PUNCT
# Turkish  -  ADJ
# since  -  SCONJ
# 2006  -  NUM
# ;  -  PUNCT
# Basque  -  PROPN
# ,  -  PUNCT
# Catalan  -  PROPN
# ,  -  PUNCT
# Chinese  -  PROPN
# ,  -  PUNCT
# Greek  -  PROPN
# ,  -  PUNCT
# Hungarian  -  ADJ
# ,  -  PUNCT
# Italian  -  ADJ
# ,  -  PUNCT
# Turkish  -  ADJ
# since  -  SCONJ
# 2007  -  NUM
# ;  -  PUNCT
# Czech  -  PROPN
# since  -  SCONJ
# 2009  -  NUM
# ;  -  PUNCT
# Arabic  -  PROPN
# since  -  SCONJ
# 2012  -  NUM
# ;  -  PUNCT
# 2017  -  NUM
# :  -  PUNCT
# 40  -  NUM
# +  -  NUM
# languages  -  NOUN
# ;  -  PUNCT
# 2018  -  NUM
# :  -  PUNCT
# 60+/100  -  NOUN
# +  -  NUM
# languages  -  NOUN
# )  -  PUNCT
#
#   -  SPACE
# •  -  VERB
# Elimination  -  PROPN
# of  -  ADP
# symbolic  -  ADJ
# representations  -  NOUN
# (  -  PUNCT
# rule  -  NOUN
# -  -  PUNCT
# based  -  VERB
# over  -  ADP
# supervised  -  VERB
# towards  -  ADP
# weakly  -  ADJ
# supervised  -  ADJ
# methods  -  NOUN
# ,  -  PUNCT
# representation  -  NOUN
# learning  -  NOUN
# and  -  CCONJ
# end  -  NOUN
# -  -  PUNCT
# to  -  ADP
# -  -  PUNCT
# end  -  NOUN
# systems  -  NOUN
# )  -  PUNCT
#
#
#   -  SPACE
# Most  -  ADV
# higher  -  ADJ
# -  -  PUNCT
# level  -  NOUN
# NLP  -  PROPN
# applications  -  NOUN
# involve  -  VERB
# aspects  -  NOUN
# that  -  PRON
# emulate  -  VERB
# intelligent  -  ADJ
# behavior  -  NOUN
# and  -  CCONJ
# apparent  -  ADJ
# comprehension  -  NOUN
# of  -  ADP
# natural  -  ADJ
# language  -  NOUN
# .  -  PUNCT
# More  -  ADV
# broadly  -  ADV
# speaking  -  VERB
# ,  -  PUNCT
# the  -  DET
# technical  -  ADJ
# operationalization  -  NOUN
# of  -  ADP
# increasingly  -  ADV
# advanced  -  ADJ
# aspects  -  NOUN
# of  -  ADP
# cognitive  -  ADJ
# behavior  -  NOUN
# represents  -  VERB
# one  -  NUM
# of  -  ADP
# the  -  DET
# developmental  -  ADJ
# trajectories  -  NOUN
# of  -  ADP
# NLP  -  PROPN
# (  -  PUNCT
# see  -  VERB
# trends  -  NOUN
# among  -  ADP
# CoNLL  -  NOUN
# shared  -  VERB
# tasks  -  NOUN
# above  -  ADP
# )  -  PUNCT
# .  -  PUNCT
#
#
#   -  SPACE
# Cognition  -  NOUN
# refers  -  VERB
# to  -  ADP
# "  -  PUNCT
# the  -  DET
# mental  -  ADJ
# action  -  NOUN
# or  -  CCONJ
# process  -  NOUN
# of  -  ADP
# acquiring  -  VERB
# knowledge  -  NOUN
# and  -  CCONJ
# understanding  -  NOUN
# through  -  ADP
# thought  -  NOUN
# ,  -  PUNCT
# experience  -  NOUN
# ,  -  PUNCT
# and  -  CCONJ
# the  -  DET
# senses  -  NOUN
# .  -  PUNCT
# "[50  -  PUNCT
# ]  -  X
# Cognitive  -  ADJ
# science  -  NOUN
# is  -  AUX
# the  -  DET
# interdisciplinary  -  NOUN
# ,  -  PUNCT
# scientific  -  ADJ
# study  -  NOUN
# of  -  ADP
# the  -  DET
# mind  -  NOUN
# and  -  CCONJ
# its  -  PRON
# processes.[51  -  PROPN
# ]  -  PUNCT
# Cognitive  -  ADJ
# linguistics  -  NOUN
# is  -  AUX
# an  -  DET
# interdisciplinary  -  ADJ
# branch  -  NOUN
# of  -  ADP
# linguistics  -  NOUN
# ,  -  PUNCT
# combining  -  VERB
# knowledge  -  NOUN
# and  -  CCONJ
# research  -  NOUN
# from  -  ADP
# both  -  DET
# psychology  -  NOUN
# and  -  CCONJ
# linguistics.[52  -  PROPN
# ]  -  X
# Especially  -  ADV
# during  -  ADP
# the  -  DET
# age  -  NOUN
# of  -  ADP
# symbolic  -  ADJ
# NLP  -  PROPN
# ,  -  PUNCT
# the  -  DET
# area  -  NOUN
# of  -  ADP
# computational  -  ADJ
# linguistics  -  NOUN
# maintained  -  VERB
# strong  -  ADJ
# ties  -  NOUN
# with  -  ADP
# cognitive  -  ADJ
# studies  -  NOUN
# .  -  PUNCT
#
#
#   -  SPACE
# As  -  ADP
# an  -  DET
# example  -  NOUN
# ,  -  PUNCT
# George  -  PROPN
# Lakoff  -  PROPN
# offers  -  VERB
# a  -  DET
# methodology  -  NOUN
# to  -  PART
# build  -  VERB
# natural  -  ADJ
# language  -  NOUN
# processing  -  NOUN
# (  -  PUNCT
# NLP  -  PROPN
# )  -  PUNCT
# algorithms  -  VERB
# through  -  ADP
# the  -  DET
# perspective  -  NOUN
# of  -  ADP
# cognitive  -  ADJ
# science  -  NOUN
# ,  -  PUNCT
# along  -  ADP
# with  -  ADP
# the  -  DET
# findings  -  NOUN
# of  -  ADP
# cognitive  -  ADJ
# linguistics,[53  -  NOUN
# ]  -  PUNCT
# with  -  ADP
# two  -  NUM
# defining  -  ADJ
# aspects  -  NOUN
# :  -  PUNCT
#
#   -  SPACE
# •  -  VERB
# Apply  -  VERB
# the  -  DET
# theory  -  NOUN
# of  -  ADP
# conceptual  -  ADJ
# metaphor  -  NOUN
# ,  -  PUNCT
# explained  -  VERB
# by  -  ADP
# Lakoff  -  PROPN
# as  -  ADP
# "  -  PUNCT
# the  -  DET
# understanding  -  NOUN
# of  -  ADP
# one  -  NUM
# idea  -  NOUN
# ,  -  PUNCT
# in  -  ADP
# terms  -  NOUN
# of  -  ADP
# another  -  PRON
# "  -  PUNCT
# which  -  PRON
# provides  -  VERB
# an  -  DET
# idea  -  NOUN
# of  -  ADP
# the  -  DET
# intent  -  NOUN
# of  -  ADP
# the  -  DET
# author  -  NOUN
# .  -  PUNCT
# 54  -  NUM
# For  -  ADP
# example  -  NOUN
# ,  -  PUNCT
# consider  -  VERB
# the  -  DET
# English  -  ADJ
# word  -  NOUN
# big  -  ADJ
# .  -  PUNCT
# When  -  SCONJ
# used  -  VERB
# in  -  ADP
# a  -  DET
# comparison  -  NOUN
# (  -  PUNCT
# "  -  PUNCT
# That  -  PRON
# is  -  AUX
# a  -  DET
# big  -  ADJ
# tree  -  NOUN
# "  -  PUNCT
# )  -  PUNCT
# ,  -  PUNCT
# the  -  DET
# author  -  NOUN
# 's  -  PART
# intent  -  NOUN
# is  -  AUX
# to  -  PART
# imply  -  VERB
# that  -  SCONJ
# the  -  DET
# tree  -  NOUN
# is  -  AUX
# physically  -  ADV
# large  -  ADJ
# relative  -  NOUN
# to  -  ADP
# other  -  ADJ
# trees  -  NOUN
# or  -  CCONJ
# the  -  DET
# authors  -  NOUN
# experience  -  NOUN
# .  -  PUNCT
# When  -  SCONJ
# used  -  VERB
# metaphorically  -  ADV
# (  -  PUNCT
# "  -  PUNCT
# Tomorrow  -  NOUN
# is  -  AUX
# a  -  DET
# big  -  ADJ
# day  -  NOUN
# "  -  PUNCT
# )  -  PUNCT
# ,  -  PUNCT
# the  -  DET
# author  -  NOUN
# 's  -  PART
# intent  -  NOUN
# to  -  PART
# imply  -  VERB
# importance  -  NOUN
# .  -  PUNCT
# The  -  DET
# intent  -  NOUN
# behind  -  ADP
# other  -  ADJ
# usages  -  NOUN
# ,  -  PUNCT
# like  -  ADP
# in  -  ADP
# "  -  PUNCT
# She  -  PRON
# is  -  AUX
# a  -  DET
# big  -  ADJ
# person  -  NOUN
# "  -  PUNCT
# ,  -  PUNCT
# will  -  AUX
# remain  -  VERB
# somewhat  -  ADV
# ambiguous  -  ADJ
# to  -  ADP
# a  -  DET
# person  -  NOUN
# and  -  CCONJ
# a  -  DET
# cognitive  -  ADJ
# NLP  -  PROPN
# algorithm  -  PROPN
# alike  -  ADV
# without  -  ADP
# additional  -  ADJ
# information  -  NOUN
# .  -  PUNCT
#
#   -  SPACE
# •  -  VERB
# Assign  -  ADJ
# relative  -  ADJ
# measures  -  NOUN
# of  -  ADP
# meaning  -  NOUN
# to  -  ADP
# a  -  DET
# word  -  NOUN
# ,  -  PUNCT
# phrase  -  NOUN
# ,  -  PUNCT
# sentence  -  NOUN
# or  -  CCONJ
# piece  -  NOUN
# of  -  ADP
# text  -  NOUN
# based  -  VERB
# on  -  ADP
# the  -  DET
# information  -  NOUN
# presented  -  VERB
# before  -  ADP
# and  -  CCONJ
# after  -  ADP
# the  -  DET
# piece  -  NOUN
# of  -  ADP
# text  -  NOUN
# being  -  AUX
# analyzed  -  VERB
# ,  -  PUNCT
# e.g.  -  ADV
# ,  -  PUNCT
# by  -  ADP
# means  -  NOUN
# of  -  ADP
# a  -  DET
# probabilistic  -  ADJ
# context  -  NOUN
# -  -  PUNCT
# free  -  ADJ
# grammar  -  NOUN
# (  -  PUNCT
# PCFG  -  PROPN
# )  -  PUNCT
# .  -  PUNCT
# The  -  DET
# mathematical  -  ADJ
# equation  -  NOUN
# for  -  ADP
# such  -  ADJ
# algorithms  -  NOUN
# is  -  AUX
# presented  -  VERB
# in  -  ADP
# US  -  PROPN
# Patent  -  PROPN
# 9269353  -  NUM
# :  -  PUNCT
# 55  -  NUM
#
#
#   -  SPACE
# Ties  -  NOUN
# with  -  ADP
# cognitive  -  ADJ
# linguistics  -  NOUN
# are  -  AUX
# part  -  NOUN
# of  -  ADP
# the  -  DET
# historical  -  ADJ
# heritage  -  NOUN
# of  -  ADP
# NLP  -  PROPN
# ,  -  PUNCT
# but  -  CCONJ
# they  -  PRON
# have  -  AUX
# been  -  AUX
# less  -  ADV
# frequently  -  ADV
# addressed  -  VERB
# since  -  SCONJ
# the  -  DET
# statistical  -  ADJ
# turn  -  NOUN
# during  -  ADP
# the  -  DET
# 1990s  -  NUM
# .  -  PUNCT
# Nevertheless  -  ADV
# ,  -  PUNCT
# approaches  -  VERB
# to  -  PART
# develop  -  VERB
# cognitive  -  ADJ
# models  -  NOUN
# towards  -  ADP
# technically  -  ADV
# operationalizable  -  ADJ
# frameworks  -  NOUN
# have  -  AUX
# been  -  AUX
# pursued  -  VERB
# in  -  ADP
# the  -  DET
# context  -  NOUN
# of  -  ADP
# various  -  ADJ
# frameworks  -  NOUN
# ,  -  PUNCT
# e.g.  -  ADV
# ,  -  PUNCT
# of  -  ADP
# cognitive  -  ADJ
# grammar,[56  -  PROPN
# ]  -  PUNCT
# functional  -  ADJ
# grammar,[57  -  PROPN
# ]  -  PUNCT
# construction  -  NOUN
# grammar,[58  -  PROPN
# ]  -  PUNCT
# computational  -  ADJ
# psycholinguistics  -  NOUN
# and  -  CCONJ
# cognitive  -  ADJ
# neuroscience  -  NOUN
# (  -  PUNCT
# e.g.  -  ADV
# ,  -  PUNCT
# ACT  -  PROPN
# -  -  PUNCT
# R  -  PROPN
# )  -  PUNCT
# ,  -  PUNCT
# however  -  ADV
# ,  -  PUNCT
# with  -  ADP
# limited  -  ADJ
# uptake  -  NOUN
# in  -  ADP
# mainstream  -  ADJ
# NLP  -  PROPN
# (  -  PUNCT
# as  -  SCONJ
# measured  -  VERB
# by  -  ADP
# presence  -  NOUN
# on  -  ADP
# major  -  ADJ
# conferences[59  -  NOUN
# ]  -  PUNCT
# of  -  ADP
# the  -  DET
# ACL  -  PROPN
# )  -  PUNCT
# .  -  PUNCT
# More  -  ADV
# recently  -  ADV
# ,  -  PUNCT
# ideas  -  NOUN
# of  -  ADP
# cognitive  -  ADJ
# NLP  -  PROPN
# have  -  AUX
# been  -  AUX
# revived  -  VERB
# as  -  ADP
# an  -  DET
# approach  -  NOUN
# to  -  PART
# achieve  -  VERB
# explainability  -  NOUN
# ,  -  PUNCT
# e.g.  -  ADV
# ,  -  PUNCT
# under  -  ADP
# the  -  DET
# notion  -  NOUN
# of  -  ADP
# "  -  PUNCT
# cognitive  -  ADJ
# AI".[60  -  PROPN
# ]  -  PUNCT
# Likewise  -  ADV
# ,  -  PUNCT
# ideas  -  NOUN
# of  -  ADP
# cognitive  -  ADJ
# NLP  -  PROPN
# are  -  AUX
# inherent  -  ADJ
# to  -  ADP
# neural  -  ADJ
# models  -  NOUN
# multimodal  -  VERB
# NLP  -  PROPN
# (  -  PUNCT
# although  -  SCONJ
# rarely  -  ADV
# made  -  VERB
# explicit)[61  -  NOUN
# ]  -  PUNCT
# and  -  CCONJ
# developments  -  NOUN
# in  -  ADP
# artificial  -  ADJ
# intelligence  -  NOUN
# ,  -  PUNCT
# specifically  -  ADV
# tools  -  NOUN
# and  -  CCONJ
# technologies  -  NOUN
# using  -  VERB
# large  -  ADJ
# language  -  NOUN
# model  -  NOUN
# approaches[62  -  PROPN
# ]  -  PUNCT
# and  -  CCONJ
# new  -  ADJ
# directions  -  NOUN
# in  -  ADP
# artificial  -  ADJ
# general  -  ADJ
# intelligence  -  NOUN
# based  -  VERB
# on  -  ADP
# the  -  DET
# free  -  ADJ
# energy  -  NOUN
# principle[63  -  NOUN
# ]  -  PUNCT
# by  -  ADP
# British  -  ADJ
# neuroscientist  -  NOUN
# and  -  CCONJ
# theoretician  -  PROPN
# at  -  ADP
# University  -  PROPN
# College  -  PROPN
# London  -  PROPN
# Karl  -  PROPN
# J.  -  PROPN
# Friston  -  PROPN
# .  -  PUNCT

# %%
from spacy import displacy
displacy.render(document, style = 'ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Natural language processing (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) is the processing of natural language information by a computer.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is a subfield of computer science and is closely associated with artificial intelligence.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is also related to information retrieval, knowledge representation, computational linguistics, and linguistics more broadly.[1]<br><br>Major processing tasks in an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  system include: speech recognition, text classification, natural language understanding, and natural language generation.<br><br>Natural language processing has its roots in the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1950s.[2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ] Already in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1950
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alan Turing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  published an article titled
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     &quot;Computing Machinery and Intelligence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# &quot; which proposed what is now called the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Turing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  test as a criterion of intelligence, though at the time that was not articulated as a problem separate from artificial intelligence. The proposed test includes a task that involves the automated interpretation and generation of natural language.<br><br>The premise of symbolic
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is often illustrated using
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     John Searle's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  room thought experiment: Given a collection of rules (e.g., a
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  phrasebook, with questions and matching answers), the computer emulates natural language understanding (or other
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  tasks) by applying those rules to the data it confronts.<br>•
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1950s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# : The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Georgetown
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  experiment in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1954
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  involved fully automatic translation of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than sixty
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  sentences into
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     English
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LANGUAGE</span>
# </mark>
# . The authors claimed that within
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three or five years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , machine translation would be a solved problem.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight:

# %%
for entity in document.ents:
  if entity.label_ == 'PERSON':
    print(entity.text)
# Out:
# Alan Turing
# John Searle's
# Joseph Weizenbaum
# Ross Quillian's
# SAM
# Wilensky
# QUALM
# Lehnert
# Carbonell
# Lehnert
# Lesk algorithm
# Racter
# Jabberwacky
# Moore
# Bengio
# Symbolic
# Markov
# George Lakoff
# Lakoff
# Karl J. Friston

# %% [markdown]
# # Most frequent words

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/michalek/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/michalek/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
tokens = nltk.tokenize.word_tokenize(article.cleaned_text)

# %%
tokens
# Out:
# ['Natural',
#  'language',
#  'processing',
#  '(',
#  'NLP',
#  ')',
#  'is',
#  'the',
#  'processing',
#  'of',
#  'natural',
#  'language',
#  'information',
#  'by',
#  'a',
#  'computer',
#  '.',
#  'NLP',
#  'is',
#  'a',
#  'subfield',
#  'of',
#  'computer',
#  'science',
#  'and',
#  'is',
#  'closely',
#  'associated',
#  'with',
#  'artificial',
#  'intelligence',
#  '.',
#  'NLP',
#  'is',
#  'also',
#  'related',
#  'to',
#  'information',
#  'retrieval',
#  ',',
#  'knowledge',
#  'representation',
#  ',',
#  'computational',
#  'linguistics',
#  ',',
#  'and',
#  'linguistics',
#  'more',
#  'broadly',
#  '.',
#  '[',
#  '1',
#  ']',
#  'Major',
#  'processing',
#  'tasks',
#  'in',
#  'an',
#  'NLP',
#  'system',
#  'include',
#  ':',
#  'speech',
#  'recognition',
#  ',',
#  'text',
#  'classification',
#  ',',
#  'natural',
#  'language',
#  'understanding',
#  ',',
#  'and',
#  'natural',
#  'language',
#  'generation',
#  '.',
#  'Natural',
#  'language',
#  'processing',
#  'has',
#  'its',
#  'roots',
#  'in',
#  'the',
#  '1950s',
#  '.',
#  '[',
#  '2',
#  ']',
#  'Already',
#  'in',
#  '1950',
#  ',',
#  'Alan',
#  'Turing',
#  'published',
#  'an',
#  'article',
#  'titled',
#  '``',
#  'Computing',
#  'Machinery',
#  'and',
#  'Intelligence',
#  "''",
#  'which',
#  'proposed',
#  'what',
#  'is',
#  'now',
#  'called',
#  'the',
#  'Turing',
#  'test',
#  'as',
#  'a',
#  'criterion',
#  'of',
#  'intelligence',
#  ',',
#  'though',
#  'at',
#  'the',
#  'time',
#  'that',
#  'was',
#  'not',
#  'articulated',
#  'as',
#  'a',
#  'problem',
#  'separate',
#  'from',
#  'artificial',
#  'intelligence',
#  '.',
#  'The',
#  'proposed',
#  'test',
#  'includes',
#  'a',
#  'task',
#  'that',
#  'involves',
#  'the',
#  'automated',
#  'interpretation',
#  'and',
#  'generation',
#  'of',
#  'natural',
#  'language',
#  '.',
#  'The',
#  'premise',
#  'of',
#  'symbolic',
#  'NLP',
#  'is',
#  'often',
#  'illustrated',
#  'using',
#  'John',
#  'Searle',
#  "'s",
#  'Chinese',
#  'room',
#  'thought',
#  'experiment',
#  ':',
#  'Given',
#  'a',
#  'collection',
#  'of',
#  'rules',
#  '(',
#  'e.g.',
#  ',',
#  'a',
#  'Chinese',
#  'phrasebook',
#  ',',
#  'with',
#  'questions',
#  'and',
#  'matching',
#  'answers',
#  ')',
#  ',',
#  'the',
#  'computer',
#  'emulates',
#  'natural',
#  'language',
#  'understanding',
#  '(',
#  'or',
#  'other',
#  'NLP',
#  'tasks',
#  ')',
#  'by',
#  'applying',
#  'those',
#  'rules',
#  'to',
#  'the',
#  'data',
#  'it',
#  'confronts',
#  '.',
#  '•',
#  '1950s',
#  ':',
#  'The',
#  'Georgetown',
#  'experiment',
#  'in',
#  '1954',
#  'involved',
#  'fully',
#  'automatic',
#  'translation',
#  'of',
#  'more',
#  'than',
#  'sixty',
#  'Russian',
#  'sentences',
#  'into',
#  'English',
#  '.',
#  'The',
#  'authors',
#  'claimed',
#  'that',
#  'within',
#  'three',
#  'or',
#  'five',
#  'years',
#  ',',
#  'machine',
#  'translation',
#  'would',
#  'be',
#  'a',
#  'solved',
#  'problem',
#  '.',
#  '3',
#  'However',
#  ',',
#  'real',
#  'progress',
#  'was',
#  'much',
#  'slower',
#  ',',
#  'and',
#  'after',
#  'the',
#  'ALPAC',
#  'report',
#  'in',
#  '1966',
#  ',',
#  'which',
#  'found',
#  'that',
#  'ten',
#  'years',
#  'of',
#  'research',
#  'had',
#  'failed',
#  'to',
#  'fulfill',
#  'the',
#  'expectations',
#  ',',
#  'funding',
#  'for',
#  'machine',
#  'translation',
#  'was',
#  'dramatically',
#  'reduced',
#  '.',
#  'Little',
#  'further',
#  'research',
#  'in',
#  'machine',
#  'translation',
#  'was',
#  'conducted',
#  'in',
#  'America',
#  '(',
#  'though',
#  'some',
#  'research',
#  'continued',
#  'elsewhere',
#  ',',
#  'such',
#  'as',
#  'Japan',
#  'and',
#  'Europe',
#  '4',
#  ')',
#  'until',
#  'the',
#  'late',
#  '1980s',
#  'when',
#  'the',
#  'first',
#  'statistical',
#  'machine',
#  'translation',
#  'systems',
#  'were',
#  'developed',
#  '.',
#  '•',
#  '1960s',
#  ':',
#  'Some',
#  'notably',
#  'successful',
#  'natural',
#  'language',
#  'processing',
#  'systems',
#  'developed',
#  'in',
#  'the',
#  '1960s',
#  'were',
#  'SHRDLU',
#  ',',
#  'a',
#  'natural',
#  'language',
#  'system',
#  'working',
#  'in',
#  'restricted',
#  '``',
#  'blocks',
#  'worlds',
#  "''",
#  'with',
#  'restricted',
#  'vocabularies',
#  ',',
#  'and',
#  'ELIZA',
#  ',',
#  'a',
#  'simulation',
#  'of',
#  'a',
#  'Rogerian',
#  'psychotherapy',
#  ',',
#  'written',
#  'by',
#  'Joseph',
#  'Weizenbaum',
#  'between',
#  '1964',
#  'and',
#  '1966',
#  '.',
#  'Despite',
#  'using',
#  'minimal',
#  'information',
#  'about',
#  'human',
#  'thought',
#  'or',
#  'emotion',
#  ',',
#  'ELIZA',
#  'was',
#  'able',
#  'to',
#  'produce',
#  'interactions',
#  'that',
#  'appeared',
#  'human-like',
#  '.',
#  'When',
#  'the',
#  '``',
#  'patient',
#  "''",
#  'exceeded',
#  'the',
#  'very',
#  'small',
#  'knowledge',
#  'base',
#  ',',
#  'ELIZA',
#  'might',
#  'provide',
#  'a',
#  'generic',
#  'response',
#  ',',
#  'for',
#  'example',
#  ',',
#  'responding',
#  'to',
#  '``',
#  'My',
#  'head',
#  'hurts',
#  "''",
#  'with',
#  '``',
#  'Why',
#  'do',
#  'you',
#  'say',
#  'your',
#  'head',
#  'hurts',
#  '?',
#  "''",
#  '.',
#  'Ross',
#  'Quillian',
#  "'s",
#  'successful',
#  'work',
#  'on',
#  'natural',
#  'language',
#  'was',
#  'demonstrated',
#  'with',
#  'a',
#  'vocabulary',
#  'of',
#  'only',
#  'twenty',
#  'words',
#  ',',
#  'because',
#  'that',
#  'was',
#  'all',
#  'that',
#  'would',
#  'fit',
#  'in',
#  'a',
#  'computer',
#  'memory',
#  'at',
#  'the',
#  'time',
#  '.',
#  '5',
#  '•',
#  '1970s',
#  ':',
#  'During',
#  'the',
#  '1970s',
#  ',',
#  'many',
#  'programmers',
#  'began',
#  'to',
#  'write',
#  '``',
#  'conceptual',
#  'ontologies',
#  "''",
#  ',',
#  'which',
#  'structured',
#  'real-world',
#  'information',
#  'into',
#  'computer-understandable',
#  'data',
#  '.',
#  'Examples',
#  'are',
#  'MARGIE',
#  '(',
#  'Schank',
#  ',',
#  '1975',
#  ')',
#  ',',
#  'SAM',
#  '(',
#  'Cullingford',
#  ',',
#  '1978',
#  ')',
#  ',',
#  'PAM',
#  '(',
#  'Wilensky',
#  ',',
#  '1978',
#  ')',
#  ',',
#  'TaleSpin',
#  '(',
#  'Meehan',
#  ',',
#  '1976',
#  ')',
#  ',',
#  'QUALM',
#  '(',
#  'Lehnert',
#  ',',
#  '1977',
#  ')',
#  ',',
#  'Politics',
#  '(',
#  'Carbonell',
#  ',',
#  '1979',
#  ')',
#  ',',
#  'and',
#  'Plot',
#  'Units',
#  '(',
#  'Lehnert',
#  '1981',
#  ')',
#  '.',
#  'During',
#  'this',
#  'time',
#  ',',
#  'the',
#  'first',
#  'chatterbots',
#  'were',
#  'written',
#  '(',
#  'e.g.',
#  ',',
#  'PARRY',
#  ')',
#  '.',
#  '•',
#  '1980s',
#  ':',
#  'The',
#  '1980s',
#  'and',
#  'early',
#  '1990s',
#  'mark',
#  'the',
#  'heyday',
#  'of',
#  'symbolic',
#  'methods',
#  'in',
#  'NLP',
#  '.',
#  'Focus',
#  'areas',
#  'of',
#  'the',
#  'time',
#  'included',
#  'research',
#  'on',
#  'rule-based',
#  'parsing',
#  '(',
#  'e.g.',
#  ',',
#  'the',
#  'development',
#  'of',
#  'HPSG',
#  'as',
#  'a',
#  'computational',
#  'operationalization',
#  'of',
#  'generative',
#  'grammar',
#  ')',
#  ',',
#  'morphology',
#  '(',
#  'e.g.',
#  ',',
#  'two-level',
#  'morphology',
#  '6',
#  ')',
#  ',',
#  'semantics',
#  '(',
#  'e.g.',
#  ',',
#  'Lesk',
#  'algorithm',
#  ')',
#  ',',
#  'reference',
#  '(',
#  'e.g.',
#  ',',
#  'within',
#  'Centering',
#  'Theory',
#  '7',
#  ')',
#  'and',
#  'other',
#  'areas',
#  'of',
#  'natural',
#  'language',
#  'understanding',
#  '(',
#  'e.g.',
#  ',',
#  'in',
#  'the',
#  'Rhetorical',
#  'Structure',
#  'Theory',
#  ')',
#  '.',
#  'Other',
#  'lines',
#  'of',
#  'research',
#  'were',
#  'continued',
#  ',',
#  'e.g.',
#  ',',
#  'the',
#  'development',
#  'of',
#  'chatterbots',
#  'with',
#  'Racter',
#  'and',
#  'Jabberwacky',
#  '.',
#  'An',
#  'important',
#  'development',
#  '(',
#  'that',
#  'eventually',
#  'led',
#  'to',
#  'the',
#  'statistical',
#  'turn',
#  'in',
#  'the',
#  '1990s',
#  ')',
#  'was',
#  'the',
#  'rising',
#  'importance',
#  'of',
#  'quantitative',
#  'evaluation',
#  'in',
#  'this',
#  'period',
#  '.',
#  '8',
#  'Up',
#  'until',
#  'the',
#  '1980s',
#  ',',
#  'most',
#  'natural',
#  'language',
#  'processing',
#  'systems',
#  'were',
#  'based',
#  'on',
#  'complex',
#  'sets',
#  'of',
#  'hand-written',
#  'rules',
#  '.',
#  'Starting',
#  'in',
#  'the',
#  'late',
#  '1980s',
#  ',',
#  'however',
#  ',',
#  'there',
#  'was',
#  'a',
#  'revolution',
#  'in',
#  'natural',
#  'language',
#  'processing',
#  'with',
#  'the',
#  'introduction',
#  'of',
#  'machine',
#  'learning',
#  'algorithms',
#  'for',
#  'language',
#  'processing',
#  '.',
#  'This',
#  'shift',
#  'was',
#  'influenced',
#  'by',
#  'increasing',
#  'computational',
#  'power',
#  '(',
#  'see',
#  'Moore',
#  "'s",
#  'law',
#  ')',
#  'and',
#  'a',
#  'decline',
#  'in',
#  'the',
#  'dominance',
#  'of',
#  'Chomskyan',
#  'linguistic',
#  'theories',
#  '...',
#  '(',
#  'e.g',
#  '.',
#  'transformational',
#  'grammar',
#  ')',
#  ',',
#  'whose',
#  'theoretical',
#  'underpinnings',
#  'discouraged',
#  'the',
#  'sort',
#  'of',
#  'corpus',
#  'linguistics',
#  'that',
#  'underlies',
#  'the',
#  'machine-learning',
#  'approach',
#  'to',
#  'language',
#  'processing',
#  '.',
#  '[',
#  '9',
#  ']',
#  '•',
#  '1990s',
#  ':',
#  'Many',
#  'of',
#  'the',
#  'notable',
#  'early',
#  'successes',
#  'in',
#  'statistical',
#  'methods',
#  'in',
#  'NLP',
#  'occurred',
#  'in',
#  'the',
#  'field',
#  'of',
#  'machine',
#  'translation',
#  ',',
#  'due',
#  'especially',
#  'to',
#  'work',
#  'at',
#  'IBM',
#  'Research',
#  ',',
#  'such',
#  'as',
#  'IBM',
#  'alignment',
#  'models',
#  '.',
#  'These',
#  'systems',
#  'were',
#  'able',
#  'to',
#  'take',
#  'advantage',
#  'of',
#  'existing',
#  'multilingual',
#  'textual',
#  'corpora',
#  'that',
#  'had',
#  'been',
#  'produced',
#  'by',
#  'the',
#  'Parliament',
#  'of',
#  'Canada',
#  'and',
#  'the',
#  'European',
#  'Union',
#  'as',
#  'a',
#  'result',
#  'of',
#  'laws',
#  'calling',
#  'for',
#  'the',
#  'translation',
#  'of',
#  'all',
#  'governmental',
#  'proceedings',
#  'into',
#  'all',
#  'official',
#  'languages',
#  'of',
#  'the',
#  'corresponding',
#  'systems',
#  'of',
#  'government',
#  '.',
#  'However',
#  ',',
#  'many',
#  'systems',
#  'relied',
#  'on',
#  'corpora',
#  'that',
#  'were',
#  'specifically',
#  'developed',
#  'for',
#  'the',
#  'tasks',
#  'they',
#  'were',
#  'designed',
#  'to',
#  'perform',
#  '.',
#  'This',
#  'reliance',
#  'has',
#  'been',
#  'a',
#  'major',
#  'limitation',
#  'to',
#  'their',
#  'broader',
#  'effectiveness',
#  'and',
#  'continues',
#  'to',
#  'affect',
#  'similar',
#  'systems',
#  '.',
#  'Consequently',
#  ',',
#  'significant',
#  'research',
#  'has',
#  'focused',
#  'on',
#  'methods',
#  'for',
#  'learning',
#  'effectively',
#  'from',
#  'limited',
#  'amounts',
#  'of',
#  'data',
#  '.',
#  '•',
#  '2000s',
#  ':',
#  'With',
#  'the',
#  'growth',
#  'of',
#  'the',
#  'web',
#  ',',
#  'increasing',
#  'amounts',
#  'of',
#  'raw',
#  '(',
#  'unannotated',
#  ')',
#  'language',
#  'data',
#  'have',
#  'become',
#  'available',
#  'since',
#  'the',
#  'mid-1990s',
#  '.',
#  'Research',
#  'has',
#  'thus',
#  'increasingly',
#  'focused',
#  'on',
#  'unsupervised',
#  'and',
#  'semi-supervised',
#  'learning',
#  'algorithms',
#  '.',
#  'Such',
#  'algorithms',
#  'can',
#  'learn',
#  'from',
#  'data',
#  'that',
#  'has',
#  'not',
#  'been',
#  'hand-annotated',
#  'with',
#  'the',
#  'desired',
#  'answers',
#  'or',
#  'using',
#  'a',
#  'combination',
#  'of',
#  'annotated',
#  'and',
#  'non-annotated',
#  'data',
#  '.',
#  ...]

# %%
len(tokens)
# Out:
# 2516

# %%
frequency = nltk.FreqDist(tokens)
most_common = frequency.most_common(50)
most_common
# Out:
# [(',', 166),
#  ('the', 106),
#  ('of', 90),
#  ('.', 77),
#  ('and', 51),
#  ('in', 43),
#  ('a', 42),
#  ('to', 41),
#  ('(', 39),
#  (')', 39),
#  ('language', 27),
#  ('NLP', 23),
#  ('is', 23),
#  ('[', 22),
#  (']', 22),
#  ('that', 20),
#  ('for', 19),
#  ('by', 18),
#  ('with', 18),
#  ('•', 18),
#  ('natural', 17),
#  (':', 17),
#  ('e.g.', 17),
#  ('on', 15),
#  ('processing', 13),
#  ('``', 13),
#  ('as', 13),
#  ('or', 13),
#  ('was', 12),
#  ('statistical', 12),
#  ('cognitive', 12),
#  ("''", 11),
#  ('machine', 11),
#  ('systems', 11),
#  ('tasks', 10),
#  ('translation', 10),
#  ('methods', 10),
#  ('linguistics', 9),
#  ('The', 9),
#  ('data', 9),
#  ('were', 9),
#  ('are', 9),
#  ('learning', 9),
#  ('since', 9),
#  ('more', 8),
#  ('which', 8),
#  ('rules', 8),
#  ('such', 8),
#  ('rule-based', 8),
#  ('approach', 8)]

# %% [markdown]
# # Word cloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
cloud = WordCloud()
cloud = cloud.generate(article.cleaned_text)
plt.figure(figsize=(15,15))
plt.imshow(cloud)
# plt.axis('off');?

# %% [markdown]
# # Preprocessing the texts (frequency and word cloud)

# %%
def preprocessing(sentence):
  # a A
  sentence = sentence.lower()
  sentence = sentence.replace('.', '')
  tokens = []
  tokens = [token.text for token in nlp(sentence) if not (token.is_stop or token.like_num or token.is_punct or token.is_space or len(token) == 1)]
  tokens = ' '.join([element for element in tokens])

  return tokens

# %%
preprocessing('TesT natural language processing it the 1 10 50 ! . ,       1.  b ')
# Out:
# 'test natural language processing'

# %%
article_cleaned = preprocessing(article.cleaned_text)
article_cleaned
# Out:
# 'natural language processing nlp processing natural language information computer nlp subfield computer science closely associated artificial intelligence nlp related information retrieval knowledge representation computational linguistics linguistics broadly[1 major processing tasks nlp system include speech recognition text classification natural language understanding natural language generation natural language processing roots 1950s[2 alan turing published article titled computing machinery intelligence proposed called turing test criterion intelligence time articulated problem separate artificial intelligence proposed test includes task involves automated interpretation generation natural language premise symbolic nlp illustrated john searle chinese room thought experiment given collection rules eg chinese phrasebook questions matching answers computer emulates natural language understanding nlp tasks applying rules data confronts 1950s georgetown experiment involved fully automatic translation russian sentences english authors claimed years machine translation solved problem real progress slower alpac report found years research failed fulfill expectations funding machine translation dramatically reduced little research machine translation conducted america research continued japan europe late 1980s statistical machine translation systems developed 1960s notably successful natural language processing systems developed 1960s shrdlu natural language system working restricted blocks worlds restricted vocabularies eliza simulation rogerian psychotherapy written joseph weizenbaum despite minimal information human thought emotion eliza able produce interactions appeared human like patient exceeded small knowledge base eliza provide generic response example responding head hurts head hurts ross quillian successful work natural language demonstrated vocabulary words fit computer memory time 1970s 1970s programmers began write conceptual ontologies structured real world information computer understandable data examples margie schank sam cullingford pam wilensky talespin meehan qualm lehnert politics carbonell plot units lehnert time chatterbots written eg parry 1980s 1980s early 1990s mark heyday symbolic methods nlp focus areas time included research rule based parsing eg development hpsg computational operationalization generative grammar morphology eg level morphology semantics eg lesk algorithm reference eg centering theory areas natural language understanding eg rhetorical structure theory lines research continued eg development chatterbots racter jabberwacky important development eventually led statistical turn 1990s rising importance quantitative evaluation period 1980s natural language processing systems based complex sets hand written rules starting late 1980s revolution natural language processing introduction machine learning algorithms language processing shift influenced increasing computational power moore law decline dominance chomskyan linguistic theories eg transformational grammar theoretical underpinnings discouraged sort corpus linguistics underlies machine learning approach language processing[9 1990s notable early successes statistical methods nlp occurred field machine translation especially work ibm research ibm alignment models systems able advantage existing multilingual textual corpora produced parliament canada european union result laws calling translation governmental proceedings official languages corresponding systems government systems relied corpora specifically developed tasks designed perform reliance major limitation broader effectiveness continues affect similar systems consequently significant research focused methods learning effectively limited amounts data 2000s growth web increasing amounts raw unannotated language data available mid-1990s research increasingly focused unsupervised semi supervised learning algorithms algorithms learn data hand annotated desired answers combination annot ...

# %%
len(article.cleaned_text), len(article_cleaned)
# Out:
# (14201, 10004)

# %%
tokens = nltk.tokenize.word_tokenize(article_cleaned)
frequency = nltk.FreqDist(nltk.tokenize.word_tokenize(article_cleaned))
most_common = frequency.most_common(20)
most_common
# Out:
# [('language', 27),
#  ('nlp', 23),
#  ('[', 22),
#  ('eg', 20),
#  ('natural', 19),
#  ('processing', 14),
#  ('based', 14),
#  ('cognitive', 14),
#  ('machine', 13),
#  ('statistical', 12),
#  ('tasks', 11),
#  ('systems', 11),
#  ('translation', 10),
#  ('methods', 10),
#  ('learning', 10),
#  ('linguistics', 9),
#  ('data', 9),
#  ('research', 9),
#  ('rules', 8),
#  ('rule', 8)]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
cloud = WordCloud()
cloud = cloud.generate(article_cleaned)
plt.figure(figsize=(15,15))
plt.imshow(cloud)
plt.axis('off');

# %% [markdown]
# # Text summarization

# %%
# !pip install sumy
# Out:
# Requirement already satisfied: sumy in /home/michalek/miniconda3/lib/python3.13/site-packages (0.12.0)
# Requirement already satisfied: breadability>=0.1.20 in /home/michalek/miniconda3/lib/python3.13/site-packages (from sumy) (0.1.20)
# Requirement already satisfied: docopt-ng>=0.6.1 in /home/michalek/miniconda3/lib/python3.13/site-packages (from sumy) (0.9.0)
# Requirement already satisfied: lxml-html-clean in /home/michalek/miniconda3/lib/python3.13/site-packages (from sumy) (0.4.4)
# Requirement already satisfied: nltk>=3.0.2 in /home/michalek/miniconda3/lib/python3.13/site-packages (from sumy) (3.9.3)
# Requirement already satisfied: pycountry>=18.2.23 in /home/michalek/miniconda3/lib/python3.13/site-packages (from sumy) (26.2.16)
# Requirement already satisfied: requests>=2.7.0 in /home/michalek/miniconda3/lib/python3.13/site-packages (from sumy) (2.32.5)
# Requirement already satisfied: setuptools>=65.0.0 in /home/michalek/miniconda3/lib/python3.13/site-packages (from sumy) (80.9.0)
# Requirement already satisfied: docopt<0.7,>=0.6.1 in /home/michalek/miniconda3/lib/python3.13/site-packages (from breadability>=0.1.20->sumy) (0.6.2)
# Requirement already satisfied: chardet in /home/michalek/miniconda3/lib/python3.13/site-packages (from breadability>=0.1.20->sumy) (7.0.1)
# Requirement already satisfied: lxml>=2.0 in /home/michalek/miniconda3/lib/python3.13/site-packages (from breadability>=0.1.20->sumy) (6.0.2)
# Requirement already satisfied: click in /home/michalek/miniconda3/lib/python3.13/site-packages (from nltk>=3.0.2->sumy) (8.2.1)
# Requirement already satisfied: joblib in /home/michalek/miniconda3/lib/python3.13/site-packages (from nltk>=3.0.2->sumy) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /home/michalek/miniconda3/lib/python3.13/site-packages (from nltk>=3.0.2->sumy) (2026.2.28)
# Requirement already satisfied: tqdm in /home/michalek/miniconda3/lib/python3.13/site-packages (from nltk>=3.0.2->sumy) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/michalek/miniconda3/lib/python3.13/site-packages (from requests>=2.7.0->sumy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/michalek/miniconda3/lib/python3.13/site-packages (from requests>=2.7.0->sumy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/michalek/miniconda3/lib/python3.13/site-packages (from requests>=2.7.0->sumy) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/michalek/miniconda3/lib/python3.13/site-packages (from requests>=2.7.0->sumy) (2026.2.25)

# %%
article.cleaned_text
# Out:
# 'Natural language processing (NLP) is the processing of natural language information by a computer. NLP is a subfield of computer science and is closely associated with artificial intelligence. NLP is also related to information retrieval, knowledge representation, computational linguistics, and linguistics more broadly.[1]\n\nMajor processing tasks in an NLP system include: speech recognition, text classification, natural language understanding, and natural language generation.\n\nNatural language processing has its roots in the 1950s.[2] Already in 1950, Alan Turing published an article titled "Computing Machinery and Intelligence" which proposed what is now called the Turing test as a criterion of intelligence, though at the time that was not articulated as a problem separate from artificial intelligence. The proposed test includes a task that involves the automated interpretation and generation of natural language.\n\nThe premise of symbolic NLP is often illustrated using John Searle\'s Chinese room thought experiment: Given a collection of rules (e.g., a Chinese phrasebook, with questions and matching answers), the computer emulates natural language understanding (or other NLP tasks) by applying those rules to the data it confronts.\n• 1950s: The Georgetown experiment in 1954 involved fully automatic translation of more than sixty Russian sentences into English. The authors claimed that within three or five years, machine translation would be a solved problem. 3 However, real progress was much slower, and after the ALPAC report in 1966, which found that ten years of research had failed to fulfill the expectations, funding for machine translation was dramatically reduced. Little further research in machine translation was conducted in America (though some research continued elsewhere, such as Japan and Europe 4 ) until the late 1980s when the first statistical machine translation systems were developed.\n• 1960s: Some notably successful natural language processing systems developed in the 1960s were SHRDLU, a natural language system working in restricted "blocks worlds" with restricted vocabularies, and ELIZA, a simulation of a Rogerian psychotherapy, written by Joseph Weizenbaum between 1964 and 1966. Despite using minimal information about human thought or emotion, ELIZA was able to produce interactions that appeared human-like. When the "patient" exceeded the very small knowledge base, ELIZA might provide a generic response, for example, responding to "My head hurts" with "Why do you say your head hurts?". Ross Quillian\'s successful work on natural language was demonstrated with a vocabulary of only twenty words, because that was all that would fit in a computer memory at the time. 5\n• 1970s: During the 1970s, many programmers began to write "conceptual ontologies", which structured real-world information into computer-understandable data. Examples are MARGIE (Schank, 1975), SAM (Cullingford, 1978), PAM (Wilensky, 1978), TaleSpin (Meehan, 1976), QUALM (Lehnert, 1977), Politics (Carbonell, 1979), and Plot Units (Lehnert 1981). During this time, the first chatterbots were written (e.g., PARRY).\n• 1980s: The 1980s and early 1990s mark the heyday of symbolic methods in NLP. Focus areas of the time included research on rule-based parsing (e.g., the development of HPSG as a computational operationalization of generative grammar), morphology (e.g., two-level morphology 6 ), semantics (e.g., Lesk algorithm), reference (e.g., within Centering Theory 7 ) and other areas of natural language understanding (e.g., in the Rhetorical Structure Theory). Other lines of research were continued, e.g., the development of chatterbots with Racter and Jabberwacky. An important development (that eventually led to the statistical turn in the 1990s) was the rising importance of quantitative evaluation in this period. 8\n\nUp until the 1980s, most natural language processing systems were based on complex sets of hand-written rules. Starting in  ...

# %%
original_sentences = [sentence for sentence in nltk.sent_tokenize(article.cleaned_text)]

# %%
original_sentences
# Out:
# ['Natural language processing (NLP) is the processing of natural language information by a computer.',
#  'NLP is a subfield of computer science and is closely associated with artificial intelligence.',
#  'NLP is also related to information retrieval, knowledge representation, computational linguistics, and linguistics more broadly.',
#  '[1]\n\nMajor processing tasks in an NLP system include: speech recognition, text classification, natural language understanding, and natural language generation.',
#  'Natural language processing has its roots in the 1950s.',
#  '[2] Already in 1950, Alan Turing published an article titled "Computing Machinery and Intelligence" which proposed what is now called the Turing test as a criterion of intelligence, though at the time that was not articulated as a problem separate from artificial intelligence.',
#  'The proposed test includes a task that involves the automated interpretation and generation of natural language.',
#  "The premise of symbolic NLP is often illustrated using John Searle's Chinese room thought experiment: Given a collection of rules (e.g., a Chinese phrasebook, with questions and matching answers), the computer emulates natural language understanding (or other NLP tasks) by applying those rules to the data it confronts.",
#  '• 1950s: The Georgetown experiment in 1954 involved fully automatic translation of more than sixty Russian sentences into English.',
#  'The authors claimed that within three or five years, machine translation would be a solved problem.',
#  '3 However, real progress was much slower, and after the ALPAC report in 1966, which found that ten years of research had failed to fulfill the expectations, funding for machine translation was dramatically reduced.',
#  'Little further research in machine translation was conducted in America (though some research continued elsewhere, such as Japan and Europe 4 ) until the late 1980s when the first statistical machine translation systems were developed.',
#  '• 1960s: Some notably successful natural language processing systems developed in the 1960s were SHRDLU, a natural language system working in restricted "blocks worlds" with restricted vocabularies, and ELIZA, a simulation of a Rogerian psychotherapy, written by Joseph Weizenbaum between 1964 and 1966.',
#  'Despite using minimal information about human thought or emotion, ELIZA was able to produce interactions that appeared human-like.',
#  'When the "patient" exceeded the very small knowledge base, ELIZA might provide a generic response, for example, responding to "My head hurts" with "Why do you say your head hurts?".',
#  "Ross Quillian's successful work on natural language was demonstrated with a vocabulary of only twenty words, because that was all that would fit in a computer memory at the time.",
#  '5\n• 1970s: During the 1970s, many programmers began to write "conceptual ontologies", which structured real-world information into computer-understandable data.',
#  'Examples are MARGIE (Schank, 1975), SAM (Cullingford, 1978), PAM (Wilensky, 1978), TaleSpin (Meehan, 1976), QUALM (Lehnert, 1977), Politics (Carbonell, 1979), and Plot Units (Lehnert 1981).',
#  'During this time, the first chatterbots were written (e.g., PARRY).',
#  '• 1980s: The 1980s and early 1990s mark the heyday of symbolic methods in NLP.',
#  'Focus areas of the time included research on rule-based parsing (e.g., the development of HPSG as a computational operationalization of generative grammar), morphology (e.g., two-level morphology 6 ), semantics (e.g., Lesk algorithm), reference (e.g., within Centering Theory 7 ) and other areas of natural language understanding (e.g., in the Rhetorical Structure Theory).',
#  'Other lines of research were continued, e.g., the development of chatterbots with Racter and Jabberwacky.',
#  'An important development (that eventually led to the statistical turn in the 1990s) was the rising importance of quantitative evaluation in this period.',
#  '8\n\nUp until the 1980s, most natural language processing systems were based on complex sets of hand-written rules.',
#  'Starting in the late 1980s, however, there was a revolution in natural language processing with the introduction of machine learning algorithms for language processing.',
#  "This shift was influenced by increasing computational power (see Moore's law) and a decline in the dominance of Chomskyan linguistic theories... (e.g.",
#  'transformational grammar), whose theoretical underpinnings discouraged the sort of corpus linguistics that underlies the machine-learning approach to language processing.',
#  '[9]\n• 1990s: Many of the notable early successes in statistical methods in NLP occurred in the field of machine translation, due especially to work at IBM Research, such as IBM alignment models.',
#  'These systems were able to take advantage of existing multilingual textual corpora that had been produced by the Parliament of Canada and the European Union as a result of laws calling for the translation of all governmental proceedings into all official languages of the corresponding systems of government.',
#  'However, many systems relied on corpora that were specifically developed for the tasks they were designed to perform.',
#  'This reliance has been a major limitation to their broader effectiveness and continues to affect similar systems.',
#  'Consequently, significant research has focused on methods for learning effectively from limited amounts of data.',
#  '• 2000s: With the growth of the web, increasing amounts of raw (unannotated) language data have become available since the mid-1990s.',
#  'Research has thus increasingly focused on unsupervised and semi-supervised learning algorithms.',
#  'Such algorithms can learn from data that has not been hand-annotated with the desired answers or using a combination of annotated and non-annotated data.',
#  'Generally, this task is much more difficult than supervised learning, and typically produces less accurate results for a given amount of input data.',
#  'However, large quantities of non-annotated data are available (including, among other things, the entire content of the World Wide Web), which can often make up for the worse efficiency if the algorithm used has a low enough time complexity to be practical.',
#  '• 2003: word n-gram model, at the time the best statistical algorithm, is outperformed by a multi-layer perceptron (with a single hidden layer and context length of several words, trained on up to 14 million words, by Bengio et al.)',
#  '10\n• 2010: Tomáš Mikolov (then a PhD student at Brno University of Technology) with co-authors applied a simple recurrent neural network with a single hidden layer to language modeling, 11 and in the following years he went on to develop Word2vec.',
#  'In the 2010s, representation learning and deep neural network-style (featuring many hidden layers) machine learning methods became widespread in natural language processing.',
#  'This shift gained momentum due to results showing that such techniques 12 13 can achieve state-of-the-art results in many natural language tasks, e.g., in language modeling 14 and parsing.',
#  '15 16 This is increasingly important in medicine and healthcare, where NLP helps analyze notes and text in electronic health records that would otherwise be inaccessible for study when seeking to improve care 17 or protect patient privacy.',
#  '18\n\nSymbolic approach, i.e., the hand-coding of a set of rules for manipulating symbols, coupled with a dictionary lookup, was historically the first approach used both by AI in general and by NLP in particular:[19][20] such as by writing grammars or devising heuristic rules for stemming.',
#  'Machine learning approaches, which include both statistical and neural networks, on the other hand, have many advantages over the symbolic approach:\n• both statistical and neural networks methods can focus more on the most common cases extracted from a corpus of texts, whereas the rule-based approach needs to provide rules for both rare cases and common ones equally.',
#  '• language models, produced by either statistical or neural networks methods, are more robust to both unfamiliar (e.g.',
#  'containing words or structures that have not been seen before) and erroneous input (e.g.',
#  'with misspelled words or words accidentally omitted) in comparison to the rule-based systems, which are also more costly to produce.',
#  '• the larger such a (probabilistic) language model is, the more accurate it becomes, in contrast to rule-based systems that can gain accuracy only by increasing the amount and complexity of the rules leading to intractability problems.',
#  '• when the amount of training data is insufficient to successfully apply machine learning methods, e.g., for the machine translation of low-resource languages such as provided by the Apertium system,\n• for preprocessing in NLP pipelines, e.g., tokenization, or\n• for post-processing and transforming the output of NLP pipelines, e.g., for knowledge extraction from syntactic parses.',
#  'In the late 1980s and mid-1990s, the statistical approach ended a period of AI winter, which was caused by the inefficiencies of the rule-based approaches.',
#  '[21][22]\n\nThe earliest decision trees, producing systems of hard if–then rules, were still very similar to the old rule-based approaches.',
#  'Only the introduction of hidden Markov models, applied to part-of-speech tagging, announced the end of the old rule-based approach.',
#  'A major drawback of statistical methods is that they require elaborate feature engineering.',
#  'Since 2015,[23] neural network–based methods have increasingly replaced traditional statistical approaches, using semantic networks[24] and word embeddings to capture semantic properties of words.',
#  'Intermediate tasks (e.g., part-of-speech tagging and dependency parsing) are not needed anymore.',
#  'Neural machine translation, based on then-newly invented sequence-to-sequence transformations, made obsolete the intermediate steps, such as word alignment, previously necessary for statistical machine translation.',
#  'The following is a list of some of the most commonly researched tasks in natural language processing.',
#  'Some of these tasks have direct real-world applications, while others more commonly serve as subtasks that are used to aid in solving larger tasks.',
#  'Though natural language processing tasks are closely intertwined, they can be subdivided into categories for convenience.',
#  'A coarse division is given below.',
#  'Based on long-standing trends in the field, it is possible to extrapolate future directions of NLP.',
#  'As of 2020, three trends among the topics of the long-standing series of CoNLL Shared Tasks can be observed:[49]\n• Increasing interest in multilinguality, and, potentially, multimodality (English since 1999; Spanish, Dutch since 2002; German since 2003; Bulgarian, Danish, Japanese, Portuguese, Slovenian, Swedish, Turkish since 2006; Basque, Catalan, Chinese, Greek, Hungarian, Italian, Turkish since 2007; Czech since 2009; Arabic since 2012; 2017: 40+ languages; 2018: 60+/100+ languages)\n• Elimination of symbolic representations (rule-based over supervised towards weakly supervised methods, representation learning and end-to-end systems)\n\nMost higher-level NLP applications involve aspects that emulate intelligent behavior and apparent comprehension of natural language.',
#  'More broadly speaking, the technical operationalization of increasingly advanced aspects of cognitive behavior represents one of the developmental trajectories of NLP (see trends among CoNLL shared tasks above).',
#  'Cognition refers to "the mental action or process of acquiring knowledge and understanding through thought, experience, and the senses.',
#  '"[50] Cognitive science is the interdisciplinary, scientific study of the mind and its processes.',
#  '[51] Cognitive linguistics is an interdisciplinary branch of linguistics, combining knowledge and research from both psychology and linguistics.',
#  '[52] Especially during the age of symbolic NLP, the area of computational linguistics maintained strong ties with cognitive studies.',
#  'As an example, George Lakoff offers a methodology to build natural language processing (NLP) algorithms through the perspective of cognitive science, along with the findings of cognitive linguistics,[53] with two defining aspects:\n• Apply the theory of conceptual metaphor, explained by Lakoff as "the understanding of one idea, in terms of another" which provides an idea of the intent of the author.',
#  '54 For example, consider the English word big.',
#  'When used in a comparison ("That is a big tree"), the author\'s intent is to imply that the tree is physically large relative to other trees or the authors experience.',
#  'When used metaphorically ("Tomorrow is a big day"), the author\'s intent to imply importance.',
#  'The intent behind other usages, like in "She is a big person", will remain somewhat ambiguous to a person and a cognitive NLP algorithm alike without additional information.',
#  '• Assign relative measures of meaning to a word, phrase, sentence or piece of text based on the information presented before and after the piece of text being analyzed, e.g., by means of a probabilistic context-free grammar (PCFG).',
#  'The mathematical equation for such algorithms is presented in US Patent 9269353: 55\n\nTies with cognitive linguistics are part of the historical heritage of NLP, but they have been less frequently addressed since the statistical turn during the 1990s.',
#  'Nevertheless, approaches to develop cognitive models towards technically operationalizable frameworks have been pursued in the context of various frameworks, e.g., of cognitive grammar,[56] functional grammar,[57] construction grammar,[58] computational psycholinguistics and cognitive neuroscience (e.g., ACT-R), however, with limited uptake in mainstream NLP (as measured by presence on major conferences[59] of the ACL).',
#  'More recently, ideas of cognitive NLP have been revived as an approach to achieve explainability, e.g., under the notion of "cognitive AI".',
#  '[60] Likewise, ideas of cognitive NLP are inherent to neural models multimodal NLP (although rarely made explicit)[61] and developments in artificial intelligence, specifically tools and technologies using large language model approaches[62] and new directions in artificial general intelligence based on the free energy principle[63] by British neuroscientist and theoretician at University College London Karl J. Friston.']

# %%
len(original_sentences), 40 / 77
# Out:
# (77, 0.5194805194805194)

# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.sum_basic import SumBasicSummarizer

# %%
parser = PlaintextParser.from_string(article.cleaned_text, Tokenizer('english'))

# %%
summarizer = SumBasicSummarizer()
summary = summarizer(parser.document, 40)

# %%
summary
# Out:
# (<Sentence: Natural language processing (NLP) is the processing of natural language information by a computer.>,
#  <Sentence: NLP is a subfield of computer science and is closely associated with artificial intelligence.>,
#  <Sentence: Major processing tasks in an NLP system include: speech recognition, text classification, natural language understanding, and natural language generation.>,
#  <Sentence: [2] Already in 1950, Alan Turing published an article titled "Computing Machinery and Intelligence" which proposed what is now called the Turing test as a criterion of intelligence, though at the time that was not articulated as a problem separate from artificial intelligence.>,
#  <Sentence: • 1950s: The Georgetown experiment in 1954 involved fully automatic translation of more than sixty Russian sentences into English.>,
#  <Sentence: 3 However, real progress was much slower, and after the ALPAC report in 1966, which found that ten years of research had failed to fulfill the expectations, funding for machine translation was dramatically reduced.>,
#  <Sentence: Little further research in machine translation was conducted in America (though some research continued elsewhere, such as Japan and Europe 4 ) until the late 1980s when the first statistical machine translation systems were developed.>,
#  <Sentence: Despite using minimal information about human thought or emotion, ELIZA was able to produce interactions that appeared human-like.>,
#  <Sentence: When the "patient" exceeded the very small knowledge base, ELIZA might provide a generic response, for example, responding to "My head hurts" with "Why do you say your head hurts?".>,
#  <Sentence: Ross Quillian's successful work on natural language was demonstrated with a vocabulary of only twenty words, because that was all that would fit in a computer memory at the time.>,
#  <Sentence: 5 • 1970s: During the 1970s, many programmers began to write "conceptual ontologies", which structured real-world information into computer-understandable data.>,
#  <Sentence: Examples are MARGIE (Schank, 1975), SAM (Cullingford, 1978), PAM (Wilensky, 1978), TaleSpin (Meehan, 1976), QUALM (Lehnert, 1977), Politics (Carbonell, 1979), and Plot Units (Lehnert 1981).>,
#  <Sentence: During this time, the first chatterbots were written (e.g., PARRY).>,
#  <Sentence: • 1980s: The 1980s and early 1990s mark the heyday of symbolic methods in NLP.>,
#  <Sentence: Focus areas of the time included research on rule-based parsing (e.g., the development of HPSG as a computational operationalization of generative grammar), morphology (e.g., two-level morphology 6 ), semantics (e.g., Lesk algorithm), reference (e.g., within Centering Theory 7 ) and other areas of natural language understanding (e.g., in the Rhetorical Structure Theory).>,
#  <Sentence: This shift was influenced by increasing computational power (see Moore's law) and a decline in the dominance of Chomskyan linguistic theories... (e.g. transformational grammar), whose theoretical underpinnings discouraged the sort of corpus linguistics that underlies the machine-learning approach to language processing.>,
#  <Sentence: However, many systems relied on corpora that were specifically developed for the tasks they were designed to perform.>,
#  <Sentence: Consequently, significant research has focused on methods for learning effectively from limited amounts of data.>,
#  <Sentence: Research has thus increasingly focused on unsupervised and semi-supervised learning algorithms.>,
#  <Sentence: Such algorithms can learn from data that has not been hand-annotated with the desired answers or using a combination of annotated and non-annotated data.>,
#  <Sentence: Generally, this task is much more difficult than supervised learning, and typically produces less accurate results for a given amount of input data.>,
#  <Sentence: However, large quantities of non-annotated data are available (including, among other things, the entire content of the World Wide Web), which can often make up for the worse efficiency if the algorithm used has a low enough time complexity to be practical.>,
#  <Sentence: • 2003: word n-gram model, at the time the best statistical algorithm, is outperformed by a multi-layer perceptron (with a single hidden layer and context length of several words, trained on up to 14 million words, by Bengio et al.) 10 • 2010: Tomáš Mikolov (then a PhD student at Brno University of Technology) with co-authors applied a simple recurrent neural network with a single hidden layer to language modeling, 11 and in the following years he went on to develop Word2vec.>,
#  <Sentence: 15 16 This is increasingly important in medicine and healthcare, where NLP helps analyze notes and text in electronic health records that would otherwise be inaccessible for study when seeking to improve care 17 or protect patient privacy.>,
#  <Sentence: • language models, produced by either statistical or neural networks methods, are more robust to both unfamiliar (e.g. containing words or structures that have not been seen before) and erroneous input (e.g. with misspelled words or words accidentally omitted) in comparison to the rule-based systems, which are also more costly to produce.>,
#  <Sentence: The earliest decision trees, producing systems of hard if–then rules, were still very similar to the old rule-based approaches.>,
#  <Sentence: Only the introduction of hidden Markov models, applied to part-of-speech tagging, announced the end of the old rule-based approach.>,
#  <Sentence: Neural machine translation, based on then-newly invented sequence-to-sequence transformations, made obsolete the intermediate steps, such as word alignment, previously necessary for statistical machine translation.>,
#  <Sentence: Some of these tasks have direct real-world applications, while others more commonly serve as subtasks that are used to aid in solving larger tasks.>,
#  <Sentence: A coarse division is given below.>,
#  <Sentence: Based on long-standing trends in the field, it is possible to extrapolate future directions of NLP.>,
#  <Sentence: As of 2020, three trends among the topics of the long-standing series of CoNLL Shared Tasks can be observed:[49] • Increasing interest in multilinguality, and, potentially, multimodality (English since 1999; Spanish, Dutch since 2002; German since 2003; Bulgarian, Danish, Japanese, Portuguese, Slovenian, Swedish, Turkish since 2006; Basque, Catalan, Chinese, Greek, Hungarian, Italian, Turkish since 2007; Czech since 2009; Arabic since 2012; 2017: 40+ languages; 2018: 60+/100+ languages) • Elimination of symbolic representations (rule-based over supervised towards weakly supervised methods, representation learning and end-to-end systems)>,
#  <Sentence: Most higher-level NLP applications involve aspects that emulate intelligent behavior and apparent comprehension of natural language.>,
#  <Sentence: Cognition refers to "the mental action or process of acquiring knowledge and understanding through thought, experience, and the senses.>,
#  <Sentence: [51] Cognitive linguistics is an interdisciplinary branch of linguistics, combining knowledge and research from both psychology and linguistics.>,
#  <Sentence: [52] Especially during the age of symbolic NLP, the area of computational linguistics maintained strong ties with cognitive studies.>,
#  <Sentence: When used metaphorically ("Tomorrow is a big day"), the author's intent to imply importance.>,
#  <Sentence: The intent behind other usages, like in "She is a big person", will remain somewhat ambiguous to a person and a cognitive NLP algorithm alike without additional information.>,
#  <Sentence: • Assign relative measures of meaning to a word, phrase, sentence or piece of text based on the information presented before and after the piece of text being analyzed, e.g., by means of a probabilistic context-free grammar (PCFG).>,
#  <Sentence: More recently, ideas of cognitive NLP have been revived as an approach to achieve explainability, e.g., under the notion of "cognitive AI".>)

# %%
best_sentences = []
for sentence in summary:
  best_sentences.append(str(sentence))

# %%
best_sentences
# Out:
# ['Natural language processing (NLP) is the processing of natural language information by a computer.',
#  'NLP is a subfield of computer science and is closely associated with artificial intelligence.',
#  'Major processing tasks in an NLP system include: speech recognition, text classification, natural language understanding, and natural language generation.',
#  '[2] Already in 1950, Alan Turing published an article titled "Computing Machinery and Intelligence" which proposed what is now called the Turing test as a criterion of intelligence, though at the time that was not articulated as a problem separate from artificial intelligence.',
#  '• 1950s: The Georgetown experiment in 1954 involved fully automatic translation of more than sixty Russian sentences into English.',
#  '3 However, real progress was much slower, and after the ALPAC report in 1966, which found that ten years of research had failed to fulfill the expectations, funding for machine translation was dramatically reduced.',
#  'Little further research in machine translation was conducted in America (though some research continued elsewhere, such as Japan and Europe 4 ) until the late 1980s when the first statistical machine translation systems were developed.',
#  'Despite using minimal information about human thought or emotion, ELIZA was able to produce interactions that appeared human-like.',
#  'When the "patient" exceeded the very small knowledge base, ELIZA might provide a generic response, for example, responding to "My head hurts" with "Why do you say your head hurts?".',
#  "Ross Quillian's successful work on natural language was demonstrated with a vocabulary of only twenty words, because that was all that would fit in a computer memory at the time.",
#  '5 • 1970s: During the 1970s, many programmers began to write "conceptual ontologies", which structured real-world information into computer-understandable data.',
#  'Examples are MARGIE (Schank, 1975), SAM (Cullingford, 1978), PAM (Wilensky, 1978), TaleSpin (Meehan, 1976), QUALM (Lehnert, 1977), Politics (Carbonell, 1979), and Plot Units (Lehnert 1981).',
#  'During this time, the first chatterbots were written (e.g., PARRY).',
#  '• 1980s: The 1980s and early 1990s mark the heyday of symbolic methods in NLP.',
#  'Focus areas of the time included research on rule-based parsing (e.g., the development of HPSG as a computational operationalization of generative grammar), morphology (e.g., two-level morphology 6 ), semantics (e.g., Lesk algorithm), reference (e.g., within Centering Theory 7 ) and other areas of natural language understanding (e.g., in the Rhetorical Structure Theory).',
#  "This shift was influenced by increasing computational power (see Moore's law) and a decline in the dominance of Chomskyan linguistic theories... (e.g. transformational grammar), whose theoretical underpinnings discouraged the sort of corpus linguistics that underlies the machine-learning approach to language processing.",
#  'However, many systems relied on corpora that were specifically developed for the tasks they were designed to perform.',
#  'Consequently, significant research has focused on methods for learning effectively from limited amounts of data.',
#  'Research has thus increasingly focused on unsupervised and semi-supervised learning algorithms.',
#  'Such algorithms can learn from data that has not been hand-annotated with the desired answers or using a combination of annotated and non-annotated data.',
#  'Generally, this task is much more difficult than supervised learning, and typically produces less accurate results for a given amount of input data.',
#  'However, large quantities of non-annotated data are available (including, among other things, the entire content of the World Wide Web), which can often make up for the worse efficiency if the algorithm used has a low enough time complexity to be practical.',
#  '• 2003: word n-gram model, at the time the best statistical algorithm, is outperformed by a multi-layer perceptron (with a single hidden layer and context length of several words, trained on up to 14 million words, by Bengio et al.) 10 • 2010: Tomáš Mikolov (then a PhD student at Brno University of Technology) with co-authors applied a simple recurrent neural network with a single hidden layer to language modeling, 11 and in the following years he went on to develop Word2vec.',
#  '15 16 This is increasingly important in medicine and healthcare, where NLP helps analyze notes and text in electronic health records that would otherwise be inaccessible for study when seeking to improve care 17 or protect patient privacy.',
#  '• language models, produced by either statistical or neural networks methods, are more robust to both unfamiliar (e.g. containing words or structures that have not been seen before) and erroneous input (e.g. with misspelled words or words accidentally omitted) in comparison to the rule-based systems, which are also more costly to produce.',
#  'The earliest decision trees, producing systems of hard if–then rules, were still very similar to the old rule-based approaches.',
#  'Only the introduction of hidden Markov models, applied to part-of-speech tagging, announced the end of the old rule-based approach.',
#  'Neural machine translation, based on then-newly invented sequence-to-sequence transformations, made obsolete the intermediate steps, such as word alignment, previously necessary for statistical machine translation.',
#  'Some of these tasks have direct real-world applications, while others more commonly serve as subtasks that are used to aid in solving larger tasks.',
#  'A coarse division is given below.',
#  'Based on long-standing trends in the field, it is possible to extrapolate future directions of NLP.',
#  'As of 2020, three trends among the topics of the long-standing series of CoNLL Shared Tasks can be observed:[49] • Increasing interest in multilinguality, and, potentially, multimodality (English since 1999; Spanish, Dutch since 2002; German since 2003; Bulgarian, Danish, Japanese, Portuguese, Slovenian, Swedish, Turkish since 2006; Basque, Catalan, Chinese, Greek, Hungarian, Italian, Turkish since 2007; Czech since 2009; Arabic since 2012; 2017: 40+ languages; 2018: 60+/100+ languages) • Elimination of symbolic representations (rule-based over supervised towards weakly supervised methods, representation learning and end-to-end systems)',
#  'Most higher-level NLP applications involve aspects that emulate intelligent behavior and apparent comprehension of natural language.',
#  'Cognition refers to "the mental action or process of acquiring knowledge and understanding through thought, experience, and the senses.',
#  '[51] Cognitive linguistics is an interdisciplinary branch of linguistics, combining knowledge and research from both psychology and linguistics.',
#  '[52] Especially during the age of symbolic NLP, the area of computational linguistics maintained strong ties with cognitive studies.',
#  'When used metaphorically ("Tomorrow is a big day"), the author\'s intent to imply importance.',
#  'The intent behind other usages, like in "She is a big person", will remain somewhat ambiguous to a person and a cognitive NLP algorithm alike without additional information.',
#  '• Assign relative measures of meaning to a word, phrase, sentence or piece of text based on the information presented before and after the piece of text being analyzed, e.g., by means of a probabilistic context-free grammar (PCFG).',
#  'More recently, ideas of cognitive NLP have been revived as an approach to achieve explainability, e.g., under the notion of "cognitive AI".']

# %%
from IPython.core.display import HTML
text = ''
display(HTML(f'<h2>Summary - {article.title}</h2>'))
for sentence in original_sentences:
  #print(sentence)
  if sentence in best_sentences:
    text += ' ' + str(sentence).replace(sentence, f"<mark>{sentence}</mark>")
  else:
    text += ' ' + sentence
display(HTML(f"""{text}"""))
# Out:
# <h2>Summary - Natural language processing - Wikipedia</h2>
#  <mark>Natural language processing (NLP) is the processing of natural language information by a computer.</mark> <mark>NLP is a subfield of computer science and is closely associated with artificial intelligence.</mark> NLP is also related to information retrieval, knowledge representation, computational linguistics, and linguistics more broadly. [1]
#
# Major processing tasks in an NLP system include: speech recognition, text classification, natural language understanding, and natural language generation. Natural language processing has its roots in the 1950s. <mark>[2] Already in 1950, Alan Turing published an article titled "Computing Machinery and Intelligence" which proposed what is now called the Turing test as a criterion of intelligence, though at the time that was not articulated as a problem separate from artificial intelligence.</mark> The proposed test includes a task that involves the automated interpretation and generation of natural language. The premise of symbolic NLP is often illustrated using John Searle's Chinese room thought experiment: Given a collection of rules (e.g., a Chinese phrasebook, with questions and matching answers), the computer emulates natural language understanding (or other NLP tasks) by applying those rules to the data it confronts. <mark>• 1950s: The Georgetown experiment in 1954 involved fully automatic translation of more than sixty Russian sentences into English.</mark> The authors claimed that within three or five years, machine translation would be a solved problem. <mark>3 However, real progress was much slower, and after the ALPAC report in 1966, which found that ten years of research had failed to fulfill the expectations, funding for machine translation was dramatically reduced.</mark> <mark>Little further research in machine translation was conducted in America (though some research continued elsewhere, such as Japan and Europe 4 ) until the late 1980s when the first statistical machine translation systems were developed.</mark> • 1960s: Some notably successful natural language processing systems developed in the 1960s were SHRDLU, a natural language system working in restricted "blocks worlds" with restricted vocabularies, and ELIZA, a simulation of a Rogerian psychotherapy, written by Joseph Weizenbaum between 1964 and 1966. <mark>Despite using minimal information about human thought or emotion, ELIZA was able to produce interactions that appeared human-like.</mark> <mark>When the "patient" exceeded the very small knowledge base, ELIZA might provide a generic response, for example, responding to "My head hurts" with "Why do you say your head hurts?".</mark> <mark>Ross Quillian's successful work on natural language was demonstrated with a vocabulary of only twenty words, because that was all that would fit in a computer memory at the time.</mark> 5
# • 1970s: During the 1970s, many programmers began to write "conceptual ontologies", which structured real-world information into computer-understandable data. <mark>Examples are MARGIE (Schank, 1975), SAM (Cullingford, 1978), PAM (Wilensky, 1978), TaleSpin (Meehan, 1976), QUALM (Lehnert, 1977), Politics (Carbonell, 1979), and Plot Units (Lehnert 1981).</mark> <mark>During this time, the first chatterbots were written (e.g., PARRY).</mark> <mark>• 1980s: The 1980s and early 1990s mark the heyday of symbolic methods in NLP.</mark> <mark>Focus areas of the time included research on rule-based parsing (e.g., the development of HPSG as a computational operationalization of generative grammar), morphology (e.g., two-level morphology 6 ), semantics (e.g., Lesk algorithm), reference (e.g., within Centering Theory 7 ) and other areas of natural language understanding (e.g., in the Rhetorical Structure Theory).</mark> Other lines of research were continued, e.g., the development of chatterbots with Racter and Jabberwacky. An important development (that eventually led to the statistical turn in the 1990s) was the rising importance of quantitative evaluation in this period. 8
#
# Up until the 1980s, most natural language processing systems were based on complex sets of hand-written rules. Starting in the late 1980s, however, there was a revolution in natural language processing with the introduction of machine learning algorithms for language processing. This shift was influenced by increasing computational power (see Moore's law) and a decline in the dominance of Chomskyan linguistic theories... (e.g. transformational grammar), whose theoretical underpinnings discouraged the sort of corpus linguistics that underlies the machine-learning approach to language processing. [9]
# • 1990s: Many of the notable early successes in statistical methods in NLP occurred in the field of machine translation, due especially to work at IBM Research, such as IBM alignment models. These systems were able to take advantage of existing multilingual textual corpora that had been produced by the Parliament of Canada and the European Union as a result of laws calling for the translation of all governmental proceedings into all official languages of the corresponding systems of government. <mark>However, many systems relied on corpora that were specifically developed for the tasks they were designed to perform.</mark> This reliance has been a major limitation to their broader effectiveness and continues to affect similar systems. <mark>Consequently, significant research has focused on methods for learning effectively from limited amounts of data.</mark> • 2000s: With the growth of the web, increasing amounts of raw (unannotated) language data have become available since the mid-1990s. <mark>Research has thus increasingly focused on unsupervised and semi-supervised learning algorithms.</mark> <mark>Such algorithms can learn from data that has not been hand-annotated with the desired answers or using a combination of annotated and non-annotated data.</mark> <mark>Generally, this task is much more difficult than supervised learning, and typically produces less accurate results for a given amount of input data.</mark> <mark>However, large quantities of non-annotated data are available (including, among other things, the entire content of the World Wide Web), which can often make up for the worse efficiency if the algorithm used has a low enough time complexity to be practical.</mark> • 2003: word n-gram model, at the time the best statistical algorithm, is outperformed by a multi-layer perceptron (with a single hidden layer and context length of several words, trained on up to 14 million words, by Bengio et al.) 10
# • 2010: Tomáš Mikolov (then a PhD student at Brno University of Technology) with co-authors applied a simple recurrent neural network with a single hidden layer to language modeling, 11 and in the following years he went on to develop Word2vec. In the 2010s, representation learning and deep neural network-style (featuring many hidden layers) machine learning methods became widespread in natural language processing. This shift gained momentum due to results showing that such techniques 12 13 can achieve state-of-the-art results in many natural language tasks, e.g., in language modeling 14 and parsing. <mark>15 16 This is increasingly important in medicine and healthcare, where NLP helps analyze notes and text in electronic health records that would otherwise be inaccessible for study when seeking to improve care 17 or protect patient privacy.</mark> 18
#
# Symbolic approach, i.e., the hand-coding of a set of rules for manipulating symbols, coupled with a dictionary lookup, was historically the first approach used both by AI in general and by NLP in particular:[19][20] such as by writing grammars or devising heuristic rules for stemming. Machine learning approaches, which include both statistical and neural networks, on the other hand, have many advantages over the symbolic approach:
# • both statistical and neural networks methods can focus more on the most common cases extracted from a corpus o

# %% [markdown]
# # Key word search

# %%
string = 'Natural language processing (NLP) is a subfield of linguistics, computer science, and artificial intelligence concerned with the interactions between computers and human language, in particular how to program computers to process and analyze large amounts of natural language data.'

# %%
search_strings = ['artificial', 'computer']
tokens_list = [nlp(item) for item in search_strings]

# %%
tokens_list
# Out:
# [artificial, computer]

# %%
from spacy.matcher import PhraseMatcher
matcher = PhraseMatcher(nlp.vocab)
matcher.add('SEARCH', None, *tokens_list)

# %%
document = nlp(string)
matches = matcher(document)
matches
# Out:
# [(8661325627334373315, 12, 13), (8661325627334373315, 16, 17)]

# %%
document[12:13], document[16:17]
# Out:
# (computer, artificial)

# %%
document[12-5:13+5]
# Out:
# a subfield of linguistics, computer science, and artificial intelligence

# %%
document[16-5:17+5]
# Out:
# , computer science, and artificial intelligence concerned with the interactions

# %%
number_of_words = 50
search_strings_html = ' '.join([element for element in search_strings])
search_strings_html
# Out:
# 'artificial computer'

# %%
marked_text = ''
display(HTML(f'<h1>{search_strings_html.upper()}</h1>'))
document = nlp(article.cleaned_text)
matches = matcher(document)
#print(matches)
display(HTML(f"""<p><strong>Number of matches: </strong>{len(matches)}</p>"""))
for i in matches:
  #print(i)
  start = i[1] - number_of_words
  if start < 0:
    start = 0
  for j in range(len(tokens_list)):
    #print(j, tokens_list[j])
    if document[i[1]:i[2]].similarity(tokens_list[j]) == 1.0:
      search_text = str(tokens_list[j])
      marked_text += str(document[start:i[2] + number_of_words]).replace(search_text, f"<mark>{search_text}</mark>")
      marked_text += "<br /><br />"
display(HTML(f"""<blockquote>{marked_text}</blockquote>"""))
# Out:
# <h1>ARTIFICIAL COMPUTER</h1>
# <p><strong>Number of matches: </strong>9</p>
# /tmp/ipykernel_1960366/887847395.py:14: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Span.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   if document[i[1]:i[2]].similarity(tokens_list[j]) == 1.0:
# <blockquote>Natural language processing (NLP) is the processing of natural language information by a <mark>computer</mark>. NLP is a subfield of <mark>computer</mark> science and is closely associated with artificial intelligence. NLP is also related to information retrieval, knowledge representation, computational linguistics, and linguistics more broadly.[1]
#
# Major processing tasks in an NLP system include: speech recognition, text classification<br /><br />Natural language processing (NLP) is the processing of natural language information by a <mark>computer</mark>. NLP is a subfield of <mark>computer</mark> science and is closely associated with artificial intelligence. NLP is also related to information retrieval, knowledge representation, computational linguistics, and linguistics more broadly.[1]
#
# Major processing tasks in an NLP system include: speech recognition, text classification, natural language understanding, and natural<br /><br />Natural language processing (NLP) is the processing of natural language information by a computer. NLP is a subfield of computer science and is closely associated with <mark>artificial</mark> intelligence. NLP is also related to information retrieval, knowledge representation, computational linguistics, and linguistics more broadly.[1]
#
# Major processing tasks in an NLP system include: speech recognition, text classification, natural language understanding, and natural language generation.
#
# Natural language processing<br /><br />its roots in the 1950s.[2] Already in 1950, Alan Turing published an article titled "Computing Machinery and Intelligence" which proposed what is now called the Turing test as a criterion of intelligence, though at the time that was not articulated as a problem separate from <mark>artificial</mark> intelligence. The proposed test includes a task that involves the automated interpretation and generation of natural language.
#
# The premise of symbolic NLP is often illustrated using John Searle's Chinese room thought experiment: Given a collection of rules (e.g., a Chinese phrasebook, with<br /><br />task that involves the automated interpretation and generation of natural language.
#
# The premise of symbolic NLP is often illustrated using John Searle's Chinese room thought experiment: Given a collection of rules (e.g., a Chinese phrasebook, with questions and matching answers), the <mark>computer</mark> emulates natural language understanding (or other NLP tasks) by applying those rules to the data it confronts.
# • 1950s: The Georgetown experiment in 1954 involved fully automatic translation of more than sixty Russian sentences into English. The authors claimed that within three or five<br /><br />, for example, responding to "My head hurts" with "Why do you say your head hurts?". Ross Quillian's successful work on natural language was demonstrated with a vocabulary of only twenty words, because that was all that would fit in a <mark>computer</mark> memory at the time. 5
# • 1970s: During the 1970s, many programmers began to write "conceptual ontologies", which structured real-world information into <mark>computer</mark>-understandable data. Examples are MARGIE (Schank, 1975), SAM (Cullingford, 1978<br /><br />demonstrated with a vocabulary of only twenty words, because that was all that would fit in a <mark>computer</mark> memory at the time. 5
# • 1970s: During the 1970s, many programmers began to write "conceptual ontologies", which structured real-world information into <mark>computer</mark>-understandable data. Examples are MARGIE (Schank, 1975), SAM (Cullingford, 1978), PAM (Wilensky, 1978), TaleSpin (Meehan, 1976), QUALM (Lehnert, 1977), Politics (Carbonell, 1979), and Plot<br /><br />. More recently, ideas of cognitive NLP have been revived as an approach to achieve explainability, e.g., under the notion of "cognitive AI".[60] Likewise, ideas of cognitive NLP are inherent to neural models multimodal NLP (although rarely made explicit)[61] and developments in <mark>artificial</mark> intelligence, specifically tools and technologies using large language model approaches[62] and new directions in <mark>artificial</mark> general intelligence based on the free energy principle[63] by British neuroscientist and theoretician at University College London Karl J. Friston.<br /><br />, e.g., under the notion of "cognitive AI".[60] Likewise, ideas of cognitive NLP are inherent to neural models multimodal NLP (although rarely made explicit)[61] and developments in <mark>artificial</mark> intelligence, specifically tools and technologies using large language model approaches[62] and new directions in <mark>artificial</mark> general intelligence based on the free energy principle[63] by British neuroscientist and theoretician at University College London Karl J. Friston.<br /><br /></blockquote>

# %% [markdown]
# # Bag of words
