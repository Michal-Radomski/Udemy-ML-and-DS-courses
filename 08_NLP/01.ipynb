# %%
import spacy
spacy.__version__
# Out:
# '3.8.11'

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 7.7 MB/s  0:00:01a 0:00:01m eta 0:00:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# !python -m spacy download fr_core_news_sm
# Out:
# Collecting fr-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.8.0/fr_core_news_sm-3.8.0-py3-none-any.whl (16.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 6.0 MB/s  0:00:02 eta 0:00:010:00:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')

# %%
import en_core_web_sm

# %%
nlp = spacy.load('en_core_web_sm')
nlp

# %%
document = nlp('I am learning natural language processing. The course is in London')

# %%
for token in document:
  print(token.text, token.pos_)
# Out:
# I PRON
# am AUX
# learning VERB
# natural ADJ
# language NOUN
# processing NOUN
# . PUNCT
# The DET
# course NOUN
# is AUX
# in ADP
# London PROPN

# %%
for token in document:
  print(token.text, token.pos_, token.lemma_, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop)
# Out:
# I PRON I PRP nsubj X True True
# am AUX be VBP aux xx True True
# learning VERB learn VBG ROOT xxxx True False
# natural ADJ natural JJ amod xxxx True False
# language NOUN language NN compound xxxx True False
# processing NOUN processing NN dobj xxxx True False
# . PUNCT . . punct . False False
# The DET the DT det Xxx True True
# course NOUN course NN nsubj xxxx True False
# is AUX be VBZ ROOT xx True True
# in ADP in IN prep xx True True
# London PROPN London NNP pobj Xxxxx True False

# %%
for token in document:
  if token.pos_ == 'PROPN':
    print(token.text)
# Out:
# London

# %%
for token in document:
  if token.pos_ == 'PROPN':
    print(token.text)
# Out:
# London

# %%
for token in document:
  print(token.text, token.lemma_)
# Out:
# I I
# am be
# learning learn
# natural natural
# language language
# processing processing
# . .
# The the
# course course
# is be
# in in
# London London

# %%
for token in document:
  print(token.text, token.lemma_)
# Out:
# I I
# am be
# learning learn
# natural natural
# language language
# processing processing
# . .
# The the
# course course
# is be
# in in
# London London

# %%
import nltk
nltk.__version__
# Out:
# '3.9.3'

# %%
stemmer = nltk.stem.PorterStemmer()
stemmer.stem('learning')
# Out:
# 'learn'

# %%
stemmer.stem('watching')
# Out:
# 'watch'

# %%
for token in document:
  print(token.text, token.lemma_, stemmer.stem(token.text))
# Out:
# I I i
# am be am
# learning learn learn
# natural natural natur
# language language languag
# processing processing process
# . . .
# The the the
# course course cours
# is be is
# in in in
# London London london

# %%
text = 'IBM is a US company on information technology. It is located in San Francisco and revenue in 2018 was approximately 320 billion dolars'

# %%
document = nlp(text)

# %%
for entity in document.ents:
  print(entity.text, entity.label_)
# Out:
# IBM ORG
# US GPE
# San Francisco GPE
# 2018 DATE
# approximately 320 billion dolars MONEY

# %%
from spacy import displacy
displacy.render(document, style = 'ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IBM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  company on information technology. It is located in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     San Francisco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and revenue in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  was
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     approximately 320 billion dolars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %%
text = 'Bill Gates was born in Seattle on 1955-10-28 and is the founder of Microsoft'

# %%
document = nlp(text)
for entity in document.ents:
  print(entity.text, entity.label_)
# Out:
# Bill Gates PERSON
# Seattle GPE
# 1955-10-28 DATE
# Microsoft ORG

# %%
displacy.render(document, style = 'ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bill Gates
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was born in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Seattle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1955-10-28
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and is the founder of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div></span>

# %%
for entity in document.ents:
  if entity.label_ == 'PERSON':
    print(entity.text)
# Out:
# Bill Gates

# %%
from spacy.lang.en.stop_words import STOP_WORDS
print(STOP_WORDS)
# Out:
# {'many', 'both', 'sixty', 'above', 'move', 'she', 'using', 'why', 'twelve', '’d', 'are', 'herself', '‘m', 'mine', 'doing', 'due', 'his', 'whoever', 'along', 'fifteen', '‘ll', 'nowhere', 'else', 'from', 'be', 'name', "'re", 'third', 'please', 'serious', 'side', 'below', 'thereafter', 'whom', 'because', 'four', 'have', 'ours', 'hers', 'very', 'of', 'never', 'unless', 'during', 'has', 'seeming', 'throughout', 'wherein', '’ll', 'me', 'even', 'in', 'is', 'could', 'yet', 'on', 'who', 'everything', '‘s', 'without', 'mostly', 'around', 'about', "n't", 'ten', "'d", 'few', 'otherwise', 'does', 'although', 'just', 'should', 'did', 'sometimes', '’re', 'they', 'see', 'us', 'further', 'these', 'was', 'neither', 'former', 'any', 'via', 'same', 'toward', 'next', 'whereafter', 'for', 'much', 'n‘t', 'herein', 'alone', 'whence', 'anything', 'upon', 'thus', 'whose', "'s", 'every', 'thereby', 'go', 'therein', 'since', 'my', 'still', 'hereby', 'him', 'thereupon', 'can', '‘d', 'it', 'though', 'nevertheless', 'wherever', 'now', 'somehow', 'regarding', 'already', 'whereby', 'hence', 'when', 'formerly', 'down', 'amongst', 'therefore', 'thence', 'anyone', 'except', 'used', 'three', 'would', 'show', 'eight', 'at', 'an', 'beside', 'each', 'a', 'whither', 'up', 'top', 'most', 'keep', 'meanwhile', 'will', 'thru', 'back', 'against', 'everyone', 'through', 'n’t', 'our', 'seem', 'here', 'empty', 'becoming', 'hereafter', 'do', 'full', 'yourself', 'others', 'with', 'how', 'whereupon', 'which', 'someone', 'and', '’m', 'onto', 'last', 'beforehand', 'enough', 'done', 'more', 'take', 'other', 'per', 'until', 'afterwards', 'myself', 'besides', 'say', 'make', 'among', 'over', 'another', 'under', 'yours', 'elsewhere', 'by', '’ve', 'whereas', 'either', 'whatever', '‘ve', 're', 'them', 'or', 'give', 'almost', 'all', 'were', 'ca', 'nor', 'anyway', 'than', 'we', 'while', 'nobody', 'behind', 'had', 'the', 'where', '‘re', 'forty', 'seems', 'rather', 'less', 'towards', 'fifty', 'such', 'often', 'perhaps', 'within', 'get', 'its', 'nine', 'ourselves', 'made', 'quite', 'so', 'namely', 'various', 'might', 'nothing', '’s', 'somewhere', 'anyhow', 'out', 'several', 'whenever', 'together', 'their', 'become', 'again', 'indeed', 'this', 'five', 'always', 'after', 'cannot', 'you', 'part', 'latter', 'well', 'that', 'to', 'became', 'whole', 'ever', 'six', 'really', 'i', 'as', 'only', 'but', 'must', 'some', "'ll", 'itself', "'m", 'before', "'ve", 'becomes', 'also', 'what', 'everywhere', 'no', 'your', 'across', 'first', 'beyond', 'seemed', 'bottom', 'her', 'own', 'none', 'he', 'least', 'if', 'eleven', 'may', 'sometime', 'off', 'call', 'yourselves', 'himself', 'themselves', 'one', 'latterly', 'noone', 'being', 'moreover', 'once', 'two', 'front', 'hereupon', 'twenty', 'into', 'too', 'whether', 'something', 'put', 'amount', 'then', 'not', 'been', 'anywhere', 'there', 'those', 'however', 'hundred', 'am', 'between'}

# %%
# from spacy.lang.fr.stop_words import STOP_WORDS
# print(STOP_WORDS)

# %%
'it' in STOP_WORDS
# Out:
# True

# %%
len(STOP_WORDS)
# Out:
# 326

# %%
nlp.vocab['it'].is_stop
# Out:
# True

# %%
nlp.vocab['walk'].is_stop
# Out:
# False

# %%
document = nlp('I am learning natural language processing. The course is in London')

# %%
for token in document:
  if nlp.vocab[token.text].is_stop:
    print(token.text)
# Out:
# I
# am
# The
# is
# in

# %%
for token in document:
  if not nlp.vocab[token.text].is_stop:
    print(token.text)
# Out:
# learning
# natural
# language
# processing
# .
# course
# London

# %%
document = nlp('book a ticket from London to Paris')

# %%
origin = document[4]
destiny = document[6]
print(origin, destiny)
# Out:
# London Paris

# %%
list(origin.ancestors)
# Out:
# [from, ticket, book]

# %%
list(destiny.ancestors)
# Out:
# [to, ticket, book]

# %%
document[0].is_ancestor(document[2])
# Out:
# True

# %%
document = nlp('Book a table for the restaurant and a taxi to the hotel')

# %%
tasks = document[2], document[8]
locations = document[5], document[11]
print(tasks, locations)
# Out:
# (table, taxi) (restaurant, hotel)

# %%
for local in locations:
  print('-----', local)
  for obj in local.ancestors:
    print(obj)
# Out:
# ----- restaurant
# for
# table
# Book
# ----- hotel
# to
# taxi
# restaurant
# for
# table
# Book

# %%
for local in locations:
  for obj in local.ancestors:
    if obj in tasks:
      print('Reservation of a {} to the {}'.format(obj, local))
      break
# Out:
# Reservation of a table to the restaurant
# Reservation of a taxi to the hotel

# %%
list(document[5].children)
# Out:
# [the, and, taxi]

# %%
from spacy import displacy

# %%
document = nlp('Book a table for the restaurant and a taxi to the hotel')

# %%
displacy.render(document, style='dep', jupyter=True, options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8cb7aa5e57284ed390708fbdb7191d87-0" class="displacy" width="1130" height="227.0" direction="ltr" style="max-width: none; height: 227.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Book</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">table</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">restaurant</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">taxi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">hotel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8cb7aa5e57284ed390708fbdb7191d87-0-0" stroke-width="2px" d="M160,92.0 C160,47.0 225.0,47.0 225.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8cb7aa5e57284ed390708fbdb7191d87-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M160,94.0 L152,82.0 168,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8cb7aa5e57284ed390708fbdb7191d87-0-1" stroke-width="2px" d="M70,92.0 C70,2.0 230.0,2.0 230.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8cb7aa5e57284ed390708fbdb7191d87-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M230.0,94.0 L238.0,82.0 222.0,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8cb7aa5e57284ed390708fbdb7191d87-0-2" stroke-width="2px" d="M250,92.0 C250,47.0 315.0,47.0 315.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8cb7aa5e57284ed390708fbdb7191d87-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M315.0,94.0 L323.0,82.0 307.0,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8cb7aa5e57284ed390708fbdb7191d87-0-3" stroke-width="2px" d="M430,92.0 C430,47.0 495.0,47.0 495.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8cb7aa5e57284ed390708fbdb7191d87-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,94.0 L422,82.0 438,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8cb7aa5e57284ed390708fbdb7191d87-0-4" stroke-width="2px" d="M340,92.0 C340,2.0 500.0,2.0 500.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8cb7aa5e57284ed390708fbdb7191d87-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M500.0,94.0 L508.0,82.0 492.0,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8cb7aa5e57284ed390708fbdb7191d87-0-5" stroke-width="2px" d="M520,92.0 C520,47.0 585.0,47.0 585.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8cb7aa5e57284ed390708fbdb7191d87-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M585.0,94.0 L593.0,82.0 577.0,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8cb7aa5e57284ed390708fbdb7191d87-0-6" stroke-width="2px" d="M700,92.0 C700,47.0 765.0,47.0 765.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8cb7aa5e57284ed390708fbdb7191d87-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M700,94.0 L692,82.0 708,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8cb7aa5e57284ed390708fbdb7191d87-0-7" stroke-width="2px" d="M520,92.0 C520,2.0 770.0,2.0 770.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8cb7aa5e57284ed390708fbdb7191d87-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770.0,94.0 L778.0,82.0 762.0,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8cb7aa5e57284ed390708fbdb7191d87-0-8" stroke-width="2px" d="M

# %%
list(document[2].ancestors)
# Out:
# [Book]

# %%
list(document[2].children)
# Out:
# [a, for]

# %%
document = nlp('What places can we visit in London and stay in Paris?')
locations = document[6], document[10]
actions = document[4], document[8]
print(locations, actions)
# Out:
# (London, Paris) (visit, stay)

# %%
for local in locations:
  #print(local)
  for action in local.ancestors:
    if action in actions:
      print('{} to {}'.format(local, action))
      break
# Out:
# London to visit
# Paris to stay

# %%
displacy.render(document, style='dep', jupyter=True, options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7e61909a357f4ba4b37efb29d95c6eee-0" class="displacy" width="1040" height="272.0" direction="ltr" style="max-width: none; height: 272.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">What</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">places</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">we</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">visit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">London</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">stay</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">Paris?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7e61909a357f4ba4b37efb29d95c6eee-0-0" stroke-width="2px" d="M70,137.0 C70,92.0 130.0,92.0 130.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7e61909a357f4ba4b37efb29d95c6eee-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,139.0 L62,127.0 78,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7e61909a357f4ba4b37efb29d95c6eee-0-1" stroke-width="2px" d="M160,137.0 C160,2.0 410.0,2.0 410.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7e61909a357f4ba4b37efb29d95c6eee-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M160,139.0 L152,127.0 168,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7e61909a357f4ba4b37efb29d95c6eee-0-2" stroke-width="2px" d="M250,137.0 C250,47.0 405.0,47.0 405.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7e61909a357f4ba4b37efb29d95c6eee-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M250,139.0 L242,127.0 258,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7e61909a357f4ba4b37efb29d95c6eee-0-3" stroke-width="2px" d="M340,137.0 C340,92.0 400.0,92.0 400.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7e61909a357f4ba4b37efb29d95c6eee-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M340,139.0 L332,127.0 348,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7e61909a357f4ba4b37efb29d95c6eee-0-4" stroke-width="2px" d="M430,137.0 C430,92.0 490.0,92.0 490.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7e61909a357f4ba4b37efb29d95c6eee-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M490.0,139.0 L498.0,127.0 482.0,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7e61909a357f4ba4b37efb29d95c6eee-0-5" stroke-width="2px" d="M520,137.0 C520,92.0 580.0,92.0 580.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7e61909a357f4ba4b37efb29d95c6eee-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M580.0,139.0 L588.0,127.0 572.0,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7e61909a357f4ba4b37efb29d95c6eee-0-6" stroke-width="2px" d="M430,137.0 C430,47.0 675.0,47.0 675.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7e61909a357f4ba4b37efb29d95c6eee-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M675.0,139.0 L683.0,127.0 667.0,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7e61909a357f4ba4b37efb29d95c6eee-0-7" stroke-width="2px" d="M430,137.0 C430,2.0 770.0,2.0 770.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7e61909a357f4ba4b37efb29d95c6eee-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770.0,139.0 L778.0,127.0 762.0,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7e61909a357f4ba4b37efb29d95c6eee-0-8" stroke-width="2px" d="M790,137.0 C790,92.0 850.0,92.0 850.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7e61909a357f4ba4b37ef

# %%
w1 = nlp('hello')
w2 = nlp('hi')
w3 = nlp('or')

# %%
w1.similarity(w2)
# Out:
# /tmp/ipykernel_1842464/108627858.py:1: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   w1.similarity(w2)
# 0.7451297640800476

# %%
w2.similarity(w1)
# Out:
# /tmp/ipykernel_1842464/1463876200.py:1: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   w2.similarity(w1)
# 0.7451297640800476

# %%
w1.similarity(w3)
# Out:
# /tmp/ipykernel_1842464/3046747863.py:1: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   w1.similarity(w3)
# 0.2684963643550873

# %%
w2.similarity(w3)
# Out:
# /tmp/ipykernel_1842464/754946760.py:1: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   w2.similarity(w3)
# 0.27355116605758667

# %%
text1 = nlp('When will the new movie be released?')
text2 = nlp('The new movie will be released next month')
text3 = nlp('What color is the car?')

# %%
text1.similarity(text2)
# Out:
# /tmp/ipykernel_1842464/3951576355.py:1: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   text1.similarity(text2)
# 0.6667518019676208

# %%
text1.similarity(text3)
# Out:
# /tmp/ipykernel_1842464/1842271901.py:1: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   text1.similarity(text3)
# 0.428114652633667
