# %%
import datetime
print(f"Last updated: {datetime.datetime.now()}")
# Out:
# Last updated: 2026-01-30 22:16:01.938325

# %%
import pandas as pd

# Print the version
print(f"pandas version: {pd.__version__}")
# Out:
# pandas version: 2.3.3
