# %% [markdown]
# # Hello World!
#
# Litte test

# %%
print("Test")
# Out:
# Test

# %%
2+2
# Out:
# 4

# %%
# !ls -l
# Out:
# total 16
# -rw-rw-r-- 1 michalek michalek  1736 sty 30 22:08 example.ipynb
# -rw-rw-r-- 1 michalek michalek 11328 sty 30 21:38 heart-disease.csv
